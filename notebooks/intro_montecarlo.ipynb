# %% [markdown]
# <a href="https://colab.research.google.com/github/hallpaz/drl/blob/main/notebooks/intro_montecarlo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução aos Métodos de Monte Carlo
#
# ## Aprendizado por Reporço para Aplicações em Redes Neurais
#
# ### Prof. Hallison Paz
#
# ##### 29 de fevereiro de 2024
#
#
# ![image.png](data:image/png;base64,...)
# -----

# %%
import numpy as np

# %%
rng = np.random.default_rng()

# %% [markdown]
# 1. Calcule o valor esperado de um dado justo de 10 faces (D10) analiticamente.
#
# - O que este resultado representa?
# - Como este resultado pode ser aproximado computacionalmente?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Qual o valor esperado da soma de 8 dados de 6 faces, 4 dados de 10 faces e 2 dados de 20 faces, considerando que todos os dados são justos?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Escreva um gerador congruente linear que gere números reais aleatórios uniformes entre [0,1). Gere uma longa sequência de números e calcule sua média e variância. Os resultados estão de acordo com o esperado?

# %% [markdown]
# 4. Estime a integral da função $f(x) = x^3$ entre 0 e 1.

# %% [markdown]
# 5. Estime o valor de $\int_{-2}^{2}sen(x^2) e^{\sqrt{x+2}}$

# %% [markdown]
# 5. Estime a área da figura geométrica a seguir, sabendo que a curva vermelha é dada por $y = \sqrt{1 - (|x| - 1)^2}$ enquanto a curva verde é dada por $y = arccos(1 - |x|) - \pi$
#
# (*Fonte da Imagem: [Quora](https://www.quora.com/What-is-the-equation-that-gives-you-a-heart-on-the-graph#:~:text=This%20heart%20above%20is%20graphed,when%20the%20constant%20is%20positive.)*)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6. Implemente o algoritmo $\epsilon$-greedy para um problema de **multi-armed bandits** e compare cenários em relação a diferenças nas recompensas e no valor de $\epsilon$.

# %% [markdown]
# 7. Adapte o algoritmo da questão anterior para a solução de um problema de Contextual Multi-Armed Bandits.
