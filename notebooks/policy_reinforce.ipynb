# %% [markdown]
# <a href="https://colab.research.google.com/github/hallpaz/drl/blob/main/notebooks/policy_reinforce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# O objetivo deste projeto é implementar um ambiente de simulação no framework Gym para resolver um problema específico. Neste problema, há uma coluna denominada "Random" contendo 50 posições, cada uma com um valor aleatório entre 1 e 100 (distribuição uniforme). Além disso, há um campo chamado "Target" que recebe um valor aleatório entre 1 e 100 (distribuição uniforme).

# %% [markdown]
# A missão do agente é selecionar até 5 posições da coluna "Random", uma de cada vez, de modo que a soma dos valores dessas 5 posições alcance o valor do campo "Target", indicando o fim do episódio.

# %%
# !pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)

# %% [markdown]
# É importante destacar que o agente só pode "olhar" para uma posição de cada vez da coluna "Random".
#
# Um episódio é finalizado se a soma de target foi satisfeita ou todas os valores na coluna Random foram vistos ao menos 1 vez.
#
# Implementação:
# 1 - Criação do Ambiente de simulação utilizando o framework Gym.
# 2 - Definição inicial dos hiperparâmetros.
# 3 - Arquitetura da Rede Neural com Tensorflow.
# 4 - Treinamento do Agente.
# 5 - Teste e Demonstração do Agente Maduro.

# %%
import gymnasium as gym
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp

# %%
COMBINE = 1
DONT_COMBINE = 0

# %%
class MatchingEnv(gym.Env):
  def __init__(self, options_size=50, target_size=1, options_limit=5):
    self.options_size = options_size
    self.target_size = target_size
    self.options_limit = options_limit
    self.action_space = [0, 1]

    self.reset()

  def reset(self):
    self.options = np.random.randint(1, 101, self.options_size)
    self.target = np.random.randint(1, 101, self.target_size)
    self.current_option_index = 0
    self.current_target_index = 0
    self.selected = []

    return (self.options[self.current_option_index],
            self.target[self.current_target_index],
            self.options_size - 1,
            len(self.selected))

  def step(self, action):
    done = False
    reward = 0
    if action == COMBINE:
      current_value = self.options[self.current_option_index]
      self.selected.append(current_value)
      # avança para o próximo valor
      self.current_option_index += 1
      # calcula o quanto falta em relação ao target
      # self.target[self.current_target_index] -= current_value
      remaining_value = self.target[self.current_target_index] - sum(self.selected)
      # quantos passos ainda faltam
      remaining_steps = self.options_size - self.current_option_index - 1

      if remaining_value < 0:
        reward = -sum(self.selected)
      else:
        reward = current_value

      # Falta recompensa
    else:
      self.current_option_index += 1
      # calcula o quanto falta em relação ao target
      remaining_value = self.target[self.current_target_index] - sum(self.selected)
      # quantos passos ainda faltam
      remaining_steps = self.options_size - self.current_option_index - 1

    if remaining_value == 0:
      reward = 100 * 10**(self.options_limit - len(self.selected))
      done = True

    if remaining_steps < 0 and not self.selected:
      reward = -100

    if remaining_steps < 0 or len(self.selected) >= self.options_limit or reward < 0:
      done = True

    next_state = (self.options[self.current_option_index % self.options_size],
                remaining_value,
                remaining_steps,
                len(self.selected))

    return next_state, reward, done, {}

# %%
env = MatchingEnv()

# %% [markdown]
# A cada seleção que o agente aposta em fazer, as posições da coluna "Random" são sorteadas novamente, exceto aquelas que foram previamente escolhidas pelo agente.

# %%
class Model(tf.keras.Model):
  def __init__(self, out_size):
    super().__init__()
    self.d1 = tf.keras.layers.Dense(30, activation='relu')
    self.d2 = tf.keras.layers.Dense(30, activation='relu')
    self.out = tf.keras.layers.Dense(out_size, activation='softmax')

  def call(self, input_data):
    x = tf.convert_to_tensor(input_data)
    x = self.d1(x)
    x = self.d2(x)
    x = self.out(x)
    return x

# %%
class Agent():
  def __init__(self):
    self.model = Model(2)
    self.opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    self.gamma = 1

  def act(self, state):
    prob = self.model(np.array([state]))
    dist = tfp.distributions.Categorical(probs=prob, dtype=tf.float32)
    action = dist.sample()
    return int(action.numpy()[0])

  def a_loss(self,prob, action, reward):
    dist = tfp.distributions.Categorical(probs=prob, dtype=tf.float32)
    log_prob = dist.log_prob(action)
    loss = -log_prob*reward
    return loss

  def train(self, states, rewards, actions):
    sum_reward = 0
    discnt_rewards = []
    rewards.reverse()
    for r in rewards:
      sum_reward = r + self.gamma*sum_reward
      discnt_rewards.append(sum_reward)
      discnt_rewards.reverse()

    for state, reward, action in zip(states, discnt_rewards, actions):
      with tf.GradientTape() as tape:
        p = self.model(np.array([state]), training=True)
        loss = self.a_loss(p, action, reward)
        grads = tape.gradient(loss, self.model.trainable_variables)
        self.opt.apply_gradients(zip(grads, self.model.trainable_variables))

# %%
agent = Agent()
steps = 5000

# %%
for s in range(steps):
  done = False
  state = env.reset()
  total_reward = 0
  rewards = []
  states = []
  actions = []
  while not done:
    action = agent.act(state)
    next_state, reward, done, _ = env.step(action)
    rewards.append(reward)
    states.append(state)
    actions.append(action)
    state = next_state
    total_reward += reward

    if done:
      agent.train(states, rewards, actions)
      print(env.target, env.selected)
      print("total reward after {} steps is {}".format(s, total_reward))
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# [76] [34, 58]
# total reward after 47500 steps is -58
# [81] [25, 40, 28]
# total reward after 47501 steps is -28
# [72] [72]
# total reward after 47502 steps is 1000000
# [100] [31, 47, 31]
# total reward after 47503 steps is -31
# [69] [97]
# total reward after 47504 steps is -97
# [91] [41, 77]
# total reward after 47505 steps is -77
# [42] [99]
# total reward after 47506 steps is -99
# [99] [65, 31, 90]
# total reward after 47507 steps is -90
# [2] [6]
# total reward after 47508 steps is -6
# [88] [38, 75]
# total reward after 47509 steps is -75
# [28] [43]
# total reward after 47510 steps is -43
# [93] [83, 46]
# total reward after 47511 steps is -46
# [15] [20]
# total reward after 47512 steps is -20
# [25] [11, 4, 10]
# total reward after 47513 steps is 10015
# [83] [90]
# total reward after 47514 steps is -90
# [28] [75]
# total reward after 47515 steps is -75
# [15] [28]
# total reward after 47516 steps is -28
# [65] [16, 69]
# total reward after 47517 steps is -69
# [36] [94]
# total reward after 47518 steps is -94
# [1] [44]
# total reward after 47519 steps is -44
# [19] [39]
# total reward after 47520 steps is -39
# [83] [8, 41, 53]
# total reward after 47521 steps is -53
# [70] [10, 52, 100]
# total reward after 47522 steps is -100
# [30] [24, 7]
# total reward after 47523 steps is -7
# [3] [95]
# total reward after 47524 steps is -95
# [33] [98]
# total reward after 47525 steps is -98
# [38] [67]
# total reward after 47526 steps is -67
# [4] [63]
# total reward after 47527 steps is -63
# [6] [83]
# total reward after 47528 steps is -83
# [6] [25]
# total reward after 47529 steps is -25
# [87] [42, 81]
# total reward after 47530 steps is -81
# [1] [29]
# total reward after 47531 steps is -29
# [35] [59]
# total reward after 47532 steps is -59
# [14] [88]
# total reward after 47533 steps is -88
# [30] [17, 82]
# total reward after 47534 steps is -82
# [81] [46, 39]
# total reward after 47535 steps is -39
# [52] [32, 100]
# total reward after 47536 steps is -100
# [12] [41]
# total reward after 47537 steps is -41
# [21] [5, 42]
# total reward after 47538 steps is -42
# [50] [5, 55]
# total reward after 47539 steps is -55
# [26] [27]
# total reward after 47540 steps is -27
# [52] [25, 62]
# total reward after 47541 steps is -62
# [60] [37, 66]
# total reward after 47542 steps is -66
# [49] [7, 71]
# total reward after 47543 steps is -71
# [29] [79]
# total reward after 47544 steps is -79
# [34] [13, 63]
# total reward after 47545 steps is -63
# [32] [83]
# total reward after 47546 steps is -83
# [14] [31]
# total reward after 47547 steps is -31
# [12] [43]
# total reward after 47548 steps is -43
# [2] [47]
# total reward after 47549 steps is -47
# [60] [32, 9, 47]
# total reward after 47550 steps is -47
# [70] [74]
# total reward after 47551 steps is -74
# [80] [16, 27, 42]
# total reward after 47552 steps is -42
# [30] [41]
# total reward after 47553 steps is -41
# [90] [90]
# total reward after 47554 steps is 1000000
# [37] [24, 43]
# total reward after 47555 steps is -43
# [74] [97]
# total reward after 47556 steps is -97
# [42] [58]
# total reward after 47557 steps is -58
# [55] [46, 52]
# total reward after 47558 steps is -52
# [74] [35, 27, 60]
# total reward after 47559 steps is -60
# [96] [32, 47, 22]
# total reward after 47560 steps is -22
# [75] [44, 62]
# total reward after 47561 steps is -62
# [16] [77]
# total reward after 47562 steps is -77
# [47] [63]
# total reward after 47563 steps is -63
# [96] [26, 98]
# total reward after 47564 steps is -98
# [63] [10, 82]
# total reward after 47565 steps is -82
# [97] [38, 17, 99]
# total reward after 47566 steps is -99
# [46] [43, 68]
# total reward after 47567 steps is -68
# [75] [51, 95]
# total reward after 47568 steps is -95
# [57] [79]
# total reward after 47569 steps is -79
# [60] [10, 30, 42]
# total reward after 47570 steps is -42
# [2] [16]
# total reward after 47571 steps is -16
# [23] [78]
# total reward after 47572 steps is -78
# [79] [54, 33]
# total reward after 47573 steps is -33
# [59] [47, 45]
# total reward after 47574 steps is -45
# [58] [94]
# total reward after 47575 steps is -94
# [50] [86]
# total reward after 47576 steps is -86
# [91] [96]
# total reward after 47577 steps is -96
# [16] [92]
# total reward after 47578 steps is -92
# [11] [66]
# total reward after 47579 steps is -66
# [3] [41]
# total reward after 47580 steps is -41
# [51] [51]
# total reward after 47581 steps is 1000000
# [1] [74]
# total reward after 47582 steps is -74
# [30] [20, 39]
# total reward after 47583 steps is -39
# [61] [95]
# total reward after 47584 steps is -95
# [95] [5, 11, 27, 18, 18]
# total reward after 47585 steps is 79
# [47] [16, 88]
# total reward after 47586 steps is -88
# [97] [65, 79]
# total reward after 47587 steps is -79
# [17] [37]
# total reward after 47588 steps is -37
# [34] [22, 14]
# total reward after 47589 steps is -14
# [6] [83]
# total reward after 47590 steps is -83
# [87] [63, 76]
# total reward after 47591 steps is -76
# [33] [20, 21]
# total reward after 47592 steps is -21
# [61] [41, 41]
# total reward after 47593 steps is -41
# [73] [28, 38, 1, 10]
# total reward after 47594 steps is -10
# [54] [43, 10, 99]
# total reward after 47595 steps is -99
# [63] [56, 88]
# total reward after 47596 steps is -88
# [78] [21, 9, 35, 71]
# total reward after 47597 steps is -71
# [73] [55, 61]
# total reward after 47598 steps is -61
# [73] [88]
# total reward after 47599 steps is -88
# [61] [38, 67]
# total reward after 47600 steps is -67
# [23] [87]
# total reward after 47601 steps is -87
# [40] [95]
# total reward after 47602 steps is -95
# [27] [86]
# total reward after 47603 steps is -86
# [52] [83]
# total reward after 47604 steps is -83
# [6] [45]
# total reward after 47605 steps is -45
# [54] [2, 79]
# total reward after 47606 steps is -79
# [51] [64]
# total reward after 47607 steps is -64
# [57] [9, 30, 66]
# total reward after 47608 steps is -66
# [66] [71]
# total reward after 47609 steps is -71
# [61] [14, 42, 88]
# total reward after 47610 steps is -88
# [34] [16, 15, 100]
# total reward after 47611 steps is -100
# [22] [32]
# total reward after 47612 steps is -32
# [92] [24, 50, 7, 78]
# total reward after 47613 steps is -78
# [88] [12, 90]
# total reward after 47614 steps is -90
# [58] [60]
# total reward after 47615 steps is -60
# [79] [86]
# total reward after 47616 steps is -86
# [47] [84]
# total reward after 47617 steps is -84
# [12] [44]
# total reward after 47618 steps is -44
# [59] [22, 84]
# total reward after 47619 steps is -84
# [47] [62]
# total reward after 47620 steps is -62
# [96] [36, 28, 98]
# total reward after 47621 steps is -98
# [38] [56]
# total reward after 47622 steps is -56
# [70] [31, 94]
# total reward after 47623 steps is -94
# [20] [88]
# total reward after 47624 steps is -88
# [33] [14, 86]
# total reward after 47625 steps is -86
# [96] [43, 64]
# total reward after 47626 steps is -64
# [39] [29, 33]
# total reward after 47627 steps is -33
# [18] [43]
# total reward after 47628 steps is -43
# [74] [18, 37, 7, 43]
# total reward after 47629 steps is -43
# [13] [9, 98]
# total reward after 47630 steps is -98
# [92] [51, 46]
# total reward after 47631 steps is -46
# [63] [82]
# total reward after 47632 steps is -82
# [62] [96]
# total reward after 47633 steps is -96
# [91] [15, 65, 36]
# total reward after 47634 steps is -36
# [9] [71]
# total reward after 47635 steps is -71
# [97] [18, 99]
# total reward after 47636 steps is -99
# [42] [6, 66]
# total reward after 47637 steps is -66
# [10] [66]
# total reward after 47638 steps is -66
# [22] [11, 38]
# total reward after 47639 steps is -38
# [57] [30, 81]
# total reward after 47640 steps is -81
# [92] [32, 87]
# total reward after 47641 steps is -87
# [7] [62]
# total reward after 47642 steps is -62
# [43] [77]
# total reward after 47643 steps is -77
# [100] [36, 94]
# total reward after 47644 steps is -94
# [99] [43, 20, 61]
# total reward after 47645 steps is -61
# [5] [51]
# total reward after 47646 steps is -51
# [95] [83, 83]
# total reward after 47647 steps is -83
# [55] [37, 39]
# total reward after 47648 steps is -39
# [60] [97]
# total reward after 47649 steps is -97
# [33] [17, 81]
# total reward after 47650 steps is -81
# [60] [67]
# total reward after 47651 steps is -67
# [75] [94]
# total reward after 47652 steps is -94
# [85] [25, 23, 50]
# total reward after 47653 steps is -50
# [5] [39]
# total reward after 47654 steps is -39
# [27] [51]
# total reward after 47655 steps is -51
# [74] [73, 36]
# total reward after 47656 steps is -36
# [23] [61]
# total reward after 47657 steps is -61
# [18] [48]
# total reward after 47658 steps is -48
# [27] [35]
# total reward after 47659 steps is -35
# [63] [27, 3, 99]
# total reward after 47660 steps is -99
# [9] [61]
# total reward after 47661 steps is -61
# [43] [50]
# total reward after 47662 steps is -50
# [20] [48]
# total reward after 47663 steps is -48
# [65] [64, 61]
# total reward after 47664 steps is -61
# [9] [62]
# total reward after 47665 steps is -62
# [9] [3, 13]
# total reward after 47666 steps is -13
# [54] [72]
# total reward after 47667 steps is -72
# [22] [54]
# total reward after 47668 steps is -54
# [14] [69]
# total reward after 47669 steps is -69
# [10] [16]
# total reward after 47670 steps is -16
# [28] [87]
# total reward after 47671 steps is -87
# [60] [20, 42]
# total reward after 47672 steps is -42
# [9] [74]
# total reward after 47673 steps is -74
# [28] [54]
# total reward after 47674 steps is -54
# [14] [66]
# total reward after 47675 steps is -66
# [60] [73]
# total reward after 47676 steps is -73
# [57] [48, 80]
# total reward after 47677 steps is -80
# [21] [87]
# total reward after 47678 steps is -87
# [82] [1, 73, 36]
# total reward after 47679 steps is -36
# [54] [31, 98]
# total reward after 47680 steps is -98
# [45] [17, 57]
# total reward after 47681 steps is -57
# [59] [90]
# total reward after 47682 steps is -90
# [41] [44]
# total reward after 47683 steps is -44
# [73] [72, 7]
# total reward after 47684 steps is -7
# [27] [48]
# total reward after 47685 steps is -48
# [48] [58]
# total reward after 47686 steps is -58
# [70] [47, 71]
# total reward after 47687 steps is -71
# [72] [75]
# total reward after 47688 steps is -75
# [92] [76, 18]
# total reward after 47689 steps is -18
# [76] [21, 90]
# total reward after 47690 steps is -90
# [40] [92]
# total reward after 47691 steps is -92
# [73] [56, 13, 99]
# total reward after 47692 steps is -99
# [65] [55, 7, 94]
# total reward after 47693 steps is -94
# [81] [76, 89]
# total reward after 47694 steps is -89
# [69] [52, 91]
# total reward after 47695 steps is -91
# [98] [92, 95]
# total reward after 47696 steps is -95
# [86] [69, 57]
# total reward after 47697 steps is -57
# [17] [69]
# total reward after 47698 steps is -69
# [22] [25]
# total reward after 47699 steps is -25
# [79] [73, 86]
# total reward after 47700 steps is -86
# [32] [41]
# total reward after 47701 steps is -41
# [82] [27, 17, 19, 86]
# total reward after 47702 steps is -86
# [2] [83]
# total reward after 47703 steps is -83
# [84] [52, 64]
# total reward after 47704 steps is -64
# [56] [92]
# total reward after 47705 steps is -92
# [74] [78]
# total reward after 47706 steps is -78
# [26] [58]
# total reward after 47707 steps is -58
# [54] [97]
# total reward after 47708 steps is -97
# [10] [36]
# total reward after 47709 steps is -36
# [51] [85]
# total reward after 47710 steps is -85
# [96] [86, 56]
# total reward after 47711 steps is -56
# [93] [95]
# total reward after 47712 steps is -95
# [6] [28]
# total reward after 47713 steps is -28
# [5] [63]
# total reward after 47714 steps is -63
# [51] [62]
# total reward after 47715 steps is -62
# [49] [60]
# total reward after 47716 steps is -60
# [75] [9, 73]
# total reward after 47717 steps is -73
# [68] [48, 39]
# total reward after 47718 steps is -39
# [47] [10, 87]
# total reward after 47719 steps is -87
# [16] [77]
# total reward after 47720 steps is -77
# [34] [35]
# total reward after 47721 steps is -35
# [99] [43, 98]
# total reward after 47722 steps is -98
# [93] [68, 88]
# total reward after 47723 steps is -88
# [43] [5, 97]
# total reward after 47724 steps is -97
# [27] [16, 79]
# total reward after 47725 steps is -79
# [8] [93]
# total reward after 47726 steps is -93
# [22] [68]
# total reward after 47727 steps is -68
# [79] [38, 38, 5]
# total reward after 47728 steps is -5
# [15] [84]
# total reward after 47729 steps is -84
# [27] [50]
# total reward after 47730 steps is -50
# [37] [24, 39]
# total reward after 47731 steps is -39
# [84] [33, 7, 61]
# total reward after 47732 steps is -61
# [4] [63]
# total reward after 47733 steps is -63
# [77] [59, 82]
# total reward after 47734 steps is -82
# [23] [36]
# total reward after 47735 steps is -36
# [43] [77]
# total reward after 47736 steps is -77
# [28] [55]
# total reward after 47737 steps is -55
# [45] [8, 11, 63]
# total reward after 47738 steps is -63
# [83] [65, 38]
# total reward after 47739 steps is -38
# [79] [45, 18, 2, 28]
# total reward after 47740 steps is -28
# [77] [89]
# total reward after 47741 steps is -89
# [73] [16, 36, 41]
# total reward after 47742 steps is -41
# [51] [11, 25, 42]
# total reward after 47743 steps is -42
# [82] [43, 51]
# total reward after 47744 steps is -51
# [79] [39, 82]
# total reward after 47745 steps is -82
# [11] [76]
# total reward after 47746 steps is -76
# [99] [41, 13, 87]
# total reward after 47747 steps is -87
# [48] [90]
# total reward after 47748 steps is -90
# [61] [82]
# total reward after 47749 steps is -82
# [33] [50]
# total reward after 47750 steps is -50
# [14] [2, 84]
# total reward after 47751 steps is -84
# [51] [57]
# total reward after 47752 steps is -57
# [2] [27]
# total reward after 47753 steps is -27
# [57] [20, 27, 85]
# total reward after 47754 steps is -85
# [20] [81]
# total reward after 47755 steps is -81
# [26] [90]
# total reward after 47756 steps is -90
# [26] [89]
# total reward after 47757 steps is -89
# [39] [24, 72]
# total reward after 47758 steps is -72
# [21] [84]
# total reward after 47759 steps is -84
# [82] [55, 34]
# total reward after 47760 steps is -34
# [80] [90]
# total reward after 47761 steps is -90
# [81] [66, 18]
# total reward after 47762 steps is -18
# [15] [61]
# total reward after 47763 steps is -61
# [83] [58, 28]
# total reward after 47764 steps is -28
# [100] [77, 38]
# total reward after 47765 steps is -38
# [30] [16, 33]
# total reward after 47766 steps is -33
# [13] [81]
# total reward after 47767 steps is -81
# [72] [25, 15, 77]
# total reward after 47768 steps is -77
# [39] [84]
# total reward after 47769 steps is -84
# [18] [50]
# total reward after 47770 steps is -50
# [45] [70]
# total reward after 47771 steps is -70
# [68] [83]
# total reward after 47772 steps is -83
# [9] [4, 20]
# total reward after 47773 steps is -20
# [85] [86]
# total reward after 47774 steps is -86
# [68] [43, 71]
# total reward after 47775 steps is -71
# [55] [75]
# total reward after 47776 steps is -75
# [44] [63]
# total reward after 47777 steps is -63
# [52] [88]
# total reward after 47778 steps is -88
# [81] [61, 61]
# total reward after 47779 steps is -61
# [74] [44, 57]
# total reward after 47780 steps is -57
# [12] [40]
# total reward after 47781 steps is -40
# [14] [50]
# total reward after 47782 steps is -50
# [71] [20, 74]
# total reward after 47783 steps is -74
# [6] [91]
# total reward after 47784 steps is -91
# [79] [19, 92]
# total reward after 47785 steps is -92
# [32] [43]
# total reward after 47786 steps is -43
# [70] [100]
# total reward after 47787 steps is -100
# [65] [15, 74]
# total reward after 47788 steps is -74
# [34] [17, 2, 74]
# total reward after 47789 steps is -74
# [87] [46, 52]
# total reward after 47790 steps is -52
# [99] [10, 56, 68]
# total reward after 47791 steps is -68
# [9] [74]
# total reward after 47792 steps is -74
# [28] [45]
# total reward after 47793 steps is -45
# [8] [13]
# total reward after 47794 steps is -13
# [53] [21, 41]
# total reward after 47795 steps is -41
# [1] [92]
# total reward after 47796 steps is -92
# [80] [76, 100]
# total reward after 47797 steps is -100
# [100] [63, 39]
# total reward after 47798 steps is -39
# [23] [51]
# total reward after 47799 steps is -51
# [23] [19, 42]
# total reward after 47800 steps is -42
# [50] [85]
# total reward after 47801 steps is -85
# [11] [53]
# total reward after 47802 steps is -53
# [67] [81]
# total reward after 47803 steps is -81
# [59] [4, 1, 98]
# total reward after 47804 steps is -98
# [45] [76]
# total reward after 47805 steps is -76
# [26] [97]
# total reward after 47806 steps is -97
# [26] [77]
# total reward after 47807 steps is -77
# [43] [94]
# total reward after 47808 steps is -94
# [78] [37, 93]
# total reward after 47809 steps is -93
# [68] [22, 19, 12, 100]
# total reward after 47810 steps is -100
# [95] [57, 98]
# total reward after 47811 steps is -98
# [57] [54, 24]
# total reward after 47812 steps is -24
# [72] [76]
# total reward after 47813 steps is -76
# [46] [16, 29, 57]
# total reward after 47814 steps is -57
# [10] [89]
# total reward after 47815 steps is -89
# [12] [96]
# total reward after 47816 steps is -96
# [68] [42, 66]
# total reward after 47817 steps is -66
# [17] [49]
# total reward after 47818 steps is -49
# [38] [84]
# total reward after 47819 steps is -84
# [42] [7, 45]
# total reward after 47820 steps is -45
# [95] [50, 30, 11, 53]
# total reward after 47821 steps is -53
# [7] [17]
# total reward after 47822 steps is -17
# [61] [82]
# total reward after 47823 steps is -82
# [13] [71]
# total reward after 47824 steps is -71
# [10] [98]
# total reward after 47825 steps is -98
# [71] [75]
# total reward after 47826 steps is -75
# [71] [89]
# total reward after 47827 steps is -89
# [60] [75]
# total reward after 47828 steps is -75
# [8] [87]
# total reward after 47829 steps is -87
# [56] [62]
# total reward after 47830 steps is -62
# [28] [73]
# total reward after 47831 steps is -73
# [73] [40, 82]
# total reward after 47832 steps is -82
# [53] [38, 33]
# total reward after 47833 steps is -33
# [69] [18, 74]
# total reward after 47834 steps is -74
# [42] [40, 50]
# total reward after 47835 steps is -50
# [40] [84]
# total reward after 47836 steps is -84
# [44] [6, 13, 42]
# total reward after 47837 steps is -42
# [71] [47, 50]
# total reward after 47838 steps is -50
# [88] [60, 22, 17]
# total reward after 47839 steps is -17
# [17] [38]
# total reward after 47840 steps is -38
# [83] [63, 89]
# total reward after 47841 steps is -89
# [42] [77]
# total reward after 47842 steps is -77
# [94] [49, 19, 4, 78]
# total reward after 47843 steps is -78
# [66] [76]
# total reward after 47844 steps is -76
# [51] [38, 33]
# total reward after 47845 steps is -33
# [29] [93]
# total reward after 47846 steps is -93
# [2] [72]
# total reward after 47847 steps is -72
# [44] [94]
# total reward after 47848 steps is -94
# [99] [12, 15, 92]
# total reward after 47849 steps is -92
# [7] [32]
# total reward after 47850 steps is -32
# [96] [37, 80]
# total reward after 47851 steps is -80
# [82] [58, 53]
# total reward after 47852 steps is -53
# [3] [32]
# total reward after 47853 steps is -32
# [13] [63]
# total reward after 47854 steps is -63
# [31] [42]
# total reward after 47855 steps is -42
# [9] [49]
# total reward after 47856 steps is -49
# [67] [21, 90]
# total reward after 47857 steps is -90
# [61] [42, 94]
# total reward after 47858 steps is -94
# [64] [38, 32]
# total reward after 47859 steps is -32
# [77] [66, 55]
# total reward after 47860 steps is -55
# [14] [34]
# total reward after 47861 steps is -34
# [42] [5, 92]
# total reward after 47862 steps is -92
# [12] [44]
# total reward after 47863 steps is -44
# [12] [39]
# total reward after 47864 steps is -39
# [22] [50]
# total reward after 47865 steps is -50
# [11] [83]
# total reward after 47866 steps is -83
# [74] [86]
# total reward after 47867 steps is -86
# [58] [98]
# total reward after 47868 steps is -98
# [13] [42]
# total reward after 47869 steps is -42
# [85] [59, 81]
# total reward after 47870 steps is -81
# [60] [81]
# total reward after 47871 steps is -81
# [19] [8, 6, 98]
# total reward after 47872 steps is -98
# [88] [84, 48]
# total reward after 47873 steps is -48
# [77] [80]
# total reward after 47874 steps is -80
# [70] [100]
# total reward after 47875 steps is -100
# [4] [16]
# total reward after 47876 steps is -16
# [69] [3, 73]
# total reward after 47877 steps is -73
# [78] [24, 60]
# total reward after 47878 steps is -60
# [25] [49]
# total reward after 47879 steps is -49
# [1] [76]
# total reward after 47880 steps is -76
# [95] [100]
# total reward after 47881 steps is -100
# [82] [6, 94]
# total reward after 47882 steps is -94
# [99] [68, 82]
# total reward after 47883 steps is -82
# [5] [74]
# total reward after 47884 steps is -74
# [59] [50, 77]
# total reward after 47885 steps is -77
# [94] [84, 46]
# total reward after 47886 steps is -46
# [68] [32, 94]
# total reward after 47887 steps is -94
# [8] [77]
# total reward after 47888 steps is -77
# [62] [38, 15, 51]
# total reward after 47889 steps is -51
# [27] [96]
# total reward after 47890 steps is -96
# [65] [69]
# total reward after 47891 steps is -69
# [76] [71, 41]
# total reward after 47892 steps is -41
# [90] [5, 90]
# total reward after 47893 steps is -90
# [32] [91]
# total reward after 47894 steps is -91
# [29] [56]
# total reward after 47895 steps is -56
# [28] [4, 37]
# total reward after 47896 steps is -37
# [71] [66, 24]
# total reward after 47897 steps is -24
# [70] [37, 54]
# total reward after 47898 steps is -54
# [27] [48]
# total reward after 47899 steps is -48
# [34] [7, 26, 24]
# total reward after 47900 steps is -24
# [24] [15, 63]
# total reward after 47901 steps is -63
# [9] [37]
# total reward after 47902 steps is -37
# [96] [86, 22]
# total reward after 47903 steps is -22
# [84] [83, 83]
# total reward after 47904 steps is -83
# [86] [53, 17, 15, 32]
# total reward after 47905 steps is -32
# [16] [16]
# total reward after 47906 steps is 1000000
# [19] [74]
# total reward after 47907 steps is -74
# [77] [19, 76]
# total reward after 47908 steps is -76
# [20] [52]
# total reward after 47909 steps is -52
# [63] [83]
# total reward after 47910 steps is -83
# [34] [100]
# total reward after 47911 steps is -100
# [65] [55, 62]
# total reward after 47912 steps is -62
# [25] [50]
# total reward after 47913 steps is -50
# [96] [14, 91]
# total reward after 47914 steps is -91
# [11] [75]
# total reward after 47915 steps is -75
# [94] [65, 21, 45]
# total reward after 47916 steps is -45
# [89] [55, 33, 99]
# total reward after 47917 steps is -99
# [89] [78, 43]
# total reward after 47918 steps is -43
# [10] [1, 1, 58]
# total reward after 47919 steps is -58
# [9] [43]
# total reward after 47920 steps is -43
# [14] [40]
# total reward after 47921 steps is -40
# [7] [2, 85]
# total reward after 47922 steps is -85
# [40] [51]
# total reward after 47923 steps is -51
# [90] [63, 32]
# total reward after 47924 steps is -32
# [49] [55]
# total reward after 47925 steps is -55
# [77] [59, 74]
# total reward after 47926 steps is -74
# [4] [10]
# total reward after 47927 steps is -10
# [60] [40, 64]
# total reward after 47928 steps is -64
# [85] [3, 37, 18, 7, 91]
# total reward after 47929 steps is -91
# [52] [33, 5, 12, 33]
# total reward after 47930 steps is -33
# [25] [97]
# total reward after 47931 steps is -97
# [71] [37, 60]
# total reward after 47932 steps is -60
# [28] [60]
# total reward after 47933 steps is -60
# [1] [28]
# total reward after 47934 steps is -28
# [44] [66]
# total reward after 47935 steps is -66
# [55] [93]
# total reward after 47936 steps is -93
# [60] [74]
# total reward after 47937 steps is -74
# [65] [2, 54, 61]
# total reward after 47938 steps is -61
# [40] [77]
# total reward after 47939 steps is -77
# [23] [8, 30]
# total reward after 47940 steps is -30
# [52] [96]
# total reward after 47941 steps is -96
# [13] [35]
# total reward after 47942 steps is -35
# [21] [25]
# total reward after 47943 steps is -25
# [45] [18, 70]
# total reward after 47944 steps is -70
# [85] [25, 69]
# total reward after 47945 steps is -69
# [63] [4, 43, 46]
# total reward after 47946 steps is -46
# [94] [33, 6, 54, 40]
# total reward after 47947 steps is -40
# [47] [71]
# total reward after 47948 steps is -71
# [88] [38, 8, 12, 58]
# total reward after 47949 steps is -58
# [53] [99]
# total reward after 47950 steps is -99
# [78] [6, 29, 2, 84]
# total reward after 47951 steps is -84
# [48] [26, 40]
# total reward after 47952 steps is -40
# [45] [9, 91]
# total reward after 47953 steps is -91
# [78] [19, 95]
# total reward after 47954 steps is -95
# [29] [4, 91]
# total reward after 47955 steps is -91
# [68] [94]
# total reward after 47956 steps is -94
# [66] [17, 24, 27]
# total reward after 47957 steps is -27
# [38] [83]
# total reward after 47958 steps is -83
# [85] [44, 99]
# total reward after 47959 steps is -99
# [61] [55, 28]
# total reward after 47960 steps is -28
# [11] [70]
# total reward after 47961 steps is -70
# [80] [48, 41]
# total reward after 47962 steps is -41
# [74] [76]
# total reward after 47963 steps is -76
# [46] [45, 30]
# total reward after 47964 steps is -30
# [58] [31, 66]
# total reward after 47965 steps is -66
# [28] [52]
# total reward after 47966 steps is -52
# [15] [51]
# total reward after 47967 steps is -51
# [2] [85]
# total reward after 47968 steps is -85
# [74] [64, 17]
# total reward after 47969 steps is -17
# [88] [11, 60, 57]
# total reward after 47970 steps is -57
# [54] [84]
# total reward after 47971 steps is -84
# [68] [51, 92]
# total reward after 47972 steps is -92
# [83] [13, 10, 55, 45]
# total reward after 47973 steps is -45
# [71] [31, 32, 65]
# total reward after 47974 steps is -65
# [65] [55, 57]
# total reward after 47975 steps is -57
# [90] [15, 39, 90]
# total reward after 47976 steps is -90
# [61] [48, 73]
# total reward after 47977 steps is -73
# [61] [63]
# total reward after 47978 steps is -63
# [93] [12, 45, 92]
# total reward after 47979 steps is -92
# [97] [33, 17, 81]
# total reward after 47980 steps is -81
# [2] [29]
# total reward after 47981 steps is -29
# [92] [76, 90]
# total reward after 47982 steps is -90
# [89] [10, 91]
# total reward after 47983 steps is -91
# [54] [32, 83]
# total reward after 47984 steps is -83
# [42] [83]
# total reward after 47985 steps is -83
# [18] [31]
# total reward after 47986 steps is -31
# [70] [79]
# total reward after 47987 steps is -79
# [66] [85]
# total reward after 47988 steps is -85
# [78] [28, 16, 26, 100]
# total reward after 47989 steps is -100
# [98] [45, 87]
# total reward after 47990 steps is -87
# [56] [60]
# total reward after 47991 steps is -60
# [35] [58]
# total reward after 47992 steps is -58
# [69] [66, 53]
# total reward after 47993 steps is -53
# [15] [43]
# total reward after 47994 steps is -43
# [68] [41, 38]
# total reward after 47995 steps is -38
# [32] [66]
# total reward after 47996 steps is -66
# [89] [20, 46, 91]
# total reward after 47997 steps is -91
# [14] [94]
# total reward after 47998 steps is -94
# [15] [65]
# total reward after 47999 steps is -65
# [94] [13, 34, 72]
# total reward after 48000 steps is -72
# [82] [23, 20, 37, 78]
# total reward after 48001 steps is -78
# [52] [33, 98]
# total reward after 48002 steps is -98
# [48] [79]
# total reward after 48003 steps is -79
# [81] [54, 68]
# total reward after 48004 steps is -68
# [3] [1, 3]
# total reward after 48005 steps is -3
# [95] [45, 13, 17, 1, 74]
# total reward after 48006 steps is -74
# [66] [85]
# total reward after 48007 steps is -85
# [60] [82]
# total reward after 48008 steps is -82
# [72] [32, 60]
# total reward after 48009 steps is -60
# [25] [7, 30]
# total reward after 48010 steps is -30
# [39] [31, 79]
# total reward after 48011 steps is -79
# [32] [51]
# total reward after 48012 steps is -51
# [10] [95]
# total reward after 48013 steps is -95
# [31] [42]
# total reward after 48014 steps is -42
# [97] [42, 3, 55]
# total reward after 48015 steps is -55
# [42] [21, 25]
# total reward after 48016 steps is -25
# [89] [73, 94]
# total reward after 48017 steps is -94
# [8] [89]
# total reward after 48018 steps is -89
# [85] [80, 13]
# total reward after 48019 steps is -13
# [71] [42, 61]
# total reward after 48020 steps is -61
# [11] [99]
# total reward after 48021 steps is -99
# [64] [80]
# total reward after 48022 steps is -80
# [55] [34, 32]
# total reward after 48023 steps is -32
# [52] [35, 39]
# total reward after 48024 steps is -39
# [17] [45]
# total reward after 48025 steps is -45
# [1] [14]
# total reward after 48026 steps is -14
# [41] [51]
# total reward after 48027 steps is -51
# [48] [67]
# total reward after 48028 steps is -67
# [7] [93]
# total reward after 48029 steps is -93
# [100] [12, 24, 66]
# total reward after 48030 steps is -66
# [77] [16, 44, 82]
# total reward after 48031 steps is -82
# [53] [72]
# total reward after 48032 steps is -72
# [19] [30]
# total reward after 48033 steps is -30
# [64] [90]
# total reward after 48034 steps is -90
# [10] [74]
# total reward after 48035 steps is -74
# [6] [97]
# total reward after 48036 steps is -97
# [72] [69, 60]
# total reward after 48037 steps is -60
# [43] [46]
# total reward after 48038 steps is -46
# [81] [72, 19]
# total reward after 48039 steps is -19
# [28] [70]
# total reward after 48040 steps is -70
# [32] [2, 6, 69]
# total reward after 48041 steps is -69
# [90] [57, 61]
# total reward after 48042 steps is -61
# [22] [36]
# total reward after 48043 steps is -36
# [66] [96]
# total reward after 48044 steps is -96
# [49] [5, 37, 16]
# total reward after 48045 steps is -16
# [47] [17, 69]
# total reward after 48046 steps is -69
# [24] [85]
# total reward after 48047 steps is -85
# [77] [15, 27, 40]
# total reward after 48048 steps is -40
# [41] [23, 53]
# total reward after 48049 steps is -53
# [58] [58]
# total reward after 48050 steps is 1000000
# [42] [76]
# total reward after 48051 steps is -76
# [96] [29, 63, 87]
# total reward after 48052 steps is -87
# [66] [86]
# total reward after 48053 steps is -86
# [9] [16]
# total reward after 48054 steps is -16
# [13] [30]
# total reward after 48055 steps is -30
# [52] [47, 1, 75]
# total reward after 48056 steps is -75
# [7] [13]
# total reward after 48057 steps is -13
# [56] [89]
# total reward after 48058 steps is -89
# [4] [53]
# total reward after 48059 steps is -53
# [25] [22, 43]
# total reward after 48060 steps is -43
# [42] [46]
# total reward after 48061 steps is -46
# [77] [24, 14, 8, 52]
# total reward after 48062 steps is -52
# [96] [21, 63, 88]
# total reward after 48063 steps is -88
# [88] [5, 53, 60]
# total reward after 48064 steps is -60
# [49] [25, 62]
# total reward after 48065 steps is -62
# [59] [100]
# total reward after 48066 steps is -100
# [58] [63]
# total reward after 48067 steps is -63
# [88] [81, 18]
# total reward after 48068 steps is -18
# [54] [61]
# total reward after 48069 steps is -61
# [29] [24, 19]
# total reward after 48070 steps is -19
# [31] [8, 6, 21]
# total reward after 48071 steps is -21
# [74] [97]
# total reward after 48072 steps is -97
# [4] [76]
# total reward after 48073 steps is -76
# [74] [74]
# total reward after 48074 steps is 1000000
# [12] [16]
# total reward after 48075 steps is -16
# [43] [75]
# total reward after 48076 steps is -75
# [68] [98]
# total reward after 48077 steps is -98
# [62] [17, 46]
# total reward after 48078 steps is -46
# [20] [93]
# total reward after 48079 steps is -93
# [78] [11, 93]
# total reward after 48080 steps is -93
# [82] [56, 70]
# total reward after 48081 steps is -70
# [77] [69, 67]
# total reward after 48082 steps is -67
# [98] [34, 68]
# total reward after 48083 steps is -68
# [39] [23, 50]
# total reward after 48084 steps is -50
# [42] [70]
# total reward after 48085 steps is -70
# [35] [96]
# total reward after 48086 steps is -96
# [3] [8]
# total reward after 48087 steps is -8
# [24] [12, 54]
# total reward after 48088 steps is -54
# [71] [8, 90]
# total reward after 48089 steps is -90
# [48] [8, 26, 23]
# total reward after 48090 steps is -23
# [31] [46]
# total reward after 48091 steps is -46
# [25] [17, 32]
# total reward after 48092 steps is -32
# [46] [48]
# total reward after 48093 steps is -48
# [44] [97]
# total reward after 48094 steps is -97
# [13] [74]
# total reward after 48095 steps is -74
# [94] [52, 95]
# total reward after 48096 steps is -95
# [64] [52, 76]
# total reward after 48097 steps is -76
# [59] [77]
# total reward after 48098 steps is -77
# [100] [99, 69]
# total reward after 48099 steps is -69
# [82] [18, 27, 62]
# total reward after 48100 steps is -62
# [30] [20, 98]
# total reward after 48101 steps is -98
# [54] [76]
# total reward after 48102 steps is -76
# [86] [22, 33, 42]
# total reward after 48103 steps is -42
# [97] [76, 94]
# total reward after 48104 steps is -94
# [50] [91]
# total reward after 48105 steps is -91
# [86] [31, 94]
# total reward after 48106 steps is -94
# [16] [80]
# total reward after 48107 steps is -80
# [32] [46]
# total reward after 48108 steps is -46
# [51] [92]
# total reward after 48109 steps is -92
# [42] [9, 37]
# total reward after 48110 steps is -37
# [70] [36, 84]
# total reward after 48111 steps is -84
# [87] [45, 70]
# total reward after 48112 steps is -70
# [8] [79]
# total reward after 48113 steps is -79
# [54] [2, 40, 48]
# total reward after 48114 steps is -48
# [51] [83]
# total reward after 48115 steps is -83
# [5] [93]
# total reward after 48116 steps is -93
# [34] [5, 62]
# total reward after 48117 steps is -62
# [32] [14, 70]
# total reward after 48118 steps is -70
# [81] [14, 1, 6, 46, 46]
# total reward after 48119 steps is -46
# [91] [29, 69]
# total reward after 48120 steps is -69
# [98] [26, 31, 44]
# total reward after 48121 steps is -44
# [25] [87]
# total reward after 48122 steps is -87
# [29] [3, 3, 3, 3, 29]
# total reward after 48123 steps is -29
# [75] [1, 99]
# total reward after 48124 steps is -99
# [51] [53]
# total reward after 48125 steps is -53
# [63] [33, 18, 31]
# total reward after 48126 steps is -31
# [99] [10, 86, 96]
# total reward after 48127 steps is -96
# [21] [98]
# total reward after 48128 steps is -98
# [22] [84]
# total reward after 48129 steps is -84
# [94] [35, 55, 94]
# total reward after 48130 steps is -94
# [37] [63]
# total reward after 48131 steps is -63
# [7] [83]
# total reward after 48132 steps is -83
# [61] [36, 61]
# total reward after 48133 steps is -61
# [59] [88]
# total reward after 48134 steps is -88
# [93] [5, 92]
# total reward after 48135 steps is -92
# [23] [54]
# total reward after 48136 steps is -54
# [21] [28]
# total reward after 48137 steps is -28
# [13] [89]
# total reward after 48138 steps is -89
# [46] [23, 34]
# total reward after 48139 steps is -34
# [19] [57]
# total reward after 48140 steps is -57
# [62] [17, 11, 97]
# total reward after 48141 steps is -97
# [50] [99]
# total reward after 48142 steps is -99
# [64] [6, 40, 31]
# total reward after 48143 steps is -31
# [17] [24]
# total reward after 48144 steps is -24
# [3] [35]
# total reward after 48145 steps is -35
# [14] [28]
# total reward after 48146 steps is -28
# [43] [1, 51]
# total reward after 48147 steps is -51
# [57] [95]
# total reward after 48148 steps is -95
# [93] [82, 20]
# total reward after 48149 steps is -20
# [70] [2, 67, 94]
# total reward after 48150 steps is -94
# [29] [49]
# total reward after 48151 steps is -49
# [74] [37, 99]
# total reward after 48152 steps is -99
# [43] [4, 85]
# total reward after 48153 steps is -85
# [41] [48]
# total reward after 48154 steps is -48
# [100] [7, 74, 22]
# total reward after 48155 steps is -22
# [60] [90]
# total reward after 48156 steps is -90
# [19] [99]
# total reward after 48157 steps is -99
# [35] [21, 70]
# total reward after 48158 steps is -70
# [45] [58]
# total reward after 48159 steps is -58
# [60] [12, 68]
# total reward after 48160 steps is -68
# [78] [100]
# total reward after 48161 steps is -100
# [44] [79]
# total reward after 48162 steps is -79
# [68] [88]
# total reward after 48163 steps is -88
# [71] [73]
# total reward after 48164 steps is -73
# [35] [90]
# total reward after 48165 steps is -90
# [83] [84]
# total reward after 48166 steps is -84
# [18] [53]
# total reward after 48167 steps is -53
# [17] [98]
# total reward after 48168 steps is -98
# [88] [87, 72]
# total reward after 48169 steps is -72
# [12] [78]
# total reward after 48170 steps is -78
# [32] [23, 41]
# total reward after 48171 steps is -41
# [84] [52, 21, 32]
# total reward after 48172 steps is -32
# [92] [32, 84]
# total reward after 48173 steps is -84
# [87] [34, 7, 37, 37]
# total reward after 48174 steps is -37
# [48] [18, 46]
# total reward after 48175 steps is -46
# [83] [95]
# total reward after 48176 steps is -95
# [75] [90]
# total reward after 48177 steps is -90
# [92] [97]
# total reward after 48178 steps is -97
# [98] [42, 7, 68]
# total reward after 48179 steps is -68
# [75] [20, 21, 4, 17, 69]
# total reward after 48180 steps is -69
# [66] [57, 72]
# total reward after 48181 steps is -72
# [50] [63]
# total reward after 48182 steps is -63
# [42] [28, 74]
# total reward after 48183 steps is -74
# [15] [35]
# total reward after 48184 steps is -35
# [85] [49, 57]
# total reward after 48185 steps is -57
# [32] [36]
# total reward after 48186 steps is -36
# [80] [42, 20, 54]
# total reward after 48187 steps is -54
# [98] [39, 28, 80]
# total reward after 48188 steps is -80
# [58] [84]
# total reward after 48189 steps is -84
# [46] [96]
# total reward after 48190 steps is -96
# [62] [30, 24, 25]
# total reward after 48191 steps is -25
# [27] [79]
# total reward after 48192 steps is -79
# [78] [62, 1, 8, 4, 25]
# total reward after 48193 steps is -25
# [36] [44]
# total reward after 48194 steps is -44
# [70] [36, 1, 56]
# total reward after 48195 steps is -56
# [4] [60]
# total reward after 48196 steps is -60
# [2] [36]
# total reward after 48197 steps is -36
# [70] [25, 62]
# total reward after 48198 steps is -62
# [31] [53]
# total reward after 48199 steps is -53
# [95] [32, 41, 93]
# total reward after 48200 steps is -93
# [41] [12, 26, 50]
# total reward after 48201 steps is -50
# [76] [17, 9, 80]
# total reward after 48202 steps is -80
# [9] [96]
# total reward after 48203 steps is -96
# [27] [93]
# total reward after 48204 steps is -93
# [98] [49, 56]
# total reward after 48205 steps is -56
# [59] [76]
# total reward after 48206 steps is -76
# [72] [47, 49]
# total reward after 48207 steps is -49
# [84] [21, 49, 10, 81]
# total reward after 48208 steps is -81
# [38] [53]
# total reward after 48209 steps is -53
# [92] [53, 45]
# total reward after 48210 steps is -45
# [55] [53, 39]
# total reward after 48211 steps is -39
# [86] [66, 5, 46]
# total reward after 48212 steps is -46
# [48] [13, 45]
# total reward after 48213 steps is -45
# [48] [18, 65]
# total reward after 48214 steps is -65
# [36] [41]
# total reward after 48215 steps is -41
# [85] [62, 9, 54]
# total reward after 48216 steps is -54
# [10] [36]
# total reward after 48217 steps is -36
# [5] [71]
# total reward after 48218 steps is -71
# [55] [94]
# total reward after 48219 steps is -94
# [12] [15]
# total reward after 48220 steps is -15
# [26] [38]
# total reward after 48221 steps is -38
# [86] [52, 48]
# total reward after 48222 steps is -48
# [46] [81]
# total reward after 48223 steps is -81
# [55] [79]
# total reward after 48224 steps is -79
# [36] [46]
# total reward after 48225 steps is -46
# [92] [8, 47, 31, 95]
# total reward after 48226 steps is -95
# [84] [1, 21, 98]
# total reward after 48227 steps is -98
# [28] [96]
# total reward after 48228 steps is -96
# [15] [14, 41]
# total reward after 48229 steps is -41
# [28] [43]
# total reward after 48230 steps is -43
# [87] [72, 12, 15]
# total reward after 48231 steps is -15
# [4] [92]
# total reward after 48232 steps is -92
# [83] [86]
# total reward after 48233 steps is -86
# [57] [9, 82]
# total reward after 48234 steps is -82
# [73] [36, 72]
# total reward after 48235 steps is -72
# [1] [65]
# total reward after 48236 steps is -65
# [98] [52, 23, 72]
# total reward after 48237 steps is -72
# [32] [53]
# total reward after 48238 steps is -53
# [97] [85, 7, 88]
# total reward after 48239 steps is -88
# [90] [69, 42]
# total reward after 48240 steps is -42
# [34] [77]
# total reward after 48241 steps is -77
# [36] [2, 83]
# total reward after 48242 steps is -83
# [4] [64]
# total reward after 48243 steps is -64
# [70] [12, 40, 49]
# total reward after 48244 steps is -49
# [83] [70, 98]
# total reward after 48245 steps is -98
# [23] [97]
# total reward after 48246 steps is -97
# [1] [73]
# total reward after 48247 steps is -73
# [19] [26]
# total reward after 48248 steps is -26
# [90] [64, 97]
# total reward after 48249 steps is -97
# [29] [81]
# total reward after 48250 steps is -81
# [75] [23, 93]
# total reward after 48251 steps is -93
# [61] [52, 41]
# total reward after 48252 steps is -41
# [41] [77]
# total reward after 48253 steps is -77
# [52] [75]
# total reward after 48254 steps is -75
# [14] [34]
# total reward after 48255 steps is -34
# [40] [87]
# total reward after 48256 steps is -87
# [90] [13, 50, 45]
# total reward after 48257 steps is -45
# [48] [57]
# total reward after 48258 steps is -57
# [77] [77]
# total reward after 48259 steps is 1000000
# [35] [75]
# total reward after 48260 steps is -75
# [70] [34, 5, 48]
# total reward after 48261 steps is -48
# [84] [8, 50, 81]
# total reward after 48262 steps is -81
# [83] [43, 88]
# total reward after 48263 steps is -88
# [35] [47]
# total reward after 48264 steps is -47
# [77] [70, 38]
# total reward after 48265 steps is -38
# [36] [62]
# total reward after 48266 steps is -62
# [77] [100]
# total reward after 48267 steps is -100
# [32] [11, 13, 5, 59]
# total reward after 48268 steps is -59
# [93] [9, 33, 13, 36, 58]
# total reward after 48269 steps is -58
# [26] [1, 70]
# total reward after 48270 steps is -70
# [82] [12, 28, 16, 2, 86]
# total reward after 48271 steps is -86
# [73] [70, 94]
# total reward after 48272 steps is -94
# [23] [99]
# total reward after 48273 steps is -99
# [68] [86]
# total reward after 48274 steps is -86
# [79] [79]
# total reward after 48275 steps is 1000000
# [34] [1, 35]
# total reward after 48276 steps is -35
# [59] [47, 63]
# total reward after 48277 steps is -63
# [38] [58]
# total reward after 48278 steps is -58
# [65] [19, 91]
# total reward after 48279 steps is -91
# [31] [13, 84]
# total reward after 48280 steps is -84
# [56] [64]
# total reward after 48281 steps is -64
# [79] [30, 55]
# total reward after 48282 steps is -55
# [33] [57]
# total reward after 48283 steps is -57
# [99] [47, 94]
# total reward after 48284 steps is -94
# [26] [56]
# total reward after 48285 steps is -56
# [10] [40]
# total reward after 48286 steps is -40
# [84] [99]
# total reward after 48287 steps is -99
# [14] [84]
# total reward after 48288 steps is -84
# [24] [60]
# total reward after 48289 steps is -60
# [30] [45]
# total reward after 48290 steps is -45
# [87] [38, 68]
# total reward after 48291 steps is -68
# [86] [51, 88]
# total reward after 48292 steps is -88
# [90] [49, 68]
# total reward after 48293 steps is -68
# [58] [73]
# total reward after 48294 steps is -73
# [86] [39, 32, 38]
# total reward after 48295 steps is -38
# [97] [26, 43, 62]
# total reward after 48296 steps is -62
# [48] [62]
# total reward after 48297 steps is -62
# [87] [99]
# total reward after 48298 steps is -99
# [36] [41]
# total reward after 48299 steps is -41
# [31] [65]
# total reward after 48300 steps is -65
# [90] [22, 95]
# total reward after 48301 steps is -95
# [73] [70, 2, 55]
# total reward after 48302 steps is -55
# [46] [12, 36]
# total reward after 48303 steps is -36
# [33] [87]
# total reward after 48304 steps is -87
# [9] [77]
# total reward after 48305 steps is -77
# [25] [23, 80]
# total reward after 48306 steps is -80
# [31] [10, 54]
# total reward after 48307 steps is -54
# [69] [99]
# total reward after 48308 steps is -99
# [20] [36]
# total reward after 48309 steps is -36
# [93] [68, 53]
# total reward after 48310 steps is -53
# [26] [46]
# total reward after 48311 steps is -46
# [74] [84]
# total reward after 48312 steps is -84
# [4] [47]
# total reward after 48313 steps is -47
# [35] [83]
# total reward after 48314 steps is -83
# [61] [3, 23, 3, 53]
# total reward after 48315 steps is -53
# [42] [63]
# total reward after 48316 steps is -63
# [4] [19]
# total reward after 48317 steps is -19
# [26] [53]
# total reward after 48318 steps is -53
# [94] [3, 2, 20, 24, 28]
# total reward after 48319 steps is 77
# [78] [59, 13, 70]
# total reward after 48320 steps is -70
# [70] [67, 22]
# total reward after 48321 steps is -22
# [77] [41, 77]
# total reward after 48322 steps is -77
# [36] [47]
# total reward after 48323 steps is -47
# [46] [18, 53]
# total reward after 48324 steps is -53
# [58] [87]
# total reward after 48325 steps is -87
# [25] [58]
# total reward after 48326 steps is -58
# [65] [78]
# total reward after 48327 steps is -78
# [86] [93]
# total reward after 48328 steps is -93
# [54] [11, 84]
# total reward after 48329 steps is -84
# [19] [44]
# total reward after 48330 steps is -44
# [54] [34, 36]
# total reward after 48331 steps is -36
# [38] [81]
# total reward after 48332 steps is -81
# [99] [45, 32, 12, 42]
# total reward after 48333 steps is -42
# [71] [19, 13, 11, 86]
# total reward after 48334 steps is -86
# [9] [11]
# total reward after 48335 steps is -11
# [53] [58]
# total reward after 48336 steps is -58
# [85] [26, 35, 35]
# total reward after 48337 steps is -35
# [35] [90]
# total reward after 48338 steps is -90
# [82] [24, 26, 38]
# total reward after 48339 steps is -38
# [75] [17, 22, 89]
# total reward after 48340 steps is -89
# [9] [42]
# total reward after 48341 steps is -42
# [27] [72]
# total reward after 48342 steps is -72
# [17] [80]
# total reward after 48343 steps is -80
# [78] [82]
# total reward after 48344 steps is -82
# [64] [16, 99]
# total reward after 48345 steps is -99
# [61] [10, 37, 4, 43]
# total reward after 48346 steps is -43
# [86] [44, 38, 10]
# total reward after 48347 steps is -10
# [92] [65, 13, 65]
# total reward after 48348 steps is -65
# [23] [55]
# total reward after 48349 steps is -55
# [16] [19]
# total reward after 48350 steps is -19
# [67] [52, 5, 18]
# total reward after 48351 steps is -18
# [25] [48]
# total reward after 48352 steps is -48
# [8] [32]
# total reward after 48353 steps is -32
# [80] [81]
# total reward after 48354 steps is -81
# [45] [57]
# total reward after 48355 steps is -57
# [16] [96]
# total reward after 48356 steps is -96
# [10] [6, 82]
# total reward after 48357 steps is -82
# [7] [12]
# total reward after 48358 steps is -12
# [54] [97]
# total reward after 48359 steps is -97
# [6] [44]
# total reward after 48360 steps is -44
# [53] [13, 27, 60]
# total reward after 48361 steps is -60
# [98] [91, 99]
# total reward after 48362 steps is -99
# [72] [85]
# total reward after 48363 steps is -85
# [57] [32, 72]
# total reward after 48364 steps is -72
# [85] [53, 30, 22]
# total reward after 48365 steps is -22
# [36] [31, 22]
# total reward after 48366 steps is -22
# [27] [78]
# total reward after 48367 steps is -78
# [29] [65]
# total reward after 48368 steps is -65
# [73] [100]
# total reward after 48369 steps is -100
# [71] [70, 51]
# total reward after 48370 steps is -51
# [56] [87]
# total reward after 48371 steps is -87
# [95] [44, 97]
# total reward after 48372 steps is -97
# [54] [64]
# total reward after 48373 steps is -64
# [68] [69]
# total reward after 48374 steps is -69
# [92] [95]
# total reward after 48375 steps is -95
# [32] [19, 37]
# total reward after 48376 steps is -37
# [53] [31, 43]
# total reward after 48377 steps is -43
# [77] [72, 88]
# total reward after 48378 steps is -88
# [70] [99]
# total reward after 48379 steps is -99
# [47] [11, 68]
# total reward after 48380 steps is -68
# [47] [99]
# total reward after 48381 steps is -99
# [75] [67, 5, 97]
# total reward after 48382 steps is -97
# [60] [16, 68]
# total reward after 48383 steps is -68
# [48] [57]
# total reward after 48384 steps is -57
# [93] [66, 69]
# total reward after 48385 steps is -69
# [68] [36, 58]
# total reward after 48386 steps is -58
# [19] [38]
# total reward after 48387 steps is -38
# [94] [75, 51]
# total reward after 48388 steps is -51
# [3] [23]
# total reward after 48389 steps is -23
# [63] [75]
# total reward after 48390 steps is -75
# [52] [6, 4, 70]
# total reward after 48391 steps is -70
# [71] [35, 74]
# total reward after 48392 steps is -74
# [15] [40]
# total reward after 48393 steps is -40
# [54] [90]
# total reward after 48394 steps is -90
# [53] [37, 48]
# total reward after 48395 steps is -48
# [37] [84]
# total reward after 48396 steps is -84
# [55] [52, 16]
# total reward after 48397 steps is -16
# [54] [57]
# total reward after 48398 steps is -57
# [4] [24]
# total reward after 48399 steps is -24
# [19] [64]
# total reward after 48400 steps is -64
# [3] [36]
# total reward after 48401 steps is -36
# [98] [79, 77]
# total reward after 48402 steps is -77
# [6] [89]
# total reward after 48403 steps is -89
# [45] [90]
# total reward after 48404 steps is -90
# [3] [35]
# total reward after 48405 steps is -35
# [57] [43, 93]
# total reward after 48406 steps is -93
# [19] [7, 40]
# total reward after 48407 steps is -40
# [50] [55]
# total reward after 48408 steps is -55
# [56] [89]
# total reward after 48409 steps is -89
# [37] [41]
# total reward after 48410 steps is -41
# [93] [34, 53, 6]
# total reward after 48411 steps is 10087
# [41] [100]
# total reward after 48412 steps is -100
# [50] [42, 78]
# total reward after 48413 steps is -78
# [69] [31, 31, 74]
# total reward after 48414 steps is -74
# [40] [64]
# total reward after 48415 steps is -64
# [76] [73, 45]
# total reward after 48416 steps is -45
# [14] [32]
# total reward after 48417 steps is -32
# [69] [39, 40]
# total reward after 48418 steps is -40
# [82] [39, 20, 88]
# total reward after 48419 steps is -88
# [34] [16, 63]
# total reward after 48420 steps is -63
# [87] [48, 88]
# total reward after 48421 steps is -88
# [16] [48]
# total reward after 48422 steps is -48
# [54] [31, 49]
# total reward after 48423 steps is -49
# [40] [61]
# total reward after 48424 steps is -61
# [62] [33, 43]
# total reward after 48425 steps is -43
# [36] [20, 100]
# total reward after 48426 steps is -100
# [10] [96]
# total reward after 48427 steps is -96
# [67] [40, 9, 83]
# total reward after 48428 steps is -83
# [42] [18, 11, 54]
# total reward after 48429 steps is -54
# [35] [2, 17, 85]
# total reward after 48430 steps is -85
# [2] [51]
# total reward after 48431 steps is -51
# [59] [34, 13, 56]
# total reward after 48432 steps is -56
# [36] [48]
# total reward after 48433 steps is -48
# [70] [26, 11, 51]
# total reward after 48434 steps is -51
# [92] [83, 51]
# total reward after 48435 steps is -51
# [98] [96, 19]
# total reward after 48436 steps is -19
# [35] [44]
# total reward after 48437 steps is -44
# [35] [100]
# total reward after 48438 steps is -100
# [12] [48]
# total reward after 48439 steps is -48
# [41] [64]
# total reward after 48440 steps is -64
# [2] [48]
# total reward after 48441 steps is -48
# [2] [45]
# total reward after 48442 steps is -45
# [58] [39, 1, 20]
# total reward after 48443 steps is -20
# [100] [95, 16]
# total reward after 48444 steps is -16
# [42] [76]
# total reward after 48445 steps is -76
# [60] [29, 19, 36]
# ...
# total reward after 49683 steps is -54
# [43] [67]
# total reward after 49684 steps is -67
# [6] [32]
# total reward after 49685 steps is -32
# [5] [99]
# total reward after 49686 steps is -99
# [75] [71, 23]
# total reward after 49687 steps is -23
# [68] [79]
# total reward after 49688 steps is -79
# [63] [75]
# total reward after 49689 steps is -75
# [50] [37, 56]
# total reward after 49690 steps is -56
# [18] [6, 32]
# total reward after 49691 steps is -32
# [26] [84]
# total reward after 49692 steps is -84
# [90] [91]
# total reward after 49693 steps is -91
# [91] [74, 40]
# total reward after 49694 steps is -40
# [21] [25]
# total reward after 49695 steps is -25
# [10] [88]
# total reward after 49696 steps is -88
# [60] [90]
# total reward after 49697 steps is -90
# [82] [37, 19, 39]
# total reward after 49698 steps is -39
# [1] [31]
# total reward after 49699 steps is -31
# [7] [4, 95]
# total reward after 49700 steps is -95
# [11] [26]
# total reward after 49701 steps is -26
# [93] [82, 4, 47]
# total reward after 49702 steps is -47
# [11] [51]
# total reward after 49703 steps is -51
# [57] [27, 33]
# total reward after 49704 steps is -33
# [49] [13, 99]
# total reward after 49705 steps is -99
# [11] [41]
# total reward after 49706 steps is -41
# [44] [7, 24, 27]
# total reward after 49707 steps is -27
# [66] [16, 12, 74]
# total reward after 49708 steps is -74
# [40] [70]
# total reward after 49709 steps is -70
# [96] [8, 31, 91]
# total reward after 49710 steps is -91
# [15] [35]
# total reward after 49711 steps is -35
# [60] [82]
# total reward after 49712 steps is -82
# [60] [76]
# total reward after 49713 steps is -76
# [51] [71]
# total reward after 49714 steps is -71
# [98] [56, 77]
# total reward after 49715 steps is -77
# [4] [54]
# total reward after 49716 steps is -54
# [76] [88]
# total reward after 49717 steps is -88
# [81] [17, 95]
# total reward after 49718 steps is -95
# [81] [87]
# total reward after 49719 steps is -87
# [70] [24, 59]
# total reward after 49720 steps is -59
# [11] [81]
# total reward after 49721 steps is -81
# [16] [7, 94]
# total reward after 49722 steps is -94
# [5] [1, 80]
# total reward after 49723 steps is -80
# [28] [83]
# total reward after 49724 steps is -83
# [29] [17, 47]
# total reward after 49725 steps is -47
# [75] [63, 12]
# total reward after 49726 steps is 100063
# [61] [79]
# total reward after 49727 steps is -79
# [46] [67]
# total reward after 49728 steps is -67
# [68] [73]
# total reward after 49729 steps is -73
# [13] [13]
# total reward after 49730 steps is 1000000
# [13] [51]
# total reward after 49731 steps is -51
# [33] [31, 71]
# total reward after 49732 steps is -71
# [39] [1, 86]
# total reward after 49733 steps is -86
# [14] [70]
# total reward after 49734 steps is -70
# [22] [75]
# total reward after 49735 steps is -75
# [31] [73]
# total reward after 49736 steps is -73
# [93] [69, 95]
# total reward after 49737 steps is -95
# [99] [65, 54]
# total reward after 49738 steps is -54
# [13] [5, 22]
# total reward after 49739 steps is -22
# [15] [49]
# total reward after 49740 steps is -49
# [24] [42]
# total reward after 49741 steps is -42
# [1] [56]
# total reward after 49742 steps is -56
# [46] [2, 20, 69]
# total reward after 49743 steps is -69
# [42] [58]
# total reward after 49744 steps is -58
# [73] [4, 5, 2, 77]
# total reward after 49745 steps is -77
# [61] [81]
# total reward after 49746 steps is -81
# [66] [58, 31]
# total reward after 49747 steps is -31
# [5] [31]
# total reward after 49748 steps is -31
# [84] [69, 62]
# total reward after 49749 steps is -62
# [14] [21]
# total reward after 49750 steps is -21
# [14] [28]
# total reward after 49751 steps is -28
# [37] [66]
# total reward after 49752 steps is -66
# [65] [30, 78]
# total reward after 49753 steps is -78
# [90] [11, 5, 99]
# total reward after 49754 steps is -99
# [29] [43]
# total reward after 49755 steps is -43
# [89] [11, 19, 14, 94]
# total reward after 49756 steps is -94
# [4] [77]
# total reward after 49757 steps is -77
# [94] [29, 1, 99]
# total reward after 49758 steps is -99
# [65] [40, 38]
# total reward after 49759 steps is -38
# [23] [7, 83]
# total reward after 49760 steps is -83
# [44] [55]
# total reward after 49761 steps is -55
# [68] [64, 78]
# total reward after 49762 steps is -78
# [34] [80]
# total reward after 49763 steps is -80
# [82] [62, 51]
# total reward after 49764 steps is -51
# [71] [91]
# total reward after 49765 steps is -91
# [54] [35, 76]
# total reward after 49766 steps is -76
# [86] [9, 50, 48]
# total reward after 49767 steps is -48
# [67] [10, 50, 67]
# total reward after 49768 steps is -67
# [65] [28, 48]
# total reward after 49769 steps is -48
# [46] [36, 8, 16]
# total reward after 49770 steps is -16
# [49] [28, 32]
# total reward after 49771 steps is -32
# [22] [64]
# total reward after 49772 steps is -64
# [6] [27]
# total reward after 49773 steps is -27
# [10] [6, 89]
# total reward after 49774 steps is -89
# [8] [61]
# total reward after 49775 steps is -61
# [12] [8, 54]
# total reward after 49776 steps is -54
# [77] [3, 36, 32, 25]
# total reward after 49777 steps is -25
# [62] [35, 55]
# total reward after 49778 steps is -55
# [90] [100]
# total reward after 49779 steps is -100
# [17] [47]
# total reward after 49780 steps is -47
# [95] [97]
# total reward after 49781 steps is -97
# [82] [65, 57]
# total reward after 49782 steps is -57
# [39] [10, 14, 9, 53]
# total reward after 49783 steps is -53
# [6] [85]
# total reward after 49784 steps is -85
# [65] [25, 83]
# total reward after 49785 steps is -83
# [24] [61]
# total reward after 49786 steps is -61
# [93] [87, 79]
# total reward after 49787 steps is -79
# [56] [31, 15, 58]
# total reward after 49788 steps is -58
# [41] [66]
# total reward after 49789 steps is -66
# [63] [4, 71]
# total reward after 49790 steps is -71
# [91] [12, 24, 22, 38]
# total reward after 49791 steps is -38
# [80] [57, 73]
# total reward after 49792 steps is -73
# [6] [71]
# total reward after 49793 steps is -71
# [27] [27]
# total reward after 49794 steps is 1000000
# [65] [35, 52]
# total reward after 49795 steps is -52
# [52] [79]
# total reward after 49796 steps is -79
# [90] [68, 98]
# total reward after 49797 steps is -98
# [79] [99]
# total reward after 49798 steps is -99
# [38] [23, 72]
# total reward after 49799 steps is -72
# [4] [11]
# total reward after 49800 steps is -11
# [91] [99]
# total reward after 49801 steps is -99
# [32] [58]
# total reward after 49802 steps is -58
# [91] [20, 97]
# total reward after 49803 steps is -97
# [60] [97]
# total reward after 49804 steps is -97
# [26] [22, 59]
# total reward after 49805 steps is -59
# [58] [46, 22]
# total reward after 49806 steps is -22
# [39] [69]
# total reward after 49807 steps is -69
# [70] [91]
# total reward after 49808 steps is -91
# [6] [88]
# total reward after 49809 steps is -88
# [12] [70]
# total reward after 49810 steps is -70
# [75] [26, 34, 4, 17]
# total reward after 49811 steps is -17
# [75] [96]
# total reward after 49812 steps is -96
# [37] [9, 42]
# total reward after 49813 steps is -42
# [18] [99]
# total reward after 49814 steps is -99
# [39] [71]
# total reward after 49815 steps is -71
# [55] [1, 24, 18, 78]
# total reward after 49816 steps is -78
# [89] [27, 83]
# total reward after 49817 steps is -83
# [97] [29, 30, 67]
# total reward after 49818 steps is -67
# [35] [98]
# total reward after 49819 steps is -98
# [25] [87]
# total reward after 49820 steps is -87
# [18] [72]
# total reward after 49821 steps is -72
# [62] [73]
# total reward after 49822 steps is -73
# [88] [97]
# total reward after 49823 steps is -97
# [67] [6, 76]
# total reward after 49824 steps is -76
# [56] [87]
# total reward after 49825 steps is -87
# [42] [13, 71]
# total reward after 49826 steps is -71
# [12] [78]
# total reward after 49827 steps is -78
# [33] [73]
# total reward after 49828 steps is -73
# [78] [82]
# total reward after 49829 steps is -82
# [49] [73]
# total reward after 49830 steps is -73
# [70] [92]
# total reward after 49831 steps is -92
# [7] [36]
# total reward after 49832 steps is -36
# [8] [10]
# total reward after 49833 steps is -10
# [50] [32, 17, 33]
# total reward after 49834 steps is -33
# [16] [20]
# total reward after 49835 steps is -20
# [29] [96]
# total reward after 49836 steps is -96
# [36] [81]
# total reward after 49837 steps is -81
# [9] [92]
# total reward after 49838 steps is -92
# [82] [80, 54]
# total reward after 49839 steps is -54
# [78] [29, 33, 4, 59]
# total reward after 49840 steps is -59
# [45] [60]
# total reward after 49841 steps is -60
# [79] [76, 23]
# total reward after 49842 steps is -23
# [91] [18, 73]
# total reward after 49843 steps is 100018
# [9] [59]
# total reward after 49844 steps is -59
# [98] [67, 89]
# total reward after 49845 steps is -89
# [1] [12]
# total reward after 49846 steps is -12
# [26] [42]
# total reward after 49847 steps is -42
# [43] [98]
# total reward after 49848 steps is -98
# [29] [32]
# total reward after 49849 steps is -32
# [62] [73]
# total reward after 49850 steps is -73
# [24] [41]
# total reward after 49851 steps is -41
# [57] [83]
# total reward after 49852 steps is -83
# [13] [33]
# total reward after 49853 steps is -33
# [33] [9, 52]
# total reward after 49854 steps is -52
# [76] [96]
# total reward after 49855 steps is -96
# [33] [92]
# total reward after 49856 steps is -92
# [83] [43, 83]
# total reward after 49857 steps is -83
# [23] [53]
# total reward after 49858 steps is -53
# [77] [60, 79]
# total reward after 49859 steps is -79
# [9] [25]
# total reward after 49860 steps is -25
# [83] [33, 5, 94]
# total reward after 49861 steps is -94
# [10] [49]
# total reward after 49862 steps is -49
# [100] [48, 81]
# total reward after 49863 steps is -81
# [59] [51, 70]
# total reward after 49864 steps is -70
# [53] [43, 36]
# total reward after 49865 steps is -36
# [95] [10, 15, 31, 34, 77]
# total reward after 49866 steps is -77
# [82] [80, 28]
# total reward after 49867 steps is -28
# [74] [13, 23, 66]
# total reward after 49868 steps is -66
# [44] [48]
# total reward after 49869 steps is -48
# [18] [54]
# total reward after 49870 steps is -54
# [83] [27, 92]
# total reward after 49871 steps is -92
# [76] [41, 36]
# total reward after 49872 steps is -36
# [10] [66]
# total reward after 49873 steps is -66
# [29] [96]
# total reward after 49874 steps is -96
# [19] [44]
# total reward after 49875 steps is -44
# [25] [63]
# total reward after 49876 steps is -63
# [22] [47]
# total reward after 49877 steps is -47
# [11] [52]
# total reward after 49878 steps is -52
# [67] [97]
# total reward after 49879 steps is -97
# [12] [38]
# total reward after 49880 steps is -38
# [45] [90]
# total reward after 49881 steps is -90
# [58] [61]
# total reward after 49882 steps is -61
# [75] [100]
# total reward after 49883 steps is -100
# [61] [58, 13]
# total reward after 49884 steps is -13
# [37] [98]
# total reward after 49885 steps is -98
# [41] [2, 12, 74]
# total reward after 49886 steps is -74
# [100] [30, 82]
# total reward after 49887 steps is -82
# [62] [43, 75]
# total reward after 49888 steps is -75
# [69] [66, 91]
# total reward after 49889 steps is -91
# [56] [10, 6, 45]
# total reward after 49890 steps is -45
# [8] [22]
# total reward after 49891 steps is -22
# [64] [44, 20]
# total reward after 49892 steps is 100044
# [15] [66]
# total reward after 49893 steps is -66
# [34] [96]
# total reward after 49894 steps is -96
# [39] [65]
# total reward after 49895 steps is -65
# [3] [7]
# total reward after 49896 steps is -7
# [79] [13, 67]
# total reward after 49897 steps is -67
# [45] [48]
# total reward after 49898 steps is -48
# [75] [35, 52]
# total reward after 49899 steps is -52
# [69] [29, 9, 10, 19, 45]
# total reward after 49900 steps is -45
# [96] [69, 86]
# total reward after 49901 steps is -86
# [11] [100]
# total reward after 49902 steps is -100
# [84] [99]
# total reward after 49903 steps is -99
# [82] [88]
# total reward after 49904 steps is -88
# [42] [14, 43]
# total reward after 49905 steps is -43
# [71] [20, 83]
# total reward after 49906 steps is -83
# [27] [18, 68]
# total reward after 49907 steps is -68
# [68] [43, 1, 39]
# total reward after 49908 steps is -39
# [57] [44, 60]
# total reward after 49909 steps is -60
# [80] [39, 21, 77]
# total reward after 49910 steps is -77
# [88] [94]
# total reward after 49911 steps is -94
# [17] [81]
# total reward after 49912 steps is -81
# [6] [81]
# total reward after 49913 steps is -81
# [80] [48, 38]
# total reward after 49914 steps is -38
# [27] [10, 98]
# total reward after 49915 steps is -98
# [74] [86]
# total reward after 49916 steps is -86
# [18] [26]
# total reward after 49917 steps is -26
# [1] [37]
# total reward after 49918 steps is -37
# [47] [95]
# total reward after 49919 steps is -95
# [64] [33, 55]
# total reward after 49920 steps is -55
# [61] [19, 78]
# total reward after 49921 steps is -78
# [70] [13, 32, 86]
# total reward after 49922 steps is -86
# [10] [4, 77]
# total reward after 49923 steps is -77
# [71] [8, 33, 89]
# total reward after 49924 steps is -89
# [69] [72]
# total reward after 49925 steps is -72
# [35] [74]
# total reward after 49926 steps is -74
# [15] [72]
# total reward after 49927 steps is -72
# [19] [6, 56]
# total reward after 49928 steps is -56
# [35] [54]
# total reward after 49929 steps is -54
# [11] [48]
# total reward after 49930 steps is -48
# [23] [92]
# total reward after 49931 steps is -92
# [81] [36, 14, 14, 23]
# total reward after 49932 steps is -23
# [2] [19]
# total reward after 49933 steps is -19
# [41] [66]
# total reward after 49934 steps is -66
# [87] [99]
# total reward after 49935 steps is -99
# [21] [86]
# total reward after 49936 steps is -86
# [24] [52]
# total reward after 49937 steps is -52
# [21] [51]
# total reward after 49938 steps is -51
# [16] [79]
# total reward after 49939 steps is -79
# [45] [27, 83]
# total reward after 49940 steps is -83
# [80] [10, 11, 45, 25]
# total reward after 49941 steps is -25
# [61] [78]
# total reward after 49942 steps is -78
# [5] [33]
# total reward after 49943 steps is -33
# [36] [38]
# total reward after 49944 steps is -38
# [61] [71]
# total reward after 49945 steps is -71
# [34] [49]
# total reward after 49946 steps is -49
# [18] [98]
# total reward after 49947 steps is -98
# [64] [13, 29, 50]
# total reward after 49948 steps is -50
# [78] [24, 87]
# total reward after 49949 steps is -87
# [74] [24, 44, 1, 43]
# total reward after 49950 steps is -43
# [96] [9, 43, 30, 30]
# total reward after 49951 steps is -30
# [99] [92, 32]
# total reward after 49952 steps is -32
# [55] [79]
# total reward after 49953 steps is -79
# [93] [36, 54, 9]
# total reward after 49954 steps is -9
# [73] [37, 44]
# total reward after 49955 steps is -44
# [73] [20, 69]
# total reward after 49956 steps is -69
# [42] [77]
# total reward after 49957 steps is -77
# [93] [64, 76]
# total reward after 49958 steps is -76
# [35] [36]
# total reward after 49959 steps is -36
# [36] [100]
# total reward after 49960 steps is -100
# [64] [52, 46]
# total reward after 49961 steps is -46
# [73] [76]
# total reward after 49962 steps is -76
# [16] [1, 7, 78]
# total reward after 49963 steps is -78
# [3] [37]
# total reward after 49964 steps is -37
# [93] [75, 15, 2, 76]
# total reward after 49965 steps is -76
# [73] [13, 95]
# total reward after 49966 steps is -95
# [63] [91]
# total reward after 49967 steps is -91
# [66] [32, 92]
# total reward after 49968 steps is -92
# [10] [71]
# total reward after 49969 steps is -71
# [35] [32, 23]
# total reward after 49970 steps is -23
# [71] [94]
# total reward after 49971 steps is -94
# [25] [1, 16, 71]
# total reward after 49972 steps is -71
# [40] [40]
# total reward after 49973 steps is 1000000
# [11] [26]
# total reward after 49974 steps is -26
# [86] [33, 30, 73]
# total reward after 49975 steps is -73
# [24] [100]
# total reward after 49976 steps is -100
# [90] [76, 74]
# total reward after 49977 steps is -74
# [25] [42]
# total reward after 49978 steps is -42
# [88] [30, 38, 65]
# total reward after 49979 steps is -65
# [5] [100]
# total reward after 49980 steps is -100
# [65] [67]
# total reward after 49981 steps is -67
# [79] [60, 84]
# total reward after 49982 steps is -84
# [63] [54, 80]
# total reward after 49983 steps is -80
# [70] [21, 21, 12, 20]
# total reward after 49984 steps is -20
# [21] [3, 25]
# total reward after 49985 steps is -25
# [99] [91, 33]
# total reward after 49986 steps is -33
# [52] [42, 44]
# total reward after 49987 steps is -44
# [6] [6]
# total reward after 49988 steps is 1000000
# [92] [5, 69, 32]
# total reward after 49989 steps is -32
# [12] [14]
# total reward after 49990 steps is -14
# [85] [96]
# total reward after 49991 steps is -96
# [67] [43, 58]
# total reward after 49992 steps is -58
# [86] [75, 33]
# total reward after 49993 steps is -33
# [53] [21, 74]
# total reward after 49994 steps is -74
# [48] [45, 67]
# total reward after 49995 steps is -67
# [49] [97]
# total reward after 49996 steps is -97
# [16] [62]
# total reward after 49997 steps is -62
# [56] [75]
# total reward after 49998 steps is -75
# [51] [13, 11, 50]
# total reward after 49999 steps is -50
