# %% [markdown]
# <a href="https://colab.research.google.com/github/hallpaz/drl/blob/main/notebooks/actor_critic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# O objetivo deste projeto é implementar um ambiente de simulação no framework Gym para resolver um problema específico. Neste problema, há uma coluna denominada "Random" contendo 50 posições, cada uma com um valor aleatório entre 1 e 100 (distribuição uniforme). Além disso, há um campo chamado "Target" que recebe um valor aleatório entre 1 e 100 (distribuição uniforme).

# %% [markdown]
# A missão do agente é selecionar até 5 posições da coluna "Random", uma de cada vez, de modo que a soma dos valores dessas 5 posições alcance o valor do campo "Target", indicando o fim do episódio.

# %%
# !pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)

# %% [markdown]
# É importante destacar que o agente só pode "olhar" para uma posição de cada vez da coluna "Random".
#
# Um episódio é finalizado se a soma de target foi satisfeita ou todas os valores na coluna Random foram vistos ao menos 1 vez.
#
# Implementação:
# 1 - Criação do Ambiente de simulação utilizando o framework Gym.
# 2 - Definição inicial dos hiperparâmetros.
# 3 - Arquitetura da Rede Neural com Tensorflow.
# 4 - Treinamento do Agente.
# 5 - Teste e Demonstração do Agente Maduro.

# %%
import gymnasium as gym
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp

# %%
COMBINE = 1
DONT_COMBINE = 0

# %%
class MatchingEnv(gym.Env):
  def __init__(self, options_size=50, target_size=1, options_limit=5):
    self.options_size = options_size
    self.target_size = target_size
    self.options_limit = options_limit
    self.action_space = [0, 1]

    self.reset()

  def reset(self):
    self.options = np.random.randint(1, 101, self.options_size)
    self.target = np.random.randint(1, 101, self.target_size)
    self.current_option_index = 0
    self.current_target_index = 0
    self.selected = []

    return (self.options[self.current_option_index],
            self.target[self.current_target_index],
            self.options_size - 1,
            len(self.selected))

  def step(self, action):
    done = False
    reward = 0
    if action == COMBINE:
      current_value = self.options[self.current_option_index]
      self.selected.append(current_value)
      # avança para o próximo valor
      self.current_option_index += 1
      # calcula o quanto falta em relação ao target
      # self.target[self.current_target_index] -= current_value
      remaining_value = self.target[self.current_target_index] - sum(self.selected)
      # quantos passos ainda faltam
      remaining_steps = self.options_size - self.current_option_index - 1

      if remaining_value > 0:
        reward = current_value
      elif remaining_value == 0:
        reward = 100 * 10**(self.options_limit - len(self.selected))
        done = True
      else:
        reward = -sum(self.selected)
        done = True

    else:
      self.current_option_index += 1
      # calcula o quanto falta em relação ao target
      remaining_value = self.target[self.current_target_index] - sum(self.selected)
      # quantos passos ainda faltam
      remaining_steps = self.options_size - self.current_option_index - 1

    if remaining_steps < 0 and not self.selected:
      reward = -100

    if remaining_steps < 0 or len(self.selected) >= self.options_limit or reward < 0:
      done = True

    next_state = (self.options[self.current_option_index % self.options_size],
                remaining_value,
                remaining_steps,
                len(self.selected))
    print(next_state)
    return next_state, reward, done, {}

# %%
env = MatchingEnv()

# %% [markdown]
# A cada seleção que o agente aposta em fazer, as posições da coluna "Random" são sorteadas novamente, exceto aquelas que foram previamente escolhidas pelo agente.

# %%
class critic(tf.keras.Model):
  def __init__(self):
    super().__init__()
    self.d1 = tf.keras.layers.Dense(1024,activation='relu')
    self.d2 = tf.keras.layers.Dense(512,activation='relu')
    self.v = tf.keras.layers.Dense(1, activation = None)

  def call(self, input_data):
    x = self.d1(input_data)
    x = self.d2(x)
    v = self.v(x)
    return v


class actor(tf.keras.Model):
  def __init__(self):
    super().__init__()
    self.d1 = tf.keras.layers.Dense(1024,activation='relu')
    self.d2 = tf.keras.layers.Dense(512,activation='relu')
    self.a = tf.keras.layers.Dense(2, activation='softmax')

  def call(self, input_data):
    x = self.d1(input_data)
    x = self.d2(x)
    a = self.a(x)
    return a

# %%
class Agent():
    def __init__(self, gamma = 0.99):
        self.gamma = gamma
        self.a_opt = tf.keras.optimizers.Adam(learning_rate=5e-6)
        self.c_opt = tf.keras.optimizers.Adam(learning_rate=5e-6)
        self.actor = actor()
        self.critic = critic()
        self.log_prob = None

    def act(self,state):
        prob = self.actor(np.array([state]))
        prob = prob.numpy()
        dist = tfp.distributions.Categorical(probs=prob, dtype=tf.float32)
        action = dist.sample()
        return int(action.numpy()[0])

    def actor_loss(self, prob, action, td):
        dist = tfp.distributions.Categorical(probs=prob, dtype=tf.float32)
        log_prob = dist.log_prob(action)
        loss = -log_prob*td
        return loss


    def learn(self, state, action, reward, next_state, done):
        state = np.array([state])
        next_state = np.array([next_state])

        with tf.GradientTape() as tape1, tf.GradientTape() as tape2:
            p = self.actor(state, training=True)

            v =  self.critic(state,training=True)
            vn = self.critic(next_state, training=True)
            td = reward + self.gamma*vn*(1-int(done)) - v
            a_loss = self.actor_loss(p, action, td)
            c_loss = td**2
        grads1 = tape1.gradient(a_loss, self.actor.trainable_variables)
        grads2 = tape2.gradient(c_loss, self.critic.trainable_variables)
        self.a_opt.apply_gradients(zip(grads1, self.actor.trainable_variables))
        self.c_opt.apply_gradients(zip(grads2, self.critic.trainable_variables))
        return a_loss, c_loss

# %%
agent = Agent()
steps = 10000

# %%
for s in range(steps):
  done = False
  state = env.reset()
  total_reward = 0
  all_aloss = []
  all_closs = []

  while not done:
    action = agent.act(state)
    next_state, reward, done, _ = env.step(action)
    aloss, closs = agent.learn(state, action, reward, next_state, done)
    all_aloss.append(aloss)
    all_closs.append(closs)
    state = next_state
    total_reward += reward

    if done:
      print(f"Selected: {env.selected}, for target: {env.target[0]}")
      print("total reward after {} steps is {}".format(s, total_reward))
# Out:
# Streaming output truncated to the last 5000 lines.
# (70, 4, 36, 1)
# (88, 4, 35, 1)
# (17, 4, 34, 1)
# (65, 4, 33, 1)
# (57, 4, 32, 1)
# (19, 4, 31, 1)
# (31, 4, 30, 1)
# (30, 4, 29, 1)
# (49, 4, 28, 1)
# (46, 4, 27, 1)
# (12, 4, 26, 1)
# (57, 4, 25, 1)
# (36, 4, 24, 1)
# (94, 4, 23, 1)
# (73, 4, 22, 1)
# (81, 4, 21, 1)
# (17, 4, 20, 1)
# (51, 4, 19, 1)
# (46, 4, 18, 1)
# (60, 4, 17, 1)
# (76, 4, 16, 1)
# (76, 4, 15, 1)
# (73, 4, 14, 1)
# (85, 4, 13, 1)
# (26, 4, 12, 1)
# (53, 4, 11, 1)
# (18, 4, 10, 1)
# (94, 4, 9, 1)
# (24, 4, 8, 1)
# (60, 4, 7, 1)
# (93, 4, 6, 1)
# (68, 4, 5, 1)
# (31, 4, 4, 1)
# (86, 4, 3, 1)
# (81, 4, 2, 1)
# (44, 4, 1, 1)
# (40, 4, 0, 1)
# (69, 4, -1, 1)
# Selected: [6], for target: 10
# total reward after 5847 steps is 6
# (76, 18, 48, 1)
# (83, 18, 47, 1)
# (63, 18, 46, 1)
# (54, 18, 45, 1)
# (13, 18, 44, 1)
# (7, 5, 43, 2)
# (49, -2, 42, 3)
# Selected: [71, 13, 7], for target: 89
# total reward after 5848 steps is -7
# (40, 46, 48, 1)
# (49, 6, 47, 2)
# (41, 6, 46, 2)
# (8, 6, 45, 2)
# (54, -2, 44, 3)
# Selected: [31, 40, 8], for target: 77
# total reward after 5849 steps is -8
# (73, 34, 48, 0)
# (28, 34, 47, 0)
# (51, 6, 46, 1)
# (80, 6, 45, 1)
# (51, 6, 44, 1)
# (47, 6, 43, 1)
# (4, 6, 42, 1)
# (24, 2, 41, 2)
# (48, 2, 40, 2)
# (9, 2, 39, 2)
# (96, 2, 38, 2)
# (72, 2, 37, 2)
# (23, 2, 36, 2)
# (23, 2, 35, 2)
# (87, 2, 34, 2)
# (21, 2, 33, 2)
# (65, 2, 32, 2)
# (52, 2, 31, 2)
# (4, 2, 30, 2)
# (71, -2, 29, 3)
# Selected: [28, 4, 4], for target: 34
# total reward after 5850 steps is -4
# (5, -1, 48, 1)
# Selected: [88], for target: 87
# total reward after 5851 steps is -88
# (60, 4, 48, 1)
# (92, 4, 47, 1)
# (35, 4, 46, 1)
# (94, 4, 45, 1)
# (54, 4, 44, 1)
# (54, 4, 43, 1)
# (61, 4, 42, 1)
# (25, 4, 41, 1)
# (21, 4, 40, 1)
# (12, 4, 39, 1)
# (60, 4, 38, 1)
# (44, 4, 37, 1)
# (43, 4, 36, 1)
# (96, 4, 35, 1)
# (5, 4, 34, 1)
# (22, -1, 33, 2)
# Selected: [5, 5], for target: 9
# total reward after 5852 steps is -5
# (19, 33, 48, 1)
# (12, 14, 47, 2)
# (4, 2, 46, 3)
# (25, -2, 45, 4)
# Selected: [38, 19, 12, 4], for target: 71
# total reward after 5853 steps is -4
# (68, 51, 48, 1)
# (64, 51, 47, 1)
# (57, 51, 46, 1)
# (4, -6, 45, 2)
# Selected: [5, 57], for target: 56
# total reward after 5854 steps is -57
# (2, 0, 48, 1)
# Selected: [85], for target: 85
# total reward after 5855 steps is 1000000
# (61, 61, 48, 0)
# (38, 0, 47, 1)
# Selected: [61], for target: 61
# total reward after 5856 steps is 1000000
# (27, 26, 48, 1)
# (56, -1, 47, 2)
# Selected: [39, 27], for target: 65
# total reward after 5857 steps is -27
# (67, 17, 48, 0)
# (56, 17, 47, 0)
# (78, 17, 46, 0)
# (68, 17, 45, 0)
# (33, 17, 44, 0)
# (63, 17, 43, 0)
# (10, 17, 42, 0)
# (24, 7, 41, 1)
# (13, 7, 40, 1)
# (40, 7, 39, 1)
# (61, 7, 38, 1)
# (17, 7, 37, 1)
# (92, 7, 36, 1)
# (30, 7, 35, 1)
# (57, 7, 34, 1)
# (75, 7, 33, 1)
# (62, 7, 32, 1)
# (69, 7, 31, 1)
# (18, 7, 30, 1)
# (53, 7, 29, 1)
# (16, 7, 28, 1)
# (32, 7, 27, 1)
# (82, 7, 26, 1)
# (76, 7, 25, 1)
# (15, 7, 24, 1)
# (88, 7, 23, 1)
# (30, 7, 22, 1)
# (69, 7, 21, 1)
# (3, 7, 20, 1)
# (84, 4, 19, 2)
# (64, 4, 18, 2)
# (96, 4, 17, 2)
# (82, 4, 16, 2)
# (35, 4, 15, 2)
# (74, 4, 14, 2)
# (41, 4, 13, 2)
# (73, 4, 12, 2)
# (45, 4, 11, 2)
# (19, 4, 10, 2)
# (85, 4, 9, 2)
# (25, 4, 8, 2)
# (80, 4, 7, 2)
# (29, 4, 6, 2)
# (97, 4, 5, 2)
# (13, 4, 4, 2)
# (20, 4, 3, 2)
# (16, 4, 2, 2)
# (49, 4, 1, 2)
# (90, 4, 0, 2)
# (44, 4, -1, 2)
# Selected: [10, 3], for target: 17
# total reward after 5858 steps is 13
# (99, 13, 48, 1)
# (22, 13, 47, 1)
# (99, 13, 46, 1)
# (74, 13, 45, 1)
# (14, 13, 44, 1)
# (46, -1, 43, 2)
# Selected: [60, 14], for target: 73
# total reward after 5859 steps is -14
# (42, 84, 48, 1)
# (87, 42, 47, 2)
# (32, 42, 46, 2)
# (91, 10, 45, 3)
# (42, 10, 44, 3)
# (89, 10, 43, 3)
# (18, 10, 42, 3)
# (43, 10, 41, 3)
# (59, 10, 40, 3)
# (2, 10, 39, 3)
# (5, 8, 38, 4)
# (100, 3, 37, 5)
# Selected: [5, 42, 32, 2, 5], for target: 89
# total reward after 5860 steps is 86
# (52, 77, 48, 1)
# (93, 25, 47, 2)
# (30, 25, 46, 2)
# (50, -5, 45, 3)
# Selected: [10, 52, 30], for target: 87
# total reward after 5861 steps is -30
# (66, 75, 48, 1)
# (4, 9, 47, 2)
# (19, 5, 46, 3)
# (58, 5, 45, 3)
# (41, 5, 44, 3)
# (20, 5, 43, 3)
# (72, 5, 42, 3)
# (58, 5, 41, 3)
# (94, 5, 40, 3)
# (5, 5, 39, 3)
# (40, 0, 38, 4)
# Selected: [4, 66, 4, 5], for target: 79
# total reward after 5862 steps is 1074
# (5, 18, 48, 1)
# (2, 13, 47, 2)
# (42, 11, 46, 3)
# (28, 11, 45, 3)
# (58, 11, 44, 3)
# (35, 11, 43, 3)
# (39, 11, 42, 3)
# (100, 11, 41, 3)
# (29, 11, 40, 3)
# (55, 11, 39, 3)
# (62, 11, 38, 3)
# (3, 11, 37, 3)
# (46, 8, 36, 4)
# (50, 8, 35, 4)
# (90, 8, 34, 4)
# (12, 8, 33, 4)
# (55, 8, 32, 4)
# (20, 8, 31, 4)
# (59, 8, 30, 4)
# (51, 8, 29, 4)
# (15, 8, 28, 4)
# (32, 8, 27, 4)
# (88, 8, 26, 4)
# (92, 8, 25, 4)
# (39, 8, 24, 4)
# (40, 8, 23, 4)
# (91, 8, 22, 4)
# (91, 8, 21, 4)
# (94, 8, 20, 4)
# (100, 8, 19, 4)
# (97, 8, 18, 4)
# (17, 8, 17, 4)
# (68, 8, 16, 4)
# (72, 8, 15, 4)
# (20, 8, 14, 4)
# (65, 8, 13, 4)
# (37, 8, 12, 4)
# (72, 8, 11, 4)
# (37, 8, 10, 4)
# (23, 8, 9, 4)
# (15, 8, 8, 4)
# (33, 8, 7, 4)
# (72, 8, 6, 4)
# (58, 8, 5, 4)
# (23, 8, 4, 4)
# (99, 8, 3, 4)
# (2, 8, 2, 4)
# (39, 6, 1, 5)
# Selected: [12, 5, 2, 3, 2], for target: 30
# total reward after 5863 steps is 24
# (77, -2, 48, 1)
# Selected: [35], for target: 33
# total reward after 5864 steps is -35
# (9, 7, 48, 1)
# (69, -2, 47, 2)
# Selected: [11, 9], for target: 18
# total reward after 5865 steps is -9
# (16, 53, 48, 0)
# (100, 37, 47, 1)
# (75, 37, 46, 1)
# (9, 37, 45, 1)
# (37, 28, 44, 2)
# (38, -9, 43, 3)
# Selected: [16, 9, 37], for target: 53
# total reward after 5866 steps is -37
# (29, 5, 48, 1)
# (50, 5, 47, 1)
# (99, 5, 46, 1)
# (48, 5, 45, 1)
# (34, 5, 44, 1)
# (37, 5, 43, 1)
# (37, 5, 42, 1)
# (94, 5, 41, 1)
# (66, 5, 40, 1)
# (97, 5, 39, 1)
# (33, 5, 38, 1)
# (95, 5, 37, 1)
# (38, 5, 36, 1)
# (31, 5, 35, 1)
# (77, 5, 34, 1)
# (89, 5, 33, 1)
# (81, 5, 32, 1)
# (93, 5, 31, 1)
# (27, 5, 30, 1)
# (10, 5, 29, 1)
# (57, 5, 28, 1)
# (64, 5, 27, 1)
# (27, 5, 26, 1)
# (40, 5, 25, 1)
# (97, 5, 24, 1)
# (22, 5, 23, 1)
# (88, 5, 22, 1)
# (59, 5, 21, 1)
# (96, 5, 20, 1)
# (88, 5, 19, 1)
# (31, 5, 18, 1)
# (3, 5, 17, 1)
# (3, 2, 16, 2)
# (21, 2, 15, 2)
# (3, 2, 14, 2)
# (87, -1, 13, 3)
# Selected: [19, 3, 3], for target: 24
# total reward after 5867 steps is -3
# (6, 7, 48, 0)
# (38, 1, 47, 1)
# (36, 1, 46, 1)
# (18, 1, 45, 1)
# (69, 1, 44, 1)
# (83, 1, 43, 1)
# (22, 1, 42, 1)
# (26, 1, 41, 1)
# (88, 1, 40, 1)
# (12, 1, 39, 1)
# (57, 1, 38, 1)
# (32, 1, 37, 1)
# (25, 1, 36, 1)
# (74, 1, 35, 1)
# (15, 1, 34, 1)
# (77, 1, 33, 1)
# (81, 1, 32, 1)
# (42, 1, 31, 1)
# (33, 1, 30, 1)
# (12, 1, 29, 1)
# (33, 1, 28, 1)
# (76, 1, 27, 1)
# (77, 1, 26, 1)
# (67, 1, 25, 1)
# (93, 1, 24, 1)
# (12, 1, 23, 1)
# (59, 1, 22, 1)
# (4, 1, 21, 1)
# (87, -3, 20, 2)
# Selected: [6, 4], for target: 7
# total reward after 5868 steps is -4
# (53, 4, 48, 0)
# (86, 4, 47, 0)
# (46, 4, 46, 0)
# (31, 4, 45, 0)
# (94, 4, 44, 0)
# (54, 4, 43, 0)
# (9, 4, 42, 0)
# (86, -5, 41, 1)
# Selected: [9], for target: 4
# total reward after 5869 steps is -9
# (81, 2, 48, 1)
# (90, 2, 47, 1)
# (97, 2, 46, 1)
# (80, 2, 45, 1)
# (77, 2, 44, 1)
# (97, 2, 43, 1)
# (45, 2, 42, 1)
# (47, 2, 41, 1)
# (27, 2, 40, 1)
# (12, 2, 39, 1)
# (59, 2, 38, 1)
# (57, 2, 37, 1)
# (98, 2, 36, 1)
# (39, 2, 35, 1)
# (56, 2, 34, 1)
# (41, 2, 33, 1)
# (83, 2, 32, 1)
# (55, 2, 31, 1)
# (60, 2, 30, 1)
# (95, 2, 29, 1)
# (92, 2, 28, 1)
# (82, 2, 27, 1)
# (83, 2, 26, 1)
# (59, 2, 25, 1)
# (61, 2, 24, 1)
# (23, 2, 23, 1)
# (36, 2, 22, 1)
# (78, 2, 21, 1)
# (25, 2, 20, 1)
# (95, 2, 19, 1)
# (69, 2, 18, 1)
# (43, 2, 17, 1)
# (10, 2, 16, 1)
# (48, 2, 15, 1)
# (26, 2, 14, 1)
# (13, 2, 13, 1)
# (81, 2, 12, 1)
# (88, 2, 11, 1)
# (37, 2, 10, 1)
# (53, 2, 9, 1)
# (37, 2, 8, 1)
# (43, 2, 7, 1)
# (31, 2, 6, 1)
# (40, 2, 5, 1)
# (25, 2, 4, 1)
# (9, 2, 3, 1)
# (73, 2, 2, 1)
# (69, 2, 1, 1)
# (59, 2, 0, 1)
# (4, 2, -1, 1)
# Selected: [4], for target: 6
# total reward after 5870 steps is 4
# (82, -6, 48, 1)
# Selected: [53], for target: 47
# total reward after 5871 steps is -53
# (84, 15, 48, 0)
# (85, 15, 47, 0)
# (39, 15, 46, 0)
# (57, 15, 45, 0)
# (59, 15, 44, 0)
# (35, 15, 43, 0)
# (94, 15, 42, 0)
# (91, 15, 41, 0)
# (75, 15, 40, 0)
# (76, 15, 39, 0)
# (34, 15, 38, 0)
# (63, 15, 37, 0)
# (85, 15, 36, 0)
# (75, 15, 35, 0)
# (44, 15, 34, 0)
# (24, 15, 33, 0)
# (22, 15, 32, 0)
# (97, 15, 31, 0)
# (36, 15, 30, 0)
# (21, 15, 29, 0)
# (92, 15, 28, 0)
# (49, 15, 27, 0)
# (82, 15, 26, 0)
# (43, 15, 25, 0)
# (30, 15, 24, 0)
# (100, 15, 23, 0)
# (22, 15, 22, 0)
# (63, 15, 21, 0)
# (68, 15, 20, 0)
# (31, 15, 19, 0)
# (97, 15, 18, 0)
# (32, 15, 17, 0)
# (73, 15, 16, 0)
# (99, 15, 15, 0)
# (40, 15, 14, 0)
# (85, 15, 13, 0)
# (57, 15, 12, 0)
# (19, 15, 11, 0)
# (24, -4, 10, 1)
# Selected: [19], for target: 15
# total reward after 5872 steps is -19
# (43, 27, 48, 0)
# (49, 27, 47, 0)
# (44, 27, 46, 0)
# (23, 27, 45, 0)
# (69, 4, 44, 1)
# (21, 4, 43, 1)
# (81, 4, 42, 1)
# (18, 4, 41, 1)
# (13, 4, 40, 1)
# (46, 4, 39, 1)
# (27, 4, 38, 1)
# (78, 4, 37, 1)
# (55, 4, 36, 1)
# (85, 4, 35, 1)
# (97, 4, 34, 1)
# (91, 4, 33, 1)
# (23, 4, 32, 1)
# (68, 4, 31, 1)
# (64, 4, 30, 1)
# (87, 4, 29, 1)
# (87, 4, 28, 1)
# (81, 4, 27, 1)
# (59, 4, 26, 1)
# (57, 4, 25, 1)
# (18, 4, 24, 1)
# (60, 4, 23, 1)
# (69, 4, 22, 1)
# (28, 4, 21, 1)
# (65, 4, 20, 1)
# (61, 4, 19, 1)
# (75, 4, 18, 1)
# (72, 4, 17, 1)
# (59, 4, 16, 1)
# (100, 4, 15, 1)
# (87, 4, 14, 1)
# (43, 4, 13, 1)
# (87, 4, 12, 1)
# (48, 4, 11, 1)
# (96, 4, 10, 1)
# (20, 4, 9, 1)
# (80, 4, 8, 1)
# (62, 4, 7, 1)
# (49, 4, 6, 1)
# (1, 4, 5, 1)
# (45, 3, 4, 2)
# (98, 3, 3, 2)
# (55, 3, 2, 2)
# (7, 3, 1, 2)
# (92, 3, 0, 2)
# (76, 3, -1, 2)
# Selected: [23, 1], for target: 27
# total reward after 5873 steps is 24
# (34, 23, 48, 0)
# (88, 23, 47, 0)
# (96, 23, 46, 0)
# (53, 23, 45, 0)
# (24, 23, 44, 0)
# (36, -1, 43, 1)
# Selected: [24], for target: 23
# total reward after 5874 steps is -24
# (95, 32, 48, 0)
# (8, 32, 47, 0)
# (78, 24, 46, 1)
# (62, 24, 45, 1)
# (68, 24, 44, 1)
# (91, 24, 43, 1)
# (92, 24, 42, 1)
# (28, 24, 41, 1)
# (94, -4, 40, 2)
# Selected: [8, 28], for target: 32
# total reward after 5875 steps is -28
# (80, 5, 48, 0)
# (55, 5, 47, 0)
# (58, 5, 46, 0)
# (2, 5, 45, 0)
# (73, 3, 44, 1)
# (2, 3, 43, 1)
# (70, 1, 42, 2)
# (68, 1, 41, 2)
# (26, 1, 40, 2)
# (48, 1, 39, 2)
# (25, 1, 38, 2)
# (47, 1, 37, 2)
# (49, 1, 36, 2)
# (82, 1, 35, 2)
# (42, 1, 34, 2)
# (84, 1, 33, 2)
# (39, 1, 32, 2)
# (50, 1, 31, 2)
# (7, 1, 30, 2)
# (18, 1, 29, 2)
# (99, 1, 28, 2)
# (11, 1, 27, 2)
# (39, 1, 26, 2)
# (45, 1, 25, 2)
# (32, 1, 24, 2)
# (88, 1, 23, 2)
# (53, 1, 22, 2)
# (42, 1, 21, 2)
# (46, 1, 20, 2)
# (85, 1, 19, 2)
# (5, 1, 18, 2)
# (47, 1, 17, 2)
# (59, 1, 16, 2)
# (41, 1, 15, 2)
# (15, 1, 14, 2)
# (6, 1, 13, 2)
# (48, 1, 12, 2)
# (60, 1, 11, 2)
# (76, 1, 10, 2)
# (49, 1, 9, 2)
# (12, 1, 8, 2)
# (21, 1, 7, 2)
# (4, 1, 6, 2)
# (22, 1, 5, 2)
# (63, 1, 4, 2)
# (55, 1, 3, 2)
# (8, 1, 2, 2)
# (91, 1, 1, 2)
# (8, 1, 0, 2)
# (28, 1, -1, 2)
# Selected: [2, 2], for target: 5
# total reward after 5876 steps is 4
# (26, 44, 48, 1)
# (93, 18, 47, 2)
# (62, 18, 46, 2)
# (11, 18, 45, 2)
# (59, 7, 44, 3)
# (27, 7, 43, 3)
# (22, 7, 42, 3)
# (73, 7, 41, 3)
# (32, 7, 40, 3)
# (6, 7, 39, 3)
# (98, 1, 38, 4)
# (60, 1, 37, 4)
# (85, 1, 36, 4)
# (19, 1, 35, 4)
# (35, 1, 34, 4)
# (71, 1, 33, 4)
# (33, 1, 32, 4)
# (53, 1, 31, 4)
# (21, 1, 30, 4)
# (76, 1, 29, 4)
# (6, 1, 28, 4)
# (70, 1, 27, 4)
# (23, 1, 26, 4)
# (44, 1, 25, 4)
# (14, 1, 24, 4)
# (76, 1, 23, 4)
# (50, 1, 22, 4)
# (95, 1, 21, 4)
# (22, 1, 20, 4)
# (36, 1, 19, 4)
# (45, 1, 18, 4)
# (53, 1, 17, 4)
# (52, 1, 16, 4)
# (66, 1, 15, 4)
# (54, 1, 14, 4)
# (82, 1, 13, 4)
# (92, 1, 12, 4)
# (28, 1, 11, 4)
# (17, 1, 10, 4)
# (64, 1, 9, 4)
# (49, 1, 8, 4)
# (13, 1, 7, 4)
# (16, 1, 6, 4)
# (50, 1, 5, 4)
# (58, 1, 4, 4)
# (47, 1, 3, 4)
# (48, 1, 2, 4)
# (40, 1, 1, 4)
# (70, 1, 0, 4)
# (25, 1, -1, 4)
# Selected: [25, 26, 11, 6], for target: 69
# total reward after 5877 steps is 68
# (3, 3, 48, 1)
# (83, 0, 47, 2)
# Selected: [95, 3], for target: 98
# total reward after 5878 steps is 100095
# (39, 50, 48, 1)
# (39, 11, 47, 2)
# (29, 11, 46, 2)
# (99, 11, 45, 2)
# (82, 11, 44, 2)
# (21, 11, 43, 2)
# (17, 11, 42, 2)
# (82, 11, 41, 2)
# (37, 11, 40, 2)
# (72, 11, 39, 2)
# (88, 11, 38, 2)
# (91, 11, 37, 2)
# (46, 11, 36, 2)
# (22, 11, 35, 2)
# (68, 11, 34, 2)
# (52, 11, 33, 2)
# (5, 11, 32, 2)
# (63, 6, 31, 3)
# (85, 6, 30, 3)
# (56, 6, 29, 3)
# (99, 6, 28, 3)
# (51, 6, 27, 3)
# (90, 6, 26, 3)
# (73, 6, 25, 3)
# (48, 6, 24, 3)
# (23, 6, 23, 3)
# (60, 6, 22, 3)
# (40, 6, 21, 3)
# (22, 6, 20, 3)
# (62, 6, 19, 3)
# (18, 6, 18, 3)
# (26, 6, 17, 3)
# (62, 6, 16, 3)
# (51, 6, 15, 3)
# (70, 6, 14, 3)
# (7, 6, 13, 3)
# (60, 6, 12, 3)
# (43, 6, 11, 3)
# (2, 6, 10, 3)
# (46, 4, 9, 4)
# (27, 4, 8, 4)
# (66, 4, 7, 4)
# (78, 4, 6, 4)
# (12, 4, 5, 4)
# (17, 4, 4, 4)
# (65, 4, 3, 4)
# (6, 4, 2, 4)
# (76, 4, 1, 4)
# (24, 4, 0, 4)
# (23, 4, -1, 4)
# Selected: [23, 39, 5, 2], for target: 73
# total reward after 5879 steps is 69
# (43, 42, 48, 0)
# (34, -1, 47, 1)
# Selected: [43], for target: 42
# total reward after 5880 steps is -43
# (19, 48, 48, 0)
# (98, 29, 47, 1)
# (24, 29, 46, 1)
# (57, 5, 45, 2)
# (20, 5, 44, 2)
# (29, 5, 43, 2)
# (46, 5, 42, 2)
# (32, 5, 41, 2)
# (77, 5, 40, 2)
# (56, 5, 39, 2)
# (41, 5, 38, 2)
# (74, 5, 37, 2)
# (38, 5, 36, 2)
# (70, 5, 35, 2)
# (79, 5, 34, 2)
# (55, 5, 33, 2)
# (96, 5, 32, 2)
# (15, 5, 31, 2)
# (15, 5, 30, 2)
# (81, 5, 29, 2)
# (37, 5, 28, 2)
# (12, 5, 27, 2)
# (73, 5, 26, 2)
# (80, 5, 25, 2)
# (33, 5, 24, 2)
# (67, 5, 23, 2)
# (85, 5, 22, 2)
# (41, 5, 21, 2)
# (13, 5, 20, 2)
# (47, 5, 19, 2)
# (43, 5, 18, 2)
# (58, 5, 17, 2)
# (99, 5, 16, 2)
# (89, 5, 15, 2)
# (90, 5, 14, 2)
# (68, 5, 13, 2)
# (52, 5, 12, 2)
# (67, 5, 11, 2)
# (22, 5, 10, 2)
# (95, 5, 9, 2)
# (100, 5, 8, 2)
# (26, 5, 7, 2)
# (2, 5, 6, 2)
# (68, 3, 5, 3)
# (74, 3, 4, 3)
# (19, 3, 3, 3)
# (25, 3, 2, 3)
# (61, 3, 1, 3)
# (48, 3, 0, 3)
# (90, 3, -1, 3)
# Selected: [19, 24, 2], for target: 48
# total reward after 5881 steps is 45
# (67, 23, 48, 0)
# (57, 23, 47, 0)
# (87, 23, 46, 0)
# (80, 23, 45, 0)
# (78, 23, 44, 0)
# (3, 23, 43, 0)
# (94, 20, 42, 1)
# (28, 20, 41, 1)
# (85, -8, 40, 2)
# Selected: [3, 28], for target: 23
# total reward after 5882 steps is -28
# (63, 29, 48, 1)
# (63, 29, 47, 1)
# (86, 29, 46, 1)
# (77, 29, 45, 1)
# (4, 29, 44, 1)
# (2, 25, 43, 2)
# (42, 23, 42, 3)
# (32, 23, 41, 3)
# (100, 23, 40, 3)
# (88, 23, 39, 3)
# (78, 23, 38, 3)
# (20, 23, 37, 3)
# (46, 3, 36, 4)
# (88, 3, 35, 4)
# (15, 3, 34, 4)
# (71, 3, 33, 4)
# (20, 3, 32, 4)
# (18, 3, 31, 4)
# (15, 3, 30, 4)
# (30, 3, 29, 4)
# (64, 3, 28, 4)
# (53, 3, 27, 4)
# (30, 3, 26, 4)
# (7, 3, 25, 4)
# (73, 3, 24, 4)
# (86, 3, 23, 4)
# (34, 3, 22, 4)
# (74, 3, 21, 4)
# (84, 3, 20, 4)
# (70, 3, 19, 4)
# (64, 3, 18, 4)
# (95, 3, 17, 4)
# (48, 3, 16, 4)
# (87, 3, 15, 4)
# (87, 3, 14, 4)
# (79, 3, 13, 4)
# (90, 3, 12, 4)
# (83, 3, 11, 4)
# (42, 3, 10, 4)
# (61, 3, 9, 4)
# (83, 3, 8, 4)
# (31, 3, 7, 4)
# (51, 3, 6, 4)
# (68, 3, 5, 4)
# (62, 3, 4, 4)
# (41, 3, 3, 4)
# (51, 3, 2, 4)
# (84, 3, 1, 4)
# (24, 3, 0, 4)
# (38, 3, -1, 4)
# Selected: [38, 4, 2, 20], for target: 67
# total reward after 5883 steps is 64
# (73, 8, 48, 0)
# (52, 8, 47, 0)
# (81, 8, 46, 0)
# (69, 8, 45, 0)
# (11, 8, 44, 0)
# (3, -3, 43, 1)
# Selected: [11], for target: 8
# total reward after 5884 steps is -11
# (77, 17, 48, 1)
# (24, 17, 47, 1)
# (40, 17, 46, 1)
# (14, 17, 45, 1)
# (33, 3, 44, 2)
# (12, 3, 43, 2)
# (53, 3, 42, 2)
# (6, 3, 41, 2)
# (20, -3, 40, 3)
# Selected: [44, 14, 6], for target: 61
# total reward after 5885 steps is -6
# (66, 40, 48, 0)
# (8, 40, 47, 0)
# (52, 32, 46, 1)
# (66, 32, 45, 1)
# (18, 32, 44, 1)
# (76, 14, 43, 2)
# (66, 14, 42, 2)
# (96, 14, 41, 2)
# (61, 14, 40, 2)
# (39, 14, 39, 2)
# (30, 14, 38, 2)
# (2, 14, 37, 2)
# (53, 12, 36, 3)
# (60, 12, 35, 3)
# (53, 12, 34, 3)
# (64, 12, 33, 3)
# (70, 12, 32, 3)
# (90, 12, 31, 3)
# (27, 12, 30, 3)
# (96, 12, 29, 3)
# (69, 12, 28, 3)
# (26, 12, 27, 3)
# (10, 12, 26, 3)
# (91, 2, 25, 4)
# (95, 2, 24, 4)
# (34, 2, 23, 4)
# (2, 2, 22, 4)
# (75, 0, 21, 5)
# Selected: [8, 18, 2, 10, 2], for target: 40
# total reward after 5886 steps is 138
# (37, 58, 48, 1)
# (32, 21, 47, 2)
# (10, 21, 46, 2)
# (22, 11, 45, 3)
# (78, 11, 44, 3)
# (72, 11, 43, 3)
# (55, 11, 42, 3)
# (29, 11, 41, 3)
# (81, 11, 40, 3)
# (58, 11, 39, 3)
# (24, 11, 38, 3)
# (58, 11, 37, 3)
# (96, 11, 36, 3)
# (72, 11, 35, 3)
# (34, 11, 34, 3)
# (34, 11, 33, 3)
# (57, 11, 32, 3)
# (40, 11, 31, 3)
# (29, 11, 30, 3)
# (27, 11, 29, 3)
# (79, 11, 28, 3)
# (19, 11, 27, 3)
# (44, 11, 26, 3)
# (38, 11, 25, 3)
# (86, 11, 24, 3)
# (86, 11, 23, 3)
# (90, 11, 22, 3)
# (82, 11, 21, 3)
# (12, 11, 20, 3)
# (3, -1, 19, 4)
# Selected: [37, 37, 10, 12], for target: 95
# total reward after 5887 steps is -12
# (46, 20, 48, 0)
# (75, 20, 47, 0)
# (73, 20, 46, 0)
# (52, 20, 45, 0)
# (59, 20, 44, 0)
# (51, 20, 43, 0)
# (36, 20, 42, 0)
# (47, 20, 41, 0)
# (9, 20, 40, 0)
# (33, 11, 39, 1)
# (10, 11, 38, 1)
# (29, 1, 37, 2)
# (61, 1, 36, 2)
# (43, 1, 35, 2)
# (81, 1, 34, 2)
# (86, 1, 33, 2)
# (28, 1, 32, 2)
# (48, 1, 31, 2)
# (54, 1, 30, 2)
# (44, 1, 29, 2)
# (50, 1, 28, 2)
# (61, 1, 27, 2)
# (49, 1, 26, 2)
# (90, 1, 25, 2)
# (18, 1, 24, 2)
# (78, 1, 23, 2)
# (20, 1, 22, 2)
# (24, 1, 21, 2)
# (40, 1, 20, 2)
# (54, 1, 19, 2)
# (13, 1, 18, 2)
# (92, 1, 17, 2)
# (50, 1, 16, 2)
# (65, 1, 15, 2)
# (21, 1, 14, 2)
# (94, 1, 13, 2)
# (63, 1, 12, 2)
# (33, 1, 11, 2)
# (65, 1, 10, 2)
# (63, 1, 9, 2)
# (40, 1, 8, 2)
# (8, 1, 7, 2)
# (92, 1, 6, 2)
# (90, 1, 5, 2)
# (70, 1, 4, 2)
# (22, 1, 3, 2)
# (71, 1, 2, 2)
# (89, 1, 1, 2)
# (10, 1, 0, 2)
# (35, 1, -1, 2)
# Selected: [9, 10], for target: 20
# total reward after 5888 steps is 19
# (34, 5, 48, 0)
# (53, 5, 47, 0)
# (99, 5, 46, 0)
# (22, 5, 45, 0)
# (33, 5, 44, 0)
# (59, 5, 43, 0)
# (52, 5, 42, 0)
# (28, 5, 41, 0)
# (92, 5, 40, 0)
# (89, 5, 39, 0)
# (24, 5, 38, 0)
# (65, 5, 37, 0)
# (17, 5, 36, 0)
# (16, 5, 35, 0)
# (93, 5, 34, 0)
# (68, 5, 33, 0)
# (40, 5, 32, 0)
# (35, 5, 31, 0)
# (22, 5, 30, 0)
# (37, 5, 29, 0)
# (82, 5, 28, 0)
# (96, 5, 27, 0)
# (39, 5, 26, 0)
# (26, 5, 25, 0)
# (13, 5, 24, 0)
# (42, 5, 23, 0)
# (72, 5, 22, 0)
# (89, 5, 21, 0)
# (80, 5, 20, 0)
# (18, 5, 19, 0)
# (71, 5, 18, 0)
# (26, 5, 17, 0)
# (16, 5, 16, 0)
# (6, 5, 15, 0)
# (79, -1, 14, 1)
# Selected: [6], for target: 5
# total reward after 5889 steps is -6
# (54, 66, 48, 1)
# (29, 12, 47, 2)
# (40, 12, 46, 2)
# (19, 12, 45, 2)
# (6, 12, 44, 2)
# (89, 6, 43, 3)
# (70, 6, 42, 3)
# (73, 6, 41, 3)
# (48, 6, 40, 3)
# (11, 6, 39, 3)
# (49, 6, 38, 3)
# (20, 6, 37, 3)
# (56, 6, 36, 3)
# (37, 6, 35, 3)
# (14, 6, 34, 3)
# (13, 6, 33, 3)
# (80, 6, 32, 3)
# (27, 6, 31, 3)
# (17, 6, 30, 3)
# (46, 6, 29, 3)
# (65, 6, 28, 3)
# (8, 6, 27, 3)
# (44, 6, 26, 3)
# (37, 6, 25, 3)
# (17, 6, 24, 3)
# (40, 6, 23, 3)
# (62, 6, 22, 3)
# (52, 6, 21, 3)
# (16, 6, 20, 3)
# (22, 6, 19, 3)
# (49, 6, 18, 3)
# (51, 6, 17, 3)
# (6, 6, 16, 3)
# (90, 0, 15, 4)
# Selected: [19, 54, 6, 6], for target: 85
# total reward after 5890 steps is 1079
# (74, 6, 48, 0)
# (44, 6, 47, 0)
# (42, 6, 46, 0)
# (44, 6, 45, 0)
# (61, 6, 44, 0)
# (61, 6, 43, 0)
# (85, 6, 42, 0)
# (61, 6, 41, 0)
# (79, 6, 40, 0)
# (18, 6, 39, 0)
# (78, 6, 38, 0)
# (84, 6, 37, 0)
# (49, 6, 36, 0)
# (94, 6, 35, 0)
# (83, 6, 34, 0)
# (41, 6, 33, 0)
# (48, 6, 32, 0)
# (56, 6, 31, 0)
# (55, 6, 30, 0)
# (47, 6, 29, 0)
# (89, 6, 28, 0)
# (37, 6, 27, 0)
# (80, 6, 26, 0)
# (97, 6, 25, 0)
# (59, 6, 24, 0)
# (96, 6, 23, 0)
# (37, 6, 22, 0)
# (21, 6, 21, 0)
# (94, 6, 20, 0)
# (37, 6, 19, 0)
# (43, 6, 18, 0)
# (61, 6, 17, 0)
# (43, 6, 16, 0)
# (49, 6, 15, 0)
# (15, 6, 14, 0)
# (42, 6, 13, 0)
# (7, 6, 12, 0)
# (35, 6, 11, 0)
# (10, 6, 10, 0)
# (38, 6, 9, 0)
# (80, 6, 8, 0)
# (80, 6, 7, 0)
# (39, 6, 6, 0)
# (18, 6, 5, 0)
# (25, 6, 4, 0)
# (10, 6, 3, 0)
# (77, 6, 2, 0)
# (74, 6, 1, 0)
# (64, 6, 0, 0)
# (72, 6, -1, 0)
# Selected: [], for target: 6
# total reward after 5891 steps is -100
# (76, 35, 48, 0)
# (34, 35, 47, 0)
# (15, 1, 46, 1)
# (77, 1, 45, 1)
# (77, 1, 44, 1)
# (86, 1, 43, 1)
# (2, 1, 42, 1)
# (41, -1, 41, 2)
# Selected: [34, 2], for target: 35
# total reward after 5892 steps is -2
# (6, 47, 48, 0)
# (69, 41, 47, 1)
# (51, 41, 46, 1)
# (87, -10, 45, 2)
# Selected: [6, 51], for target: 47
# total reward after 5893 steps is -51
# (58, 62, 48, 1)
# (45, 4, 47, 2)
# (66, 4, 46, 2)
# (70, 4, 45, 2)
# (12, 4, 44, 2)
# (44, 4, 43, 2)
# (60, 4, 42, 2)
# (61, 4, 41, 2)
# (59, 4, 40, 2)
# (45, 4, 39, 2)
# (79, 4, 38, 2)
# (56, 4, 37, 2)
# (24, 4, 36, 2)
# (46, 4, 35, 2)
# (5, 4, 34, 2)
# (67, -1, 33, 3)
# Selected: [15, 58, 5], for target: 77
# total reward after 5894 steps is -5
# (39, -3, 48, 1)
# Selected: [12], for target: 9
# total reward after 5895 steps is -12
# (14, 55, 48, 1)
# (45, 41, 47, 2)
# (10, -4, 46, 3)
# Selected: [44, 14, 45], for target: 99
# total reward after 5896 steps is -45
# (6, 19, 48, 0)
# (54, 13, 47, 1)
# (17, 13, 46, 1)
# (28, 13, 45, 1)
# (13, 13, 44, 1)
# (15, 0, 43, 2)
# Selected: [6, 13], for target: 19
# total reward after 5897 steps is 100006
# (3, 8, 48, 1)
# (14, 5, 47, 2)
# (98, 5, 46, 2)
# (7, 5, 45, 2)
# (21, -2, 44, 3)
# Selected: [42, 3, 7], for target: 50
# total reward after 5898 steps is -7
# (57, 1, 48, 1)
# (4, 1, 47, 1)
# (93, -3, 46, 2)
# Selected: [65, 4], for target: 66
# total reward after 5899 steps is -4
# (67, 58, 48, 0)
# (65, -9, 47, 1)
# Selected: [67], for target: 58
# total reward after 5900 steps is -67
# (11, 27, 48, 1)
# (71, 16, 47, 2)
# (22, 16, 46, 2)
# (10, -6, 45, 3)
# Selected: [45, 11, 22], for target: 72
# total reward after 5901 steps is -22
# (65, 52, 48, 1)
# (73, 52, 47, 1)
# (50, 52, 46, 1)
# (21, 2, 45, 2)
# (46, 2, 44, 2)
# (54, 2, 43, 2)
# (20, 2, 42, 2)
# (70, 2, 41, 2)
# (45, 2, 40, 2)
# (4, 2, 39, 2)
# (80, -2, 38, 3)
# Selected: [30, 50, 4], for target: 82
# total reward after 5902 steps is -4
# (75, 18, 48, 0)
# (50, 18, 47, 0)
# (62, 18, 46, 0)
# (45, 18, 45, 0)
# (11, 18, 44, 0)
# (24, 7, 43, 1)
# (89, 7, 42, 1)
# (40, 7, 41, 1)
# (45, 7, 40, 1)
# (96, 7, 39, 1)
# (57, 7, 38, 1)
# (23, 7, 37, 1)
# (70, 7, 36, 1)
# (76, 7, 35, 1)
# (40, 7, 34, 1)
# (92, 7, 33, 1)
# (89, 7, 32, 1)
# (77, 7, 31, 1)
# (36, 7, 30, 1)
# (63, 7, 29, 1)
# (61, 7, 28, 1)
# (94, 7, 27, 1)
# (51, 7, 26, 1)
# (93, 7, 25, 1)
# (73, 7, 24, 1)
# (32, 7, 23, 1)
# (31, 7, 22, 1)
# (2, 7, 21, 1)
# (65, 5, 20, 2)
# (59, 5, 19, 2)
# (31, 5, 18, 2)
# (43, 5, 17, 2)
# (72, 5, 16, 2)
# (84, 5, 15, 2)
# (17, 5, 14, 2)
# (96, 5, 13, 2)
# (59, 5, 12, 2)
# (3, 5, 11, 2)
# (49, 2, 10, 3)
# (36, 2, 9, 3)
# (15, 2, 8, 3)
# (84, 2, 7, 3)
# (7, 2, 6, 3)
# (80, 2, 5, 3)
# (34, 2, 4, 3)
# (92, 2, 3, 3)
# (51, 2, 2, 3)
# (62, 2, 1, 3)
# (19, 2, 0, 3)
# (79, 2, -1, 3)
# Selected: [11, 2, 3], for target: 18
# total reward after 5903 steps is 16
# (72, 36, 48, 0)
# (43, 36, 47, 0)
# (74, -7, 46, 1)
# Selected: [43], for target: 36
# total reward after 5904 steps is -43
# (99, 14, 48, 1)
# (99, 14, 47, 1)
# (43, 14, 46, 1)
# (40, 14, 45, 1)
# (4, 14, 44, 1)
# (15, 10, 43, 2)
# (24, -5, 42, 3)
# Selected: [78, 4, 15], for target: 92
# total reward after 5905 steps is -15
# (23, 3, 48, 1)
# (3, 3, 47, 1)
# (99, 0, 46, 2)
# Selected: [6, 3], for target: 9
# total reward after 5906 steps is 100006
# (31, 35, 48, 0)
# (71, 4, 47, 1)
# (30, 4, 46, 1)
# (87, 4, 45, 1)
# (90, 4, 44, 1)
# (25, 4, 43, 1)
# (42, 4, 42, 1)
# (1, 4, 41, 1)
# (69, 3, 40, 2)
# (18, 3, 39, 2)
# (59, 3, 38, 2)
# (59, 3, 37, 2)
# (26, 3, 36, 2)
# (88, 3, 35, 2)
# (66, 3, 34, 2)
# (19, 3, 33, 2)
# (8, 3, 32, 2)
# (12, -5, 31, 3)
# Selected: [31, 1, 8], for target: 35
# total reward after 5907 steps is -8
# (1, 22, 48, 0)
# (88, 21, 47, 1)
# (87, 21, 46, 1)
# (84, 21, 45, 1)
# (46, 21, 44, 1)
# (63, 21, 43, 1)
# (57, 21, 42, 1)
# (84, 21, 41, 1)
# (96, 21, 40, 1)
# (61, 21, 39, 1)
# (50, 21, 38, 1)
# (72, 21, 37, 1)
# (31, 21, 36, 1)
# (21, 21, 35, 1)
# (16, 0, 34, 2)
# Selected: [1, 21], for target: 22
# total reward after 5908 steps is 100001
# (56, 3, 48, 0)
# (75, 3, 47, 0)
# (53, 3, 46, 0)
# (63, 3, 45, 0)
# (8, 3, 44, 0)
# (28, -5, 43, 1)
# Selected: [8], for target: 3
# total reward after 5909 steps is -8
# (86, 42, 48, 1)
# (7, 42, 47, 1)
# (91, 35, 46, 2)
# (34, 35, 45, 2)
# (82, 1, 44, 3)
# (29, 1, 43, 3)
# (13, 1, 42, 3)
# (17, 1, 41, 3)
# (73, 1, 40, 3)
# (43, 1, 39, 3)
# (37, 1, 38, 3)
# (90, 1, 37, 3)
# (23, 1, 36, 3)
# (23, 1, 35, 3)
# (70, 1, 34, 3)
# (81, 1, 33, 3)
# (75, 1, 32, 3)
# (39, 1, 31, 3)
# (26, 1, 30, 3)
# (17, 1, 29, 3)
# (43, 1, 28, 3)
# (78, 1, 27, 3)
# (20, 1, 26, 3)
# (13, 1, 25, 3)
# (57, 1, 24, 3)
# (38, 1, 23, 3)
# (37, 1, 22, 3)
# (56, 1, 21, 3)
# (55, 1, 20, 3)
# (55, 1, 19, 3)
# (61, 1, 18, 3)
# (1, 1, 17, 3)
# (76, 1, 16, 3)
# (34, 1, 15, 3)
# (97, 1, 14, 3)
# (10, 1, 13, 3)
# (63, 1, 12, 3)
# (18, 1, 11, 3)
# (59, 1, 10, 3)
# (69, 1, 9, 3)
# (20, 1, 8, 3)
# (21, 1, 7, 3)
# (90, 1, 6, 3)
# (63, 1, 5, 3)
# (65, 1, 4, 3)
# (31, 1, 3, 3)
# (95, 1, 2, 3)
# (13, 1, 1, 3)
# (4, 1, 0, 3)
# (23, 1, -1, 3)
# Selected: [23, 7, 34], for target: 65
# total reward after 5910 steps is 64
# (23, 11, 48, 0)
# (3, 11, 47, 0)
# (28, 8, 46, 1)
# (32, 8, 45, 1)
# (39, 8, 44, 1)
# (15, 8, 43, 1)
# (49, -7, 42, 2)
# Selected: [3, 15], for target: 11
# total reward after 5911 steps is -15
# (96, 0, 48, 1)
# Selected: [96], for target: 96
# total reward after 5912 steps is 1000000
# (21, 77, 48, 1)
# (60, 56, 47, 2)
# (91, -4, 46, 3)
# Selected: [5, 21, 60], for target: 82
# total reward after 5913 steps is -60
# (62, 14, 48, 1)
# (24, 14, 47, 1)
# (60, -10, 46, 2)
# Selected: [75, 24], for target: 89
# total reward after 5914 steps is -24
# (40, 39, 48, 1)
# (20, -1, 47, 2)
# Selected: [40, 40], for target: 79
# total reward after 5915 steps is -40
# (51, 49, 48, 0)
# (94, -2, 47, 1)
# Selected: [51], for target: 49
# total reward after 5916 steps is -51
# (48, -9, 48, 1)
# Selected: [63], for target: 54
# total reward after 5917 steps is -63
# (45, 22, 48, 0)
# (71, 22, 47, 0)
# (94, 22, 46, 0)
# (40, 22, 45, 0)
# (23, 22, 44, 0)
# (11, -1, 43, 1)
# Selected: [23], for target: 22
# total reward after 5918 steps is -23
# (10, 39, 48, 1)
# (1, 29, 47, 2)
# (46, 28, 46, 3)
# (72, 28, 45, 3)
# (32, 28, 44, 3)
# (99, -4, 43, 4)
# Selected: [45, 10, 1, 32], for target: 84
# total reward after 5919 steps is -32
# (40, 23, 48, 0)
# (60, 23, 47, 0)
# (3, 23, 46, 0)
# (36, 20, 45, 1)
# (68, 20, 44, 1)
# (41, 20, 43, 1)
# (59, 20, 42, 1)
# (68, 20, 41, 1)
# (97, 20, 40, 1)
# (56, 20, 39, 1)
# (36, 20, 38, 1)
# (22, 20, 37, 1)
# (17, -2, 36, 2)
# Selected: [3, 22], for target: 23
# total reward after 5920 steps is -22
# (3, 15, 48, 1)
# (34, 12, 47, 2)
# (44, 12, 46, 2)
# (63, 12, 45, 2)
# (81, 12, 44, 2)
# (14, 12, 43, 2)
# (58, -2, 42, 3)
# Selected: [3, 3, 14], for target: 18
# total reward after 5921 steps is -14
# (90, 21, 48, 0)
# (10, 21, 47, 0)
# (36, 11, 46, 1)
# (54, 11, 45, 1)
# (81, 11, 44, 1)
# (89, 11, 43, 1)
# (92, 11, 42, 1)
# (32, 11, 41, 1)
# (63, 11, 40, 1)
# (91, 11, 39, 1)
# (73, 11, 38, 1)
# (72, 11, 37, 1)
# (78, 11, 36, 1)
# (49, 11, 35, 1)
# (21, 11, 34, 1)
# (77, 11, 33, 1)
# (86, 11, 32, 1)
# (90, 11, 31, 1)
# (14, 11, 30, 1)
# (79, -3, 29, 2)
# Selected: [10, 14], for target: 21
# total reward after 5922 steps is -14
# (90, -6, 48, 1)
# Selected: [49], for target: 43
# total reward after 5923 steps is -49
# (13, 76, 48, 1)
# (15, 63, 47, 2)
# (42, 48, 46, 3)
# (21, 6, 45, 4)
# (83, 6, 44, 4)
# (73, 6, 43, 4)
# (65, 6, 42, 4)
# (36, 6, 41, 4)
# (14, 6, 40, 4)
# (31, 6, 39, 4)
# (94, 6, 38, 4)
# (34, 6, 37, 4)
# (36, 6, 36, 4)
# (89, 6, 35, 4)
# (30, 6, 34, 4)
# (68, 6, 33, 4)
# (51, 6, 32, 4)
# (65, 6, 31, 4)
# (91, 6, 30, 4)
# (48, 6, 29, 4)
# (72, 6, 28, 4)
# (36, 6, 27, 4)
# (19, 6, 26, 4)
# (28, 6, 25, 4)
# (93, 6, 24, 4)
# (39, 6, 23, 4)
# (40, 6, 22, 4)
# (41, 6, 21, 4)
# (88, 6, 20, 4)
# (51, 6, 19, 4)
# (31, 6, 18, 4)
# (81, 6, 17, 4)
# (50, 6, 16, 4)
# (20, 6, 15, 4)
# (35, 6, 14, 4)
# (81, 6, 13, 4)
# (3, 6, 12, 4)
# (21, 3, 11, 5)
# Selected: [10, 13, 15, 42, 3], for target: 86
# total reward after 5924 steps is 83
# (52, 28, 48, 1)
# (66, 28, 47, 1)
# (54, 28, 46, 1)
# (14, 28, 45, 1)
# (39, 14, 44, 2)
# (97, 14, 43, 2)
# (28, 14, 42, 2)
# (87, 14, 41, 2)
# (15, 14, 40, 2)
# (48, -1, 39, 3)
# Selected: [34, 14, 15], for target: 62
# total reward after 5925 steps is -15
# (69, 6, 48, 0)
# (85, 6, 47, 0)
# (37, 6, 46, 0)
# (9, 6, 45, 0)
# (88, -3, 44, 1)
# Selected: [9], for target: 6
# total reward after 5926 steps is -9
# (37, 63, 48, 1)
# (30, 26, 47, 2)
# (42, -4, 46, 3)
# Selected: [18, 37, 30], for target: 81
# total reward after 5927 steps is -30
# (94, 5, 48, 1)
# (11, 5, 47, 1)
# (6, -6, 46, 2)
# Selected: [39, 11], for target: 44
# total reward after 5928 steps is -11
# (22, -12, 48, 1)
# Selected: [67], for target: 55
# total reward after 5929 steps is -67
# (8, 34, 48, 0)
# (46, 26, 47, 1)
# (62, 26, 46, 1)
# (52, 26, 45, 1)
# (20, 26, 44, 1)
# (26, 6, 43, 2)
# (42, 6, 42, 2)
# (58, 6, 41, 2)
# (82, 6, 40, 2)
# (71, 6, 39, 2)
# (56, 6, 38, 2)
# (7, 6, 37, 2)
# (6, -1, 36, 3)
# Selected: [8, 20, 7], for target: 34
# total reward after 5930 steps is -7
# (69, 31, 48, 0)
# (16, 31, 47, 0)
# (45, 15, 46, 1)
# (25, 15, 45, 1)
# (12, 15, 44, 1)
# (1, 3, 43, 2)
# (28, 2, 42, 3)
# (94, 2, 41, 3)
# (70, 2, 40, 3)
# (63, 2, 39, 3)
# (74, 2, 38, 3)
# (16, 2, 37, 3)
# (48, 2, 36, 3)
# (8, 2, 35, 3)
# (6, 2, 34, 3)
# (64, 2, 33, 3)
# (61, 2, 32, 3)
# (55, 2, 31, 3)
# (9, 2, 30, 3)
# (71, 2, 29, 3)
# (2, 2, 28, 3)
# (63, 0, 27, 4)
# Selected: [16, 12, 1, 2], for target: 31
# total reward after 5931 steps is 1029
# (9, 13, 48, 0)
# (20, 4, 47, 1)
# (100, 4, 46, 1)
# (42, 4, 45, 1)
# (84, 4, 44, 1)
# (20, 4, 43, 1)
# (21, 4, 42, 1)
# (100, 4, 41, 1)
# (32, 4, 40, 1)
# (55, 4, 39, 1)
# (59, 4, 38, 1)
# (29, 4, 37, 1)
# (23, 4, 36, 1)
# (70, 4, 35, 1)
# (42, 4, 34, 1)
# (4, 4, 33, 1)
# (20, 0, 32, 2)
# Selected: [9, 4], for target: 13
# total reward after 5932 steps is 100009
# (56, 10, 48, 1)
# (3, 10, 47, 1)
# (27, 7, 46, 2)
# (40, 7, 45, 2)
# (61, 7, 44, 2)
# (54, 7, 43, 2)
# (41, 7, 42, 2)
# (95, 7, 41, 2)
# (5, 7, 40, 2)
# (89, 2, 39, 3)
# (38, 2, 38, 3)
# (19, 2, 37, 3)
# (85, 2, 36, 3)
# (75, 2, 35, 3)
# (20, 2, 34, 3)
# (18, 2, 33, 3)
# (19, 2, 32, 3)
# (56, 2, 31, 3)
# (85, 2, 30, 3)
# (8, 2, 29, 3)
# (96, -6, 28, 4)
# Selected: [6, 3, 5, 8], for target: 16
# total reward after 5933 steps is -8
# (25, 13, 48, 0)
# (92, 13, 47, 0)
# (81, 13, 46, 0)
# (6, 13, 45, 0)
# (17, 7, 44, 1)
# (59, 7, 43, 1)
# (42, 7, 42, 1)
# (53, 7, 41, 1)
# (95, 7, 40, 1)
# (6, 7, 39, 1)
# (95, 1, 38, 2)
# (26, 1, 37, 2)
# (86, 1, 36, 2)
# (56, 1, 35, 2)
# (59, 1, 34, 2)
# (17, 1, 33, 2)
# (80, 1, 32, 2)
# (46, 1, 31, 2)
# (87, 1, 30, 2)
# (16, 1, 29, 2)
# (5, 1, 28, 2)
# (27, -4, 27, 3)
# Selected: [6, 6, 5], for target: 13
# total reward after 5934 steps is -5
# (14, -9, 48, 1)
# Selected: [58], for target: 49
# total reward after 5935 steps is -58
# (61, 30, 48, 1)
# (28, 30, 47, 1)
# (43, 2, 46, 2)
# (66, 2, 45, 2)
# (49, 2, 44, 2)
# (6, 2, 43, 2)
# (55, -4, 42, 3)
# Selected: [4, 28, 6], for target: 34
# total reward after 5936 steps is -6
# (54, 13, 48, 0)
# (81, 13, 47, 0)
# (94, 13, 46, 0)
# (98, 13, 45, 0)
# (10, 13, 44, 0)
# (57, 3, 43, 1)
# (16, 3, 42, 1)
# (9, 3, 41, 1)
# (92, 3, 40, 1)
# (52, 3, 39, 1)
# (79, 3, 38, 1)
# (34, 3, 37, 1)
# (14, 3, 36, 1)
# (37, 3, 35, 1)
# (54, 3, 34, 1)
# (3, 3, 33, 1)
# (66, 0, 32, 2)
# Selected: [10, 3], for target: 13
# total reward after 5937 steps is 100010
# (16, 35, 48, 1)
# (87, 19, 47, 2)
# (60, 19, 46, 2)
# (96, 19, 45, 2)
# (93, 19, 44, 2)
# (39, 19, 43, 2)
# (22, 19, 42, 2)
# (7, -3, 41, 3)
# Selected: [8, 16, 22], for target: 43
# total reward after 5938 steps is -22
# (19, 29, 48, 0)
# (80, 10, 47, 1)
# (50, 10, 46, 1)
# (25, 10, 45, 1)
# (82, 10, 44, 1)
# (43, 10, 43, 1)
# (62, 10, 42, 1)
# (4, 10, 41, 1)
# (53, 6, 40, 2)
# (95, 6, 39, 2)
# (66, 6, 38, 2)
# (86, 6, 37, 2)
# (96, 6, 36, 2)
# (56, 6, 35, 2)
# (80, 6, 34, 2)
# (9, 6, 33, 2)
# (27, -3, 32, 3)
# Selected: [19, 4, 9], for target: 29
# total reward after 5939 steps is -9
# (54, 41, 48, 0)
# (54, 41, 47, 0)
# (55, 41, 46, 0)
# (83, 41, 45, 0)
# (42, 41, 44, 0)
# (62, -1, 43, 1)
# Selected: [42], for target: 41
# total reward after 5940 steps is -42
# (31, 21, 48, 1)
# (27, 21, 47, 1)
# (52, -6, 46, 2)
# Selected: [65, 27], for target: 86
# total reward after 5941 steps is -27
# (31, 2, 48, 0)
# (57, 2, 47, 0)
# (2, 2, 46, 0)
# (26, 0, 45, 1)
# Selected: [2], for target: 2
# total reward after 5942 steps is 1000000
# (66, 74, 48, 1)
# (25, 8, 47, 2)
# (84, 8, 46, 2)
# (19, 8, 45, 2)
# (45, -11, 44, 3)
# Selected: [9, 66, 19], for target: 83
# total reward after 5943 steps is -19
# (91, 6, 48, 0)
# (66, 6, 47, 0)
# (66, 6, 46, 0)
# (11, 6, 45, 0)
# (1, -5, 44, 1)
# Selected: [11], for target: 6
# total reward after 5944 steps is -11
# (47, 37, 48, 0)
# (35, -10, 47, 1)
# Selected: [47], for target: 37
# total reward after 5945 steps is -47
# (31, 7, 48, 0)
# (3, 7, 47, 0)
# (11, 4, 46, 1)
# (58, 4, 45, 1)
# (61, 4, 44, 1)
# (78, 4, 43, 1)
# (16, 4, 42, 1)
# (21, 4, 41, 1)
# (87, 4, 40, 1)
# (73, 4, 39, 1)
# (60, 4, 38, 1)
# (3, 4, 37, 1)
# (42, 1, 36, 2)
# (95, 1, 35, 2)
# (69, 1, 34, 2)
# (74, 1, 33, 2)
# (79, 1, 32, 2)
# (3, 1, 31, 2)
# (51, -2, 30, 3)
# Selected: [3, 3, 3], for target: 7
# total reward after 5946 steps is -3
# (68, 42, 48, 0)
# (15, 42, 47, 0)
# (76, 27, 46, 1)
# (68, 27, 45, 1)
# (89, 27, 44, 1)
# (4, 27, 43, 1)
# (20, 23, 42, 2)
# (36, 3, 41, 3)
# (47, 3, 40, 3)
# (7, 3, 39, 3)
# (38, -4, 38, 4)
# Selected: [15, 4, 20, 7], for target: 42
# total reward after 5947 steps is -7
# (1, -6, 48, 1)
# Selected: [15], for target: 9
# total reward after 5948 steps is -15
# (85, 38, 48, 0)
# (85, 38, 47, 0)
# (56, 38, 46, 0)
# (70, 38, 45, 0)
# (73, 38, 44, 0)
# (4, 38, 43, 0)
# (1, 34, 42, 1)
# (6, 33, 41, 2)
# (89, 27, 40, 3)
# (66, 27, 39, 3)
# (3, 27, 38, 3)
# (23, 24, 37, 4)
# (40, 1, 36, 5)
# Selected: [4, 1, 6, 3, 23], for target: 38
# total reward after 5949 steps is 37
# (21, 14, 48, 0)
# (51, 14, 47, 0)
# (98, 14, 46, 0)
# (43, 14, 45, 0)
# (25, 14, 44, 0)
# (1, 14, 43, 0)
# (84, 13, 42, 1)
# (74, 13, 41, 1)
# (27, 13, 40, 1)
# (18, 13, 39, 1)
# (28, 13, 38, 1)
# (56, 13, 37, 1)
# (47, 13, 36, 1)
# (99, 13, 35, 1)
# (40, 13, 34, 1)
# (75, 13, 33, 1)
# (96, 13, 32, 1)
# (35, 13, 31, 1)
# (30, 13, 30, 1)
# (16, 13, 29, 1)
# (2, -3, 28, 2)
# Selected: [1, 16], for target: 14
# total reward after 5950 steps is -16
# (88, 36, 48, 1)
# (86, 36, 47, 1)
# (51, 36, 46, 1)
# (25, 36, 45, 1)
# (86, 11, 44, 2)
# (92, 11, 43, 2)
# (32, 11, 42, 2)
# (57, 11, 41, 2)
# (67, 11, 40, 2)
# (30, 11, 39, 2)
# (76, 11, 38, 2)
# (41, 11, 37, 2)
# (28, 11, 36, 2)
# (89, 11, 35, 2)
# (13, 11, 34, 2)
# (72, -2, 33, 3)
# Selected: [35, 25, 13], for target: 71
# total reward after 5951 steps is -13
# (84, 31, 48, 1)
# (95, 31, 47, 1)
# (33, 31, 46, 1)
# (16, -2, 45, 2)
# Selected: [68, 33], for target: 99
# total reward after 5952 steps is -33
# (17, 19, 48, 0)
# (49, 2, 47, 1)
# (81, 2, 46, 1)
# (93, 2, 45, 1)
# (82, 2, 44, 1)
# (55, 2, 43, 1)
# (90, 2, 42, 1)
# (79, 2, 41, 1)
# (9, 2, 40, 1)
# (24, 2, 39, 1)
# (2, 2, 38, 1)
# (3, 0, 37, 2)
# Selected: [17, 2], for target: 19
# total reward after 5953 steps is 100017
# (87, 29, 48, 1)
# (71, 29, 47, 1)
# (46, 29, 46, 1)
# (53, 29, 45, 1)
# (12, 29, 44, 1)
# (24, 17, 43, 2)
# (95, 17, 42, 2)
# (97, 17, 41, 2)
# (38, 17, 40, 2)
# (87, 17, 39, 2)
# (42, 17, 38, 2)
# (25, 17, 37, 2)
# (91, 17, 36, 2)
# (25, 17, 35, 2)
# (96, -8, 34, 3)
# Selected: [1, 12, 25], for target: 30
# total reward after 5954 steps is -25
# (81, 30, 48, 0)
# (84, 30, 47, 0)
# (2, 30, 46, 0)
# (43, 28, 45, 1)
# (63, 28, 44, 1)
# (67, 28, 43, 1)
# (25, 28, 42, 1)
# (1, 3, 41, 2)
# (6, 2, 40, 3)
# (22, -4, 39, 4)
# Selected: [2, 25, 1, 6], for target: 30
# total reward after 5955 steps is -6
# (54, 49, 48, 1)
# (84, -5, 47, 2)
# Selected: [46, 54], for target: 95
# total reward after 5956 steps is -54
# (43, 7, 48, 1)
# (10, 7, 47, 1)
# (52, -3, 46, 2)
# Selected: [83, 10], for target: 90
# total reward after 5957 steps is -10
# (85, 19, 48, 0)
# (56, 19, 47, 0)
# (14, 19, 46, 0)
# (19, 5, 45, 1)
# (88, 5, 44, 1)
# (53, 5, 43, 1)
# (30, 5, 42, 1)
# (45, 5, 41, 1)
# (31, 5, 40, 1)
# (61, 5, 39, 1)
# (29, 5, 38, 1)
# (56, 5, 37, 1)
# (13, 5, 36, 1)
# (56, 5, 35, 1)
# (33, 5, 34, 1)
# (78, 5, 33, 1)
# (19, 5, 32, 1)
# (75, 5, 31, 1)
# (14, 5, 30, 1)
# (37, 5, 29, 1)
# (7, 5, 28, 1)
# (47, -2, 27, 2)
# Selected: [14, 7], for target: 19
# total reward after 5958 steps is -7
# (88, 5, 48, 1)
# (36, 5, 47, 1)
# (37, 5, 46, 1)
# (44, 5, 45, 1)
# (94, 5, 44, 1)
# (33, 5, 43, 1)
# (13, 5, 42, 1)
# (59, 5, 41, 1)
# (81, 5, 40, 1)
# (52, 5, 39, 1)
# (63, 5, 38, 1)
# (67, 5, 37, 1)
# (96, 5, 36, 1)
# (55, 5, 35, 1)
# (26, 5, 34, 1)
# (63, 5, 33, 1)
# (40, 5, 32, 1)
# (3, 5, 31, 1)
# (44, 2, 30, 2)
# (33, 2, 29, 2)
# (63, 2, 28, 2)
# (27, 2, 27, 2)
# (77, 2, 26, 2)
# (86, 2, 25, 2)
# (73, 2, 24, 2)
# (28, 2, 23, 2)
# (62, 2, 22, 2)
# (86, 2, 21, 2)
# (81, 2, 20, 2)
# (34, 2, 19, 2)
# (43, 2, 18, 2)
# (68, 2, 17, 2)
# (92, 2, 16, 2)
# (38, 2, 15, 2)
# (23, 2, 14, 2)
# (3, 2, 13, 2)
# (68, -1, 12, 3)
# Selected: [13, 3, 3], for target: 18
# total reward after 5959 steps is -3
# (12, 27, 48, 0)
# (19, 15, 47, 1)
# (59, 15, 46, 1)
# (64, 15, 45, 1)
# (37, 15, 44, 1)
# (100, 15, 43, 1)
# (17, 15, 42, 1)
# (82, -2, 41, 2)
# Selected: [12, 17], for target: 27
# total reward after 5960 steps is -17
# (49, 48, 48, 1)
# (73, -1, 47, 2)
# Selected: [12, 49], for target: 60
# total reward after 5961 steps is -49
# (16, 33, 48, 1)
# (73, 17, 47, 2)
# (99, 17, 46, 2)
# (17, 17, 45, 2)
# (24, 0, 44, 3)
# Selected: [33, 16, 17], for target: 66
# total reward after 5962 steps is 10049
# (7, 14, 48, 0)
# (33, 7, 47, 1)
# (39, 7, 46, 1)
# (29, 7, 45, 1)
# (64, 7, 44, 1)
# (81, 7, 43, 1)
# (70, 7, 42, 1)
# (77, 7, 41, 1)
# (59, 7, 40, 1)
# (80, 7, 39, 1)
# (80, 7, 38, 1)
# (19, 7, 37, 1)
# (27, 7, 36, 1)
# (6, 7, 35, 1)
# (34, 1, 34, 2)
# (22, 1, 33, 2)
# (26, 1, 32, 2)
# (43, 1, 31, 2)
# (50, 1, 30, 2)
# (65, 1, 29, 2)
# (3, 1, 28, 2)
# (98, -2, 27, 3)
# Selected: [7, 6, 3], for target: 14
# total reward after 5963 steps is -3
# (49, 9, 48, 1)
# (76, 9, 47, 1)
# (75, 9, 46, 1)
# (100, 9, 45, 1)
# (37, 9, 44, 1)
# (7, 9, 43, 1)
# (36, 2, 42, 2)
# (5, 2, 41, 2)
# (9, -3, 40, 3)
# Selected: [85, 7, 5], for target: 94
# total reward after 5964 steps is -5
# (37, 13, 48, 0)
# (26, 13, 47, 0)
# (31, 13, 46, 0)
# (86, 13, 45, 0)
# (43, 13, 44, 0)
# (68, 13, 43, 0)
# (75, 13, 42, 0)
# (63, 13, 41, 0)
# (55, 13, 40, 0)
# (95, 13, 39, 0)
# (59, 13, 38, 0)
# (16, 13, 37, 0)
# (61, -3, 36, 1)
# Selected: [16], for target: 13
# total reward after 5965 steps is -16
# (42, 24, 48, 0)
# (40, 24, 47, 0)
# (57, 24, 46, 0)
# (21, 24, 45, 0)
# (42, 3, 44, 1)
# (44, 3, 43, 1)
# (90, 3, 42, 1)
# (19, 3, 41, 1)
# (22, 3, 40, 1)
# (99, 3, 39, 1)
# (23, 3, 38, 1)
# (38, 3, 37, 1)
# (11, 3, 36, 1)
# (18, 3, 35, 1)
# (3, 3, 34, 1)
# (48, 0, 33, 2)
# Selected: [21, 3], for target: 24
# total reward after 5966 steps is 100021
# (80, 69, 48, 1)
# (78, 69, 47, 1)
# (67, -9, 46, 2)
# Selected: [9, 78], for target: 78
# total reward after 5967 steps is -78
# (18, -7, 48, 1)
# Selected: [13], for target: 6
# total reward after 5968 steps is -13
# (17, 11, 48, 0)
# (81, -6, 47, 1)
# Selected: [17], for target: 11
# total reward after 5969 steps is -17
# (63, 11, 48, 1)
# (50, 11, 47, 1)
# (73, 11, 46, 1)
# (36, 11, 45, 1)
# (1, 11, 44, 1)
# (67, 10, 43, 2)
# (45, 10, 42, 2)
# (6, 10, 41, 2)
# (69, 4, 40, 3)
# (100, 4, 39, 3)
# (5, 4, 38, 3)
# (22, -1, 37, 4)
# Selected: [74, 1, 6, 5], for target: 85
# total reward after 5970 steps is -5
# (85, 12, 48, 0)
# (82, 12, 47, 0)
# (95, 12, 46, 0)
# (48, 12, 45, 0)
# (54, 12, 44, 0)
# (52, 12, 43, 0)
# (11, 12, 42, 0)
# (46, 1, 41, 1)
# (43, 1, 40, 1)
# (13, 1, 39, 1)
# (94, 1, 38, 1)
# (33, 1, 37, 1)
# (21, 1, 36, 1)
# (38, 1, 35, 1)
# (8, 1, 34, 1)
# (24, 1, 33, 1)
# (39, 1, 32, 1)
# (30, 1, 31, 1)
# (40, 1, 30, 1)
# (89, 1, 29, 1)
# (68, 1, 28, 1)
# (63, 1, 27, 1)
# (35, 1, 26, 1)
# (6, 1, 25, 1)
# (90, 1, 24, 1)
# (60, 1, 23, 1)
# (51, 1, 22, 1)
# (35, 1, 21, 1)
# (28, 1, 20, 1)
# (28, 1, 19, 1)
# (3, 1, 18, 1)
# (4, 1, 17, 1)
# (88, 1, 16, 1)
# (18, 1, 15, 1)
# (58, 1, 14, 1)
# (2, 1, 13, 1)
# (14, -1, 12, 2)
# Selected: [11, 2], for target: 12
# total reward after 5971 steps is -2
# (43, 61, 48, 0)
# (37, 18, 47, 1)
# (37, 18, 46, 1)
# (61, 18, 45, 1)
# (34, 18, 44, 1)
# (25, 18, 43, 1)
# (29, 18, 42, 1)
# (81, 18, 41, 1)
# (39, 18, 40, 1)
# (84, 18, 39, 1)
# (73, 18, 38, 1)
# (70, 18, 37, 1)
# (38, 18, 36, 1)
# (60, 18, 35, 1)
# (78, 18, 34, 1)
# (96, 18, 33, 1)
# (19, 18, 32, 1)
# (84, -1, 31, 2)
# Selected: [43, 19], for target: 61
# total reward after 5972 steps is -19
# (70, 70, 48, 0)
# (77, 0, 47, 1)
# Selected: [70], for target: 70
# total reward after 5973 steps is 1000000
# (37, 25, 48, 0)
# (15, 25, 47, 0)
# (74, 10, 46, 1)
# (65, 10, 45, 1)
# (97, 10, 44, 1)
# (6, 10, 43, 1)
# (27, 4, 42, 2)
# (29, 4, 41, 2)
# (16, 4, 40, 2)
# (38, 4, 39, 2)
# (19, 4, 38, 2)
# (1, 4, 37, 2)
# (47, 3, 36, 3)
# (74, 3, 35, 3)
# (65, 3, 34, 3)
# (86, 3, 33, 3)
# (78, 3, 32, 3)
# (19, 3, 31, 3)
# (24, 3, 30, 3)
# (91, 3, 29, 3)
# (41, 3, 28, 3)
# (65, 3, 27, 3)
# (63, 3, 26, 3)
# (27, 3, 25, 3)
# (71, 3, 24, 3)
# (71, 3, 23, 3)
# (90, 3, 22, 3)
# (94, 3, 21, 3)
# (100, 3, 20, 3)
# (20, 3, 19, 3)
# (37, 3, 18, 3)
# (9, 3, 17, 3)
# (28, 3, 16, 3)
# (30, 3, 15, 3)
# (86, 3, 14, 3)
# (26, 3, 13, 3)
# (62, 3, 12, 3)
# (26, 3, 11, 3)
# (17, 3, 10, 3)
# (2, 3, 9, 3)
# (93, 1, 8, 4)
# (100, 1, 7, 4)
# (39, 1, 6, 4)
# (68, 1, 5, 4)
# (39, 1, 4, 4)
# (27, 1, 3, 4)
# (15, 1, 2, 4)
# (48, 1, 1, 4)
# (73, 1, 0, 4)
# (78, 1, -1, 4)
# Selected: [15, 6, 1, 2], for target: 25
# total reward after 5974 steps is 24
# (63, -2, 48, 1)
# Selected: [79], for target: 77
# total reward after 5975 steps is -79
# (48, 25, 48, 0)
# (92, 25, 47, 0)
# (44, 25, 46, 0)
# (28, 25, 45, 0)
# (10, -3, 44, 1)
# Selected: [28], for target: 25
# total reward after 5976 steps is -28
# (51, 25, 48, 0)
# (95, 25, 47, 0)
# (18, 25, 46, 0)
# (57, 7, 45, 1)
# (77, 7, 44, 1)
# (93, 7, 43, 1)
# (5, 7, 42, 1)
# (74, 2, 41, 2)
# (11, 2, 40, 2)
# (3, 2, 39, 2)
# (98, -1, 38, 3)
# Selected: [18, 5, 3], for target: 25
# total reward after 5977 steps is -3
# (43, 41, 48, 1)
# (6, -2, 47, 2)
# Selected: [48, 43], for target: 89
# total reward after 5978 steps is -43
# (36, 26, 48, 1)
# (44, -10, 47, 2)
# Selected: [72, 36], for target: 98
# total reward after 5979 steps is -36
# (37, -1, 48, 1)
# Selected: [94], for target: 93
# total reward after 5980 steps is -94
# (45, 4, 48, 1)
# (40, 4, 47, 1)
# (1, 4, 46, 1)
# (15, 3, 45, 2)
# (21, 3, 44, 2)
# (25, 3, 43, 2)
# (93, 3, 42, 2)
# (95, 3, 41, 2)
# (33, 3, 40, 2)
# (12, 3, 39, 2)
# (65, 3, 38, 2)
# (19, 3, 37, 2)
# (43, 3, 36, 2)
# (95, 3, 35, 2)
# (70, 3, 34, 2)
# (23, 3, 33, 2)
# (54, 3, 32, 2)
# (92, 3, 31, 2)
# (99, 3, 30, 2)
# (77, 3, 29, 2)
# (81, 3, 28, 2)
# (41, 3, 27, 2)
# (34, 3, 26, 2)
# (22, 3, 25, 2)
# (21, 3, 24, 2)
# (55, 3, 23, 2)
# (63, 3, 22, 2)
# (23, 3, 21, 2)
# (24, 3, 20, 2)
# (26, 3, 19, 2)
# (15, 3, 18, 2)
# (67, 3, 17, 2)
# (89, 3, 16, 2)
# (96, 3, 15, 2)
# (11, 3, 14, 2)
# (10, 3, 13, 2)
# (50, 3, 12, 2)
# (1, 3, 11, 2)
# (99, 2, 10, 3)
# (33, 2, 9, 3)
# (73, 2, 8, 3)
# (88, 2, 7, 3)
# (29, 2, 6, 3)
# (64, 2, 5, 3)
# (17, 2, 4, 3)
# (32, 2, 3, 3)
# (59, 2, 2, 3)
# (64, 2, 1, 3)
# (50, 2, 0, 3)
# (54, 2, -1, 3)
# Selected: [54, 1, 1], for target: 58
# total reward after 5981 steps is 56
# (59, 53, 48, 1)
# (7, -6, 47, 2)
# Selected: [12, 59], for target: 65
# total reward after 5982 steps is -59
# (86, 32, 48, 0)
# (48, 32, 47, 0)
# (82, 32, 46, 0)
# (18, 32, 45, 0)
# (94, 14, 44, 1)
# (87, 14, 43, 1)
# (70, 14, 42, 1)
# (24, 14, 41, 1)
# (73, 14, 40, 1)
# (1, 14, 39, 1)
# (70, 13, 38, 2)
# (75, 13, 37, 2)
# (34, 13, 36, 2)
# (53, 13, 35, 2)
# (32, 13, 34, 2)
# (35, 13, 33, 2)
# (57, 13, 32, 2)
# (54, 13, 31, 2)
# (15, 13, 30, 2)
# (8, -2, 29, 3)
# Selected: [18, 1, 15], for target: 32
# total reward after 5983 steps is -15
# (57, 3, 48, 0)
# (77, 3, 47, 0)
# (82, 3, 46, 0)
# (49, 3, 45, 0)
# (35, 3, 44, 0)
# (42, 3, 43, 0)
# (4, 3, 42, 0)
# (66, -1, 41, 1)
# Selected: [4], for target: 3
# total reward after 5984 steps is -4
# (85, 13, 48, 0)
# (3, 13, 47, 0)
# (92, 10, 46, 1)
# (40, 10, 45, 1)
# (16, 10, 44, 1)
# (26, 10, 43, 1)
# (56, 10, 42, 1)
# (3, 10, 41, 1)
# (62, 7, 40, 2)
# (31, 7, 39, 2)
# (14, 7, 38, 2)
# (46, 7, 37, 2)
# (38, 7, 36, 2)
# (2, 7, 35, 2)
# (27, 5, 34, 3)
# (2, 5, 33, 3)
# (18, 3, 32, 4)
# (69, 3, 31, 4)
# (3, 3, 30, 4)
# (91, 0, 29, 5)
# Selected: [3, 3, 2, 2, 3], for target: 13
# total reward after 5985 steps is 110
# (81, 25, 48, 0)
# (44, 25, 47, 0)
# (63, 25, 46, 0)
# (84, 25, 45, 0)
# (82, 25, 44, 0)
# (50, 25, 43, 0)
# (55, 25, 42, 0)
# (48, 25, 41, 0)
# (67, 25, 40, 0)
# (92, 25, 39, 0)
# (13, 25, 38, 0)
# (59, 12, 37, 1)
# (24, 12, 36, 1)
# (99, 12, 35, 1)
# (12, 12, 34, 1)
# (66, 0, 33, 2)
# Selected: [13, 12], for target: 25
# total reward after 5986 steps is 100013
# (85, 47, 48, 1)
# (63, 47, 47, 1)
# (51, 47, 46, 1)
# (82, -4, 45, 2)
# Selected: [48, 51], for target: 95
# total reward after 5987 steps is -51
# (98, 12, 48, 0)
# (15, 12, 47, 0)
# (25, -3, 46, 1)
# Selected: [15], for target: 12
# total reward after 5988 steps is -15
# (50, 4, 48, 1)
# (15, 4, 47, 1)
# (39, 4, 46, 1)
# (25, 4, 45, 1)
# (65, 4, 44, 1)
# (12, 4, 43, 1)
# (92, -8, 42, 2)
# Selected: [15, 12], for target: 19
# total reward after 5989 steps is -12
# (72, 69, 48, 1)
# (19, -3, 47, 2)
# Selected: [6, 72], for target: 75
# total reward after 5990 steps is -72
# (64, 51, 48, 1)
# (92, 51, 47, 1)
# (14, 51, 46, 1)
# (27, 37, 45, 2)
# (55, 10, 44, 3)
# (25, 10, 43, 3)
# (22, 10, 42, 3)
# (100, 10, 41, 3)
# (28, 10, 40, 3)
# (9, 10, 39, 3)
# (19, 1, 38, 4)
# (34, 1, 37, 4)
# (20, 1, 36, 4)
# (30, 1, 35, 4)
# (75, 1, 34, 4)
# (77, 1, 33, 4)
# (24, 1, 32, 4)
# (30, 1, 31, 4)
# (86, 1, 30, 4)
# (71, 1, 29, 4)
# (47, 1, 28, 4)
# (54, 1, 27, 4)
# (97, 1, 26, 4)
# (99, 1, 25, 4)
# (71, 1, 24, 4)
# (68, 1, 23, 4)
# (36, 1, 22, 4)
# (24, 1, 21, 4)
# (22, 1, 20, 4)
# (39, 1, 19, 4)
# (25, 1, 18, 4)
# (52, 1, 17, 4)
# (98, 1, 16, 4)
# (67, 1, 15, 4)
# (73, 1, 14, 4)
# (44, 1, 13, 4)
# (31, 1, 12, 4)
# (44, 1, 11, 4)
# (31, 1, 10, 4)
# (68, 1, 9, 4)
# (37, 1, 8, 4)
# (88, 1, 7, 4)
# (39, 1, 6, 4)
# (59, 1, 5, 4)
# (11, 1, 4, 4)
# (4, 1, 3, 4)
# (88, 1, 2, 4)
# (62, 1, 1, 4)
# (63, 1, 0, 4)
# (20, 1, -1, 4)
# Selected: [20, 14, 27, 9], for target: 71
# total reward after 5991 steps is 70
# (42, 57, 48, 0)
# (11, 15, 47, 1)
# (9, 4, 46, 2)
# (76, -5, 45, 3)
# Selected: [42, 11, 9], for target: 57
# total reward after 5992 steps is -9
# (58, 37, 48, 1)
# (20, 37, 47, 1)
# (59, 17, 46, 2)
# (48, 17, 45, 2)
# (55, 17, 44, 2)
# (90, 17, 43, 2)
# (59, 17, 42, 2)
# (24, 17, 41, 2)
# (88, 17, 40, 2)
# (50, 17, 39, 2)
# (78, 17, 38, 2)
# (55, 17, 37, 2)
# (72, 17, 36, 2)
# (38, 17, 35, 2)
# (41, 17, 34, 2)
# (42, 17, 33, 2)
# (56, 17, 32, 2)
# (41, 17, 31, 2)
# (46, 17, 30, 2)
# (19, 17, 29, 2)
# (9, -2, 28, 3)
# Selected: [7, 20, 19], for target: 44
# total reward after 5993 steps is -19
# (67, 25, 48, 1)
# (1, 25, 47, 1)
# (34, 24, 46, 2)
# (45, -10, 45, 3)
# Selected: [68, 1, 34], for target: 93
# total reward after 5994 steps is -34
# (50, 5, 48, 1)
# (45, 5, 47, 1)
# (87, 5, 46, 1)
# (39, 5, 45, 1)
# (60, 5, 44, 1)
# (83, 5, 43, 1)
# (75, 5, 42, 1)
# (86, 5, 41, 1)
# (77, 5, 40, 1)
# (22, 5, 39, 1)
# (97, 5, 38, 1)
# (31, 5, 37, 1)
# (72, 5, 36, 1)
# (39, 5, 35, 1)
# (62, 5, 34, 1)
# (92, 5, 33, 1)
# (39, 5, 32, 1)
# (88, 5, 31, 1)
# (4, 5, 30, 1)
# (3, 1, 29, 2)
# (60, -2, 28, 3)
# Selected: [66, 4, 3], for target: 71
# total reward after 5995 steps is -3
# (64, 5, 48, 1)
# (67, 5, 47, 1)
# (85, 5, 46, 1)
# (19, 5, 45, 1)
# (27, 5, 44, 1)
# (16, 5, 43, 1)
# (29, 5, 42, 1)
# (21, 5, 41, 1)
# (41, 5, 40, 1)
# (70, 5, 39, 1)
# (79, 5, 38, 1)
# (9, 5, 37, 1)
# (69, -4, 36, 2)
# Selected: [26, 9], for target: 31
# total reward after 5996 steps is -9
# (65, 15, 48, 1)
# (39, 15, 47, 1)
# (96, 15, 46, 1)
# (32, 15, 45, 1)
# (96, 15, 44, 1)
# (37, 15, 43, 1)
# (22, 15, 42, 1)
# (74, -7, 41, 2)
# Selected: [71, 22], for target: 86
# total reward after 5997 steps is -22
# (24, 52, 48, 1)
# (59, 28, 47, 2)
# (96, 28, 46, 2)
# (84, 28, 45, 2)
# (72, 28, 44, 2)
# (27, 28, 43, 2)
# (15, 1, 42, 3)
# (49, 1, 41, 3)
# (18, 1, 40, 3)
# (81, 1, 39, 3)
# (5, 1, 38, 3)
# (7, -4, 37, 4)
# Selected: [5, 24, 27, 5], for target: 57
# total reward after 5998 steps is -5
# (78, 42, 48, 1)
# (49, 42, 47, 1)
# (17, -7, 46, 2)
# Selected: [20, 49], for target: 62
# total reward after 5999 steps is -49
# (4, -6, 48, 1)
# Selected: [100], for target: 94
# total reward after 6000 steps is -100
# (58, 48, 48, 1)
# (62, -10, 47, 2)
# Selected: [18, 58], for target: 66
# total reward after 6001 steps is -58
# (5, -4, 48, 1)
# Selected: [91], for target: 87
# total reward after 6002 steps is -91
# (38, 20, 48, 0)
# (29, 20, 47, 0)
# (15, 20, 46, 0)
# (28, 5, 45, 1)
# (77, 5, 44, 1)
# (75, 5, 43, 1)
# (60, 5, 42, 1)
# (51, 5, 41, 1)
# (44, 5, 40, 1)
# (91, 5, 39, 1)
# (56, 5, 38, 1)
# (76, 5, 37, 1)
# (100, 5, 36, 1)
# (87, 5, 35, 1)
# (94, 5, 34, 1)
# (89, 5, 33, 1)
# (32, 5, 32, 1)
# (63, 5, 31, 1)
# (2, 5, 30, 1)
# (46, 3, 29, 2)
# (99, 3, 28, 2)
# (38, 3, 27, 2)
# (6, 3, 26, 2)
# (46, -3, 25, 3)
# Selected: [15, 2, 6], for target: 20
# total reward after 6003 steps is -6
# (1, 11, 48, 0)
# (61, 10, 47, 1)
# (91, 10, 46, 1)
# (69, 10, 45, 1)
# (13, 10, 44, 1)
# (73, -3, 43, 2)
# Selected: [1, 13], for target: 11
# total reward after 6004 steps is -13
# (28, 52, 48, 1)
# (86, 24, 47, 2)
# (86, 24, 46, 2)
# (40, 24, 45, 2)
# (77, 24, 44, 2)
# (72, 24, 43, 2)
# (75, 24, 42, 2)
# (54, 24, 41, 2)
# (99, 24, 40, 2)
# (64, 24, 39, 2)
# (93, 24, 38, 2)
# (33, 24, 37, 2)
# (24, 24, 36, 2)
# (53, 0, 35, 3)
# Selected: [15, 28, 24], for target: 67
# total reward after 6005 steps is 10043
# (11, 14, 48, 0)
# (48, 3, 47, 1)
# (41, 3, 46, 1)
# (71, 3, 45, 1)
# (57, 3, 44, 1)
# (19, 3, 43, 1)
# (84, 3, 42, 1)
# (46, 3, 41, 1)
# (43, 3, 40, 1)
# (5, 3, 39, 1)
# (79, -2, 38, 2)
# Selected: [11, 5], for target: 14
# total reward after 6006 steps is -5
# (85, 10, 48, 0)
# (29, 10, 47, 0)
# (76, 10, 46, 0)
# (38, 10, 45, 0)
# (100, 10, 44, 0)
# (32, 10, 43, 0)
# (28, 10, 42, 0)
# (20, 10, 41, 0)
# (81, 10, 40, 0)
# (31, 10, 39, 0)
# (93, 10, 38, 0)
# (7, 10, 37, 0)
# (13, 3, 36, 1)
# (65, 3, 35, 1)
# (5, 3, 34, 1)
# (22, -2, 33, 2)
# Selected: [7, 5], for target: 10
# total reward after 6007 steps is -5
# (83, 48, 48, 0)
# (75, 48, 47, 0)
# (61, 48, 46, 0)
# (49, 48, 45, 0)
# (18, -1, 44, 1)
# Selected: [49], for target: 48
# total reward after 6008 steps is -49
# (100, 68, 48, 0)
# (97, 68, 47, 0)
# (64, 68, 46, 0)
# (9, 4, 45, 1)
# (8, -5, 44, 2)
# Selected: [64, 9], for target: 68
# total reward after 6009 steps is -9
# (91, 39, 48, 1)
# (20, 39, 47, 1)
# (66, 19, 46, 2)
# (85, 19, 45, 2)
# (85, 19, 44, 2)
# (51, 19, 43, 2)
# (54, 19, 42, 2)
# (50, 19, 41, 2)
# (9, 19, 40, 2)
# (6, 10, 39, 3)
# (46, 4, 38, 4)
# (75, 4, 37, 4)
# (97, 4, 36, 4)
# (82, 4, 35, 4)
# (37, 4, 34, 4)
# (62, 4, 33, 4)
# (53, 4, 32, 4)
# (52, 4, 31, 4)
# (78, 4, 30, 4)
# (91, 4, 29, 4)
# (10, 4, 28, 4)
# (23, 4, 27, 4)
# (15, 4, 26, 4)
# (29, 4, 25, 4)
# (40, 4, 24, 4)
# (92, 4, 23, 4)
# (88, 4, 22, 4)
# (43, 4, 21, 4)
# (25, 4, 20, 4)
# (35, 4, 19, 4)
# (45, 4, 18, 4)
# (62, 4, 17, 4)
# (89, 4, 16, 4)
# (15, 4, 15, 4)
# (95, 4, 14, 4)
# (30, 4, 13, 4)
# (40, 4, 12, 4)
# (14, 4, 11, 4)
# (8, 4, 10, 4)
# (21, 4, 9, 4)
# (59, 4, 8, 4)
# (91, 4, 7, 4)
# (27, 4, 6, 4)
# (84, 4, 5, 4)
# (37, 4, 4, 4)
# (91, 4, 3, 4)
# (49, 4, 2, 4)
# (76, 4, 1, 4)
# (69, 4, 0, 4)
# (17, 4, -1, 4)
# Selected: [17, 20, 9, 6], for target: 56
# total reward after 6010 steps is 52
# (17, 6, 48, 1)
# (16, 6, 47, 1)
# (2, 6, 46, 1)
# (68, 4, 45, 2)
# (10, 4, 44, 2)
# (20, -6, 43, 3)
# Selected: [1, 2, 10], for target: 7
# total reward after 6011 steps is -10
# (3, 6, 48, 0)
# (39, 3, 47, 1)
# (96, 3, 46, 1)
# (16, 3, 45, 1)
# (42, 3, 44, 1)
# (43, 3, 43, 1)
# (74, 3, 42, 1)
# (80, 3, 41, 1)
# (74, 3, 40, 1)
# (27, 3, 39, 1)
# (2, 3, 38, 1)
# (71, 1, 37, 2)
# (14, 1, 36, 2)
# (56, 1, 35, 2)
# (96, 1, 34, 2)
# (80, 1, 33, 2)
# (98, 1, 32, 2)
# (71, 1, 31, 2)
# (38, 1, 30, 2)
# (10, 1, 29, 2)
# (86, 1, 28, 2)
# (51, 1, 27, 2)
# (17, 1, 26, 2)
# (100, 1, 25, 2)
# (30, 1, 24, 2)
# (61, 1, 23, 2)
# (29, 1, 22, 2)
# (33, 1, 21, 2)
# (84, 1, 20, 2)
# (2, 1, 19, 2)
# (32, -1, 18, 3)
# Selected: [3, 2, 2], for target: 6
# total reward after 6012 steps is -2
# (99, 16, 48, 1)
# (58, 16, 47, 1)
# (94, 16, 46, 1)
# (32, 16, 45, 1)
# (44, 16, 44, 1)
# (1, 16, 43, 1)
# (30, 15, 42, 2)
# (37, 15, 41, 2)
# (72, 15, 40, 2)
# (83, 15, 39, 2)
# (83, 15, 38, 2)
# (85, 15, 37, 2)
# (96, 15, 36, 2)
# (42, 15, 35, 2)
# (32, 15, 34, 2)
# (89, 15, 33, 2)
# (86, 15, 32, 2)
# (28, 15, 31, 2)
# (22, 15, 30, 2)
# (29, 15, 29, 2)
# (96, 15, 28, 2)
# (68, 15, 27, 2)
# (62, 15, 26, 2)
# (41, 15, 25, 2)
# (11, 15, 24, 2)
# (32, 4, 23, 3)
# ...
# (65, 4, 10, 2)
# (56, 4, 9, 2)
# (47, 4, 8, 2)
# (36, 4, 7, 2)
# (14, 4, 6, 2)
# (37, 4, 5, 2)
# (3, 4, 4, 2)
# (9, 1, 3, 3)
# (61, 1, 2, 3)
# (45, 1, 1, 3)
# (6, 1, 0, 3)
# (85, 1, -1, 3)
# Selected: [85, 3, 3], for target: 92
# total reward after 6100 steps is 91
# (42, 72, 48, 1)
# (51, 30, 47, 2)
# (56, 30, 46, 2)
# (56, 30, 45, 2)
# (69, 30, 44, 2)
# (60, 30, 43, 2)
# (97, 30, 42, 2)
# (50, 30, 41, 2)
# (20, 30, 40, 2)
# (93, 10, 39, 3)
# (62, 10, 38, 3)
# (72, 10, 37, 3)
# (56, 10, 36, 3)
# (71, 10, 35, 3)
# (19, 10, 34, 3)
# (59, -9, 33, 4)
# Selected: [28, 42, 20, 19], for target: 100
# total reward after 6101 steps is -19
# (21, 26, 48, 0)
# (8, 5, 47, 1)
# (51, -3, 46, 2)
# Selected: [21, 8], for target: 26
# total reward after 6102 steps is -8
# (18, 7, 48, 0)
# (53, 7, 47, 0)
# (8, 7, 46, 0)
# (41, -1, 45, 1)
# Selected: [8], for target: 7
# total reward after 6103 steps is -8
# (55, 35, 48, 1)
# (6, 35, 47, 1)
# (76, 29, 46, 2)
# (87, 29, 45, 2)
# (68, 29, 44, 2)
# (63, 29, 43, 2)
# (47, 29, 42, 2)
# (32, 29, 41, 2)
# (11, -3, 40, 3)
# Selected: [42, 6, 32], for target: 77
# total reward after 6104 steps is -32
# (5, 79, 48, 0)
# (86, 74, 47, 1)
# (75, 74, 46, 1)
# (67, -1, 45, 2)
# Selected: [5, 75], for target: 79
# total reward after 6105 steps is -75
# (15, 27, 48, 1)
# (99, 12, 47, 2)
# (26, 12, 46, 2)
# (86, 12, 45, 2)
# (3, 12, 44, 2)
# (93, 9, 43, 3)
# (91, 9, 42, 3)
# (66, 9, 41, 3)
# (47, 9, 40, 3)
# (69, 9, 39, 3)
# (74, 9, 38, 3)
# (17, 9, 37, 3)
# (1, 9, 36, 3)
# (55, 8, 35, 4)
# (69, 8, 34, 4)
# (74, 8, 33, 4)
# (73, 8, 32, 4)
# (14, 8, 31, 4)
# (82, 8, 30, 4)
# (70, 8, 29, 4)
# (78, 8, 28, 4)
# (85, 8, 27, 4)
# (19, 8, 26, 4)
# (86, 8, 25, 4)
# (69, 8, 24, 4)
# (31, 8, 23, 4)
# (69, 8, 22, 4)
# (21, 8, 21, 4)
# (89, 8, 20, 4)
# (59, 8, 19, 4)
# (59, 8, 18, 4)
# (77, 8, 17, 4)
# (36, 8, 16, 4)
# (38, 8, 15, 4)
# (52, 8, 14, 4)
# (26, 8, 13, 4)
# (59, 8, 12, 4)
# (55, 8, 11, 4)
# (64, 8, 10, 4)
# (6, 8, 9, 4)
# (16, 2, 8, 5)
# Selected: [47, 15, 3, 1, 6], for target: 74
# total reward after 6106 steps is 72
# (97, 80, 48, 1)
# (91, 80, 47, 1)
# (14, 80, 46, 1)
# (80, 66, 45, 2)
# (81, 66, 44, 2)
# (2, 66, 43, 2)
# (1, 64, 42, 3)
# (13, 63, 41, 4)
# (57, 50, 40, 5)
# Selected: [18, 14, 2, 1, 13], for target: 98
# total reward after 6107 steps is 48
# (23, 58, 48, 0)
# (33, 35, 47, 1)
# (22, 2, 46, 2)
# (96, 2, 45, 2)
# (15, 2, 44, 2)
# (49, 2, 43, 2)
# (7, 2, 42, 2)
# (83, 2, 41, 2)
# (59, 2, 40, 2)
# (38, 2, 39, 2)
# (87, 2, 38, 2)
# (40, 2, 37, 2)
# (96, 2, 36, 2)
# (47, 2, 35, 2)
# (77, 2, 34, 2)
# (6, 2, 33, 2)
# (7, 2, 32, 2)
# (65, 2, 31, 2)
# (64, 2, 30, 2)
# (32, 2, 29, 2)
# (70, 2, 28, 2)
# (43, 2, 27, 2)
# (36, 2, 26, 2)
# (14, 2, 25, 2)
# (34, 2, 24, 2)
# (93, 2, 23, 2)
# (84, 2, 22, 2)
# (69, 2, 21, 2)
# (99, 2, 20, 2)
# (91, 2, 19, 2)
# (81, 2, 18, 2)
# (21, 2, 17, 2)
# (60, 2, 16, 2)
# (4, 2, 15, 2)
# (92, 2, 14, 2)
# (23, 2, 13, 2)
# (29, 2, 12, 2)
# (64, 2, 11, 2)
# (76, 2, 10, 2)
# (52, 2, 9, 2)
# (89, 2, 8, 2)
# (38, 2, 7, 2)
# (69, 2, 6, 2)
# (12, 2, 5, 2)
# (74, 2, 4, 2)
# (10, 2, 3, 2)
# (70, 2, 2, 2)
# (99, 2, 1, 2)
# (30, 2, 0, 2)
# (94, 2, -1, 2)
# Selected: [23, 33], for target: 58
# total reward after 6108 steps is 56
# (15, 43, 48, 0)
# (45, 28, 47, 1)
# (98, 28, 46, 1)
# (91, 28, 45, 1)
# (46, 28, 44, 1)
# (34, 28, 43, 1)
# (79, -6, 42, 2)
# Selected: [15, 34], for target: 43
# total reward after 6109 steps is -34
# (59, 71, 48, 1)
# (99, 12, 47, 2)
# (86, 12, 46, 2)
# (63, 12, 45, 2)
# (23, 12, 44, 2)
# (15, 12, 43, 2)
# (92, -3, 42, 3)
# Selected: [7, 59, 15], for target: 78
# total reward after 6110 steps is -15
# (9, 34, 48, 0)
# (9, 25, 47, 1)
# (72, 16, 46, 2)
# (16, 16, 45, 2)
# (61, 0, 44, 3)
# Selected: [9, 9, 16], for target: 34
# total reward after 6111 steps is 10018
# (75, 71, 48, 0)
# (11, -4, 47, 1)
# Selected: [75], for target: 71
# total reward after 6112 steps is -75
# (75, 32, 48, 0)
# (99, 32, 47, 0)
# (92, 32, 46, 0)
# (61, 32, 45, 0)
# (15, 32, 44, 0)
# (71, 17, 43, 1)
# (8, 17, 42, 1)
# (35, 9, 41, 2)
# (100, 9, 40, 2)
# (17, 9, 39, 2)
# (37, 9, 38, 2)
# (21, 9, 37, 2)
# (47, 9, 36, 2)
# (16, 9, 35, 2)
# (70, 9, 34, 2)
# (15, 9, 33, 2)
# (30, 9, 32, 2)
# (96, 9, 31, 2)
# (93, 9, 30, 2)
# (3, 9, 29, 2)
# (55, 6, 28, 3)
# (23, 6, 27, 3)
# (31, 6, 26, 3)
# (55, 6, 25, 3)
# (14, 6, 24, 3)
# (64, 6, 23, 3)
# (12, 6, 22, 3)
# (8, 6, 21, 3)
# (71, 6, 20, 3)
# (41, 6, 19, 3)
# (68, 6, 18, 3)
# (2, 6, 17, 3)
# (64, 4, 16, 4)
# (70, 4, 15, 4)
# (57, 4, 14, 4)
# (51, 4, 13, 4)
# (4, 4, 12, 4)
# (44, 0, 11, 5)
# Selected: [15, 8, 3, 2, 4], for target: 32
# total reward after 6113 steps is 128
# (67, 19, 48, 1)
# (51, 19, 47, 1)
# (30, 19, 46, 1)
# (50, 19, 45, 1)
# (99, 19, 44, 1)
# (22, 19, 43, 1)
# (52, -3, 42, 2)
# Selected: [72, 22], for target: 91
# total reward after 6114 steps is -22
# (53, 19, 48, 0)
# (58, 19, 47, 0)
# (29, 19, 46, 0)
# (87, 19, 45, 0)
# (90, 19, 44, 0)
# (17, 19, 43, 0)
# (38, 2, 42, 1)
# (95, 2, 41, 1)
# (83, 2, 40, 1)
# (98, 2, 39, 1)
# (68, 2, 38, 1)
# (93, 2, 37, 1)
# (21, 2, 36, 1)
# (47, 2, 35, 1)
# (25, 2, 34, 1)
# (56, 2, 33, 1)
# (67, 2, 32, 1)
# (91, 2, 31, 1)
# (52, 2, 30, 1)
# (67, 2, 29, 1)
# (96, 2, 28, 1)
# (83, 2, 27, 1)
# (34, 2, 26, 1)
# (7, 2, 25, 1)
# (85, 2, 24, 1)
# (57, 2, 23, 1)
# (59, 2, 22, 1)
# (59, 2, 21, 1)
# (5, 2, 20, 1)
# (42, -3, 19, 2)
# Selected: [17, 5], for target: 19
# total reward after 6115 steps is -5
# (14, 7, 48, 0)
# (82, 7, 47, 0)
# (68, 7, 46, 0)
# (49, 7, 45, 0)
# (69, 7, 44, 0)
# (23, 7, 43, 0)
# (74, 7, 42, 0)
# (35, 7, 41, 0)
# (53, 7, 40, 0)
# (36, 7, 39, 0)
# (57, 7, 38, 0)
# (65, 7, 37, 0)
# (88, 7, 36, 0)
# (34, 7, 35, 0)
# (95, 7, 34, 0)
# (25, 7, 33, 0)
# (78, 7, 32, 0)
# (82, 7, 31, 0)
# (40, 7, 30, 0)
# (71, 7, 29, 0)
# (32, 7, 28, 0)
# (41, 7, 27, 0)
# (58, 7, 26, 0)
# (54, 7, 25, 0)
# (90, 7, 24, 0)
# (85, 7, 23, 0)
# (69, 7, 22, 0)
# (79, 7, 21, 0)
# (51, 7, 20, 0)
# (14, 7, 19, 0)
# (70, 7, 18, 0)
# (46, 7, 17, 0)
# (45, 7, 16, 0)
# (66, 7, 15, 0)
# (10, 7, 14, 0)
# (45, 7, 13, 0)
# (77, 7, 12, 0)
# (55, 7, 11, 0)
# (3, 7, 10, 0)
# (50, 4, 9, 1)
# (31, 4, 8, 1)
# (77, 4, 7, 1)
# (20, 4, 6, 1)
# (56, 4, 5, 1)
# (14, 4, 4, 1)
# (30, 4, 3, 1)
# (91, 4, 2, 1)
# (8, 4, 1, 1)
# (72, 4, 0, 1)
# (27, 4, -1, 1)
# Selected: [3], for target: 7
# total reward after 6116 steps is 3
# (72, 65, 48, 0)
# (7, 65, 47, 0)
# (94, 58, 46, 1)
# (60, 58, 45, 1)
# (54, -2, 44, 2)
# Selected: [7, 60], for target: 65
# total reward after 6117 steps is -60
# (22, 5, 48, 0)
# (93, 5, 47, 0)
# (100, 5, 46, 0)
# (6, 5, 45, 0)
# (13, -1, 44, 1)
# Selected: [6], for target: 5
# total reward after 6118 steps is -6
# (74, 29, 48, 1)
# (47, 29, 47, 1)
# (96, 29, 46, 1)
# (48, 29, 45, 1)
# (58, 29, 44, 1)
# (4, 29, 43, 1)
# (96, 25, 42, 2)
# (4, 25, 41, 2)
# (99, 21, 40, 3)
# (10, 21, 39, 3)
# (71, 11, 38, 4)
# (30, 11, 37, 4)
# (48, 11, 36, 4)
# (23, 11, 35, 4)
# (21, 11, 34, 4)
# (33, 11, 33, 4)
# (82, 11, 32, 4)
# (43, 11, 31, 4)
# (57, 11, 30, 4)
# (39, 11, 29, 4)
# (49, 11, 28, 4)
# (27, 11, 27, 4)
# (6, 11, 26, 4)
# (57, 5, 25, 5)
# Selected: [48, 4, 4, 10, 6], for target: 77
# total reward after 6119 steps is 72
# (4, 25, 48, 0)
# (71, 21, 47, 1)
# (6, 21, 46, 1)
# (87, 15, 45, 2)
# (59, 15, 44, 2)
# (62, 15, 43, 2)
# (2, 15, 42, 2)
# (4, 13, 41, 3)
# (9, 9, 40, 4)
# (3, 0, 39, 5)
# Selected: [4, 6, 2, 4, 9], for target: 25
# total reward after 6120 steps is 116
# (56, 13, 48, 0)
# (72, 13, 47, 0)
# (10, 13, 46, 0)
# (64, 3, 45, 1)
# (10, 3, 44, 1)
# (3, 3, 43, 1)
# (23, 0, 42, 2)
# Selected: [10, 3], for target: 13
# total reward after 6121 steps is 100010
# (18, 21, 48, 1)
# (12, 3, 47, 2)
# (74, 3, 46, 2)
# (73, 3, 45, 2)
# (67, 3, 44, 2)
# (38, 3, 43, 2)
# (90, 3, 42, 2)
# (72, 3, 41, 2)
# (11, 3, 40, 2)
# (97, 3, 39, 2)
# (41, 3, 38, 2)
# (69, 3, 37, 2)
# (18, 3, 36, 2)
# (5, 3, 35, 2)
# (56, -2, 34, 3)
# Selected: [68, 18, 5], for target: 89
# total reward after 6122 steps is -5
# (84, 75, 48, 1)
# (17, 75, 47, 1)
# (65, 58, 46, 2)
# (15, 58, 45, 2)
# (14, 43, 44, 3)
# (43, 29, 43, 4)
# (52, 29, 42, 4)
# (42, 29, 41, 4)
# (54, 29, 40, 4)
# (65, 29, 39, 4)
# (35, 29, 38, 4)
# (85, -6, 37, 5)
# Selected: [16, 17, 15, 14, 35], for target: 91
# total reward after 6123 steps is -35
# (97, 9, 48, 1)
# (91, 9, 47, 1)
# (22, 9, 46, 1)
# (33, 9, 45, 1)
# (73, 9, 44, 1)
# (33, 9, 43, 1)
# (77, 9, 42, 1)
# (22, 9, 41, 1)
# (22, 9, 40, 1)
# (28, 9, 39, 1)
# (75, 9, 38, 1)
# (90, 9, 37, 1)
# (85, 9, 36, 1)
# (15, 9, 35, 1)
# (71, 9, 34, 1)
# (43, 9, 33, 1)
# (70, 9, 32, 1)
# (57, 9, 31, 1)
# (20, 9, 30, 1)
# (78, 9, 29, 1)
# (45, 9, 28, 1)
# (31, 9, 27, 1)
# (34, 9, 26, 1)
# (77, 9, 25, 1)
# (75, 9, 24, 1)
# (74, 9, 23, 1)
# (99, 9, 22, 1)
# (5, 9, 21, 1)
# (99, 4, 20, 2)
# (49, 4, 19, 2)
# (81, 4, 18, 2)
# (99, 4, 17, 2)
# (58, 4, 16, 2)
# (83, 4, 15, 2)
# (52, 4, 14, 2)
# (15, 4, 13, 2)
# (16, 4, 12, 2)
# (70, 4, 11, 2)
# (31, 4, 10, 2)
# (24, 4, 9, 2)
# (68, 4, 8, 2)
# (87, 4, 7, 2)
# (51, 4, 6, 2)
# (88, 4, 5, 2)
# (88, 4, 4, 2)
# (78, 4, 3, 2)
# (83, 4, 2, 2)
# (97, 4, 1, 2)
# (10, 4, 0, 2)
# (20, 4, -1, 2)
# Selected: [20, 5], for target: 29
# total reward after 6124 steps is 25
# (37, 44, 48, 1)
# (63, 7, 47, 2)
# (32, 7, 46, 2)
# (74, 7, 45, 2)
# (36, 7, 44, 2)
# (94, 7, 43, 2)
# (69, 7, 42, 2)
# (68, 7, 41, 2)
# (78, 7, 40, 2)
# (75, 7, 39, 2)
# (98, 7, 38, 2)
# (40, 7, 37, 2)
# (79, 7, 36, 2)
# (93, 7, 35, 2)
# (4, 7, 34, 2)
# (100, 3, 33, 3)
# (58, 3, 32, 3)
# (43, 3, 31, 3)
# (14, 3, 30, 3)
# (20, 3, 29, 3)
# (70, 3, 28, 3)
# (46, 3, 27, 3)
# (93, 3, 26, 3)
# (46, 3, 25, 3)
# (40, 3, 24, 3)
# (80, 3, 23, 3)
# (75, 3, 22, 3)
# (54, 3, 21, 3)
# (56, 3, 20, 3)
# (68, 3, 19, 3)
# (5, 3, 18, 3)
# (23, 3, 17, 3)
# (85, 3, 16, 3)
# (39, 3, 15, 3)
# (26, 3, 14, 3)
# (9, 3, 13, 3)
# (70, 3, 12, 3)
# (56, 3, 11, 3)
# (37, 3, 10, 3)
# (27, 3, 9, 3)
# (44, 3, 8, 3)
# (79, 3, 7, 3)
# (73, 3, 6, 3)
# (72, 3, 5, 3)
# (20, 3, 4, 3)
# (95, 3, 3, 3)
# (72, 3, 2, 3)
# (60, 3, 1, 3)
# (12, 3, 0, 3)
# (6, 3, -1, 3)
# Selected: [6, 37, 4], for target: 50
# total reward after 6125 steps is 47
# (43, 9, 48, 1)
# (34, 9, 47, 1)
# (35, 9, 46, 1)
# (70, 9, 45, 1)
# (31, 9, 44, 1)
# (54, 9, 43, 1)
# (28, 9, 42, 1)
# (88, 9, 41, 1)
# (26, 9, 40, 1)
# (69, 9, 39, 1)
# (92, 9, 38, 1)
# (15, 9, 37, 1)
# (30, 9, 36, 1)
# (62, 9, 35, 1)
# (83, 9, 34, 1)
# (1, 9, 33, 1)
# (30, 8, 32, 2)
# (22, 8, 31, 2)
# (34, 8, 30, 2)
# (24, 8, 29, 2)
# (64, 8, 28, 2)
# (21, 8, 27, 2)
# (25, 8, 26, 2)
# (84, 8, 25, 2)
# (24, 8, 24, 2)
# (59, 8, 23, 2)
# (60, 8, 22, 2)
# (65, 8, 21, 2)
# (73, 8, 20, 2)
# (29, 8, 19, 2)
# (35, 8, 18, 2)
# (47, 8, 17, 2)
# (45, 8, 16, 2)
# (86, 8, 15, 2)
# (3, 8, 14, 2)
# (53, 5, 13, 3)
# (27, 5, 12, 3)
# (37, 5, 11, 3)
# (3, 5, 10, 3)
# (33, 5, 9, 3)
# (29, 5, 8, 3)
# (73, 5, 7, 3)
# (12, 5, 6, 3)
# (58, 5, 5, 3)
# (81, 5, 4, 3)
# (27, 5, 3, 3)
# (27, 5, 2, 3)
# (78, 5, 1, 3)
# (4, 5, 0, 3)
# (41, 5, -1, 3)
# Selected: [41, 1, 3], for target: 50
# total reward after 6126 steps is 45
# (83, 26, 48, 0)
# (85, 26, 47, 0)
# (60, 26, 46, 0)
# (7, 26, 45, 0)
# (42, 19, 44, 1)
# (54, 19, 43, 1)
# (15, 19, 42, 1)
# (25, 4, 41, 2)
# (39, 4, 40, 2)
# (31, 4, 39, 2)
# (12, 4, 38, 2)
# (32, 4, 37, 2)
# (55, 4, 36, 2)
# (72, 4, 35, 2)
# (84, 4, 34, 2)
# (33, 4, 33, 2)
# (11, 4, 32, 2)
# (78, 4, 31, 2)
# (8, 4, 30, 2)
# (79, 4, 29, 2)
# (38, 4, 28, 2)
# (14, 4, 27, 2)
# (22, 4, 26, 2)
# (96, 4, 25, 2)
# (35, 4, 24, 2)
# (29, 4, 23, 2)
# (29, 4, 22, 2)
# (87, 4, 21, 2)
# (8, 4, 20, 2)
# (42, 4, 19, 2)
# (91, 4, 18, 2)
# (78, 4, 17, 2)
# (92, 4, 16, 2)
# (64, 4, 15, 2)
# (6, 4, 14, 2)
# (90, -2, 13, 3)
# Selected: [7, 15, 6], for target: 26
# total reward after 6127 steps is -6
# (19, 33, 48, 1)
# (32, 14, 47, 2)
# (89, 14, 46, 2)
# (99, 14, 45, 2)
# (47, 14, 44, 2)
# (21, 14, 43, 2)
# (47, 14, 42, 2)
# (28, 14, 41, 2)
# (98, 14, 40, 2)
# (42, 14, 39, 2)
# (21, 14, 38, 2)
# (97, 14, 37, 2)
# (87, 14, 36, 2)
# (37, 14, 35, 2)
# (69, 14, 34, 2)
# (47, 14, 33, 2)
# (77, 14, 32, 2)
# (55, 14, 31, 2)
# (56, 14, 30, 2)
# (52, 14, 29, 2)
# (75, 14, 28, 2)
# (14, 14, 27, 2)
# (78, 0, 26, 3)
# Selected: [10, 19, 14], for target: 43
# total reward after 6128 steps is 10029
# (47, 30, 48, 1)
# (89, 30, 47, 1)
# (30, 30, 46, 1)
# (93, 0, 45, 2)
# Selected: [33, 30], for target: 63
# total reward after 6129 steps is 100033
# (79, 21, 48, 0)
# (27, 21, 47, 0)
# (9, -6, 46, 1)
# Selected: [27], for target: 21
# total reward after 6130 steps is -27
# (60, 0, 48, 1)
# Selected: [58], for target: 58
# total reward after 6131 steps is 1000000
# (25, 4, 48, 1)
# (51, 4, 47, 1)
# (80, 4, 46, 1)
# (65, 4, 45, 1)
# (16, 4, 44, 1)
# (95, 4, 43, 1)
# (35, 4, 42, 1)
# (73, 4, 41, 1)
# (92, 4, 40, 1)
# (87, 4, 39, 1)
# (51, 4, 38, 1)
# (34, 4, 37, 1)
# (77, 4, 36, 1)
# (38, 4, 35, 1)
# (22, 4, 34, 1)
# (66, 4, 33, 1)
# (42, 4, 32, 1)
# (82, 4, 31, 1)
# (20, 4, 30, 1)
# (98, 4, 29, 1)
# (16, 4, 28, 1)
# (37, 4, 27, 1)
# (34, 4, 26, 1)
# (62, 4, 25, 1)
# (7, 4, 24, 1)
# (18, -3, 23, 2)
# Selected: [39, 7], for target: 43
# total reward after 6132 steps is -7
# (79, 4, 48, 1)
# (16, 4, 47, 1)
# (37, 4, 46, 1)
# (82, 4, 45, 1)
# (3, 4, 44, 1)
# (88, 1, 43, 2)
# (9, 1, 42, 2)
# (61, 1, 41, 2)
# (65, 1, 40, 2)
# (91, 1, 39, 2)
# (61, 1, 38, 2)
# (83, 1, 37, 2)
# (6, 1, 36, 2)
# (82, 1, 35, 2)
# (80, 1, 34, 2)
# (3, 1, 33, 2)
# (37, -2, 32, 3)
# Selected: [6, 3, 3], for target: 10
# total reward after 6133 steps is -3
# (65, 72, 48, 1)
# (65, 7, 47, 2)
# (20, 7, 46, 2)
# (32, 7, 45, 2)
# (51, 7, 44, 2)
# (44, 7, 43, 2)
# (97, 7, 42, 2)
# (49, 7, 41, 2)
# (47, 7, 40, 2)
# (41, 7, 39, 2)
# (95, 7, 38, 2)
# (27, 7, 37, 2)
# (99, 7, 36, 2)
# (86, 7, 35, 2)
# (56, 7, 34, 2)
# (52, 7, 33, 2)
# (23, 7, 32, 2)
# (40, 7, 31, 2)
# (29, 7, 30, 2)
# (97, 7, 29, 2)
# (2, 7, 28, 2)
# (10, 5, 27, 3)
# (46, 5, 26, 3)
# (72, 5, 25, 3)
# (63, 5, 24, 3)
# (46, 5, 23, 3)
# (12, 5, 22, 3)
# (16, 5, 21, 3)
# (11, 5, 20, 3)
# (54, 5, 19, 3)
# (6, 5, 18, 3)
# (78, -1, 17, 4)
# Selected: [10, 65, 2, 6], for target: 82
# total reward after 6134 steps is -6
# (71, 21, 48, 1)
# (5, 21, 47, 1)
# (59, 16, 46, 2)
# (100, 16, 45, 2)
# (69, 16, 44, 2)
# (22, 16, 43, 2)
# (52, 16, 42, 2)
# (88, 16, 41, 2)
# (90, 16, 40, 2)
# (3, 16, 39, 2)
# (78, 13, 38, 3)
# (9, 13, 37, 3)
# (4, 4, 36, 4)
# (60, 0, 35, 5)
# Selected: [35, 5, 3, 9, 4], for target: 56
# total reward after 6135 steps is 152
# (87, 24, 48, 1)
# (92, 24, 47, 1)
# (8, 24, 46, 1)
# (13, 16, 45, 2)
# (90, 3, 44, 3)
# (63, 3, 43, 3)
# (3, 3, 42, 3)
# (16, 0, 41, 4)
# Selected: [20, 8, 13, 3], for target: 44
# total reward after 6136 steps is 1041
# (5, 2, 48, 0)
# (79, -3, 47, 1)
# Selected: [5], for target: 2
# total reward after 6137 steps is -5
# (4, 1, 48, 1)
# (94, -3, 47, 2)
# Selected: [74, 4], for target: 75
# total reward after 6138 steps is -4
# (30, 63, 48, 0)
# (29, 33, 47, 1)
# (75, 4, 46, 2)
# (22, 4, 45, 2)
# (69, 4, 44, 2)
# (22, 4, 43, 2)
# (71, 4, 42, 2)
# (42, 4, 41, 2)
# (71, 4, 40, 2)
# (11, 4, 39, 2)
# (66, -7, 38, 3)
# Selected: [30, 29, 11], for target: 63
# total reward after 6139 steps is -11
# (59, 1, 48, 1)
# (17, 1, 47, 1)
# (51, 1, 46, 1)
# (53, 1, 45, 1)
# (37, 1, 44, 1)
# (21, 1, 43, 1)
# (8, 1, 42, 1)
# (1, 1, 41, 1)
# (13, 0, 40, 2)
# Selected: [53, 1], for target: 54
# total reward after 6140 steps is 100053
# (47, -7, 48, 1)
# Selected: [73], for target: 66
# total reward after 6141 steps is -73
# (46, 10, 48, 1)
# (50, 10, 47, 1)
# (84, 10, 46, 1)
# (2, 10, 45, 1)
# (38, 8, 44, 2)
# (38, 8, 43, 2)
# (69, 8, 42, 2)
# (65, 8, 41, 2)
# (30, 8, 40, 2)
# (31, 8, 39, 2)
# (98, 8, 38, 2)
# (47, 8, 37, 2)
# (95, 8, 36, 2)
# (16, 8, 35, 2)
# (86, 8, 34, 2)
# (19, 8, 33, 2)
# (31, 8, 32, 2)
# (62, 8, 31, 2)
# (38, 8, 30, 2)
# (61, 8, 29, 2)
# (6, 8, 28, 2)
# (14, 2, 27, 3)
# (71, 2, 26, 3)
# (73, 2, 25, 3)
# (49, 2, 24, 3)
# (89, 2, 23, 3)
# (19, 2, 22, 3)
# (97, 2, 21, 3)
# (64, 2, 20, 3)
# (52, 2, 19, 3)
# (87, 2, 18, 3)
# (22, 2, 17, 3)
# (85, 2, 16, 3)
# (52, 2, 15, 3)
# (49, 2, 14, 3)
# (46, 2, 13, 3)
# (23, 2, 12, 3)
# (69, 2, 11, 3)
# (78, 2, 10, 3)
# (6, 2, 9, 3)
# (89, 2, 8, 3)
# (4, 2, 7, 3)
# (89, 2, 6, 3)
# (21, 2, 5, 3)
# (26, 2, 4, 3)
# (38, 2, 3, 3)
# (57, 2, 2, 3)
# (59, 2, 1, 3)
# (75, 2, 0, 3)
# (11, 2, -1, 3)
# Selected: [11, 2, 6], for target: 21
# total reward after 6142 steps is 19
# (72, 10, 48, 1)
# (13, 10, 47, 1)
# (60, -3, 46, 2)
# Selected: [77, 13], for target: 87
# total reward after 6143 steps is -13
# (62, 21, 48, 0)
# (26, 21, 47, 0)
# (76, -5, 46, 1)
# Selected: [26], for target: 21
# total reward after 6144 steps is -26
# (82, -9, 48, 1)
# Selected: [45], for target: 36
# total reward after 6145 steps is -45
# (47, -8, 48, 1)
# Selected: [98], for target: 90
# total reward after 6146 steps is -98
# (100, 45, 48, 0)
# (81, 45, 47, 0)
# (20, 45, 46, 0)
# (35, 25, 45, 1)
# (30, 25, 44, 1)
# (50, 25, 43, 1)
# (20, 25, 42, 1)
# (10, 5, 41, 2)
# (83, 5, 40, 2)
# (20, 5, 39, 2)
# (81, 5, 38, 2)
# (6, 5, 37, 2)
# (90, -1, 36, 3)
# Selected: [20, 20, 6], for target: 45
# total reward after 6147 steps is -6
# (9, 32, 48, 0)
# (52, 23, 47, 1)
# (66, 23, 46, 1)
# (10, 23, 45, 1)
# (20, 13, 44, 2)
# (25, 13, 43, 2)
# (64, 13, 42, 2)
# (6, 13, 41, 2)
# (81, 7, 40, 3)
# (19, 7, 39, 3)
# (100, 7, 38, 3)
# (64, 7, 37, 3)
# (15, 7, 36, 3)
# (6, 7, 35, 3)
# (15, 1, 34, 4)
# (40, 1, 33, 4)
# (7, 1, 32, 4)
# (19, 1, 31, 4)
# (33, 1, 30, 4)
# (32, 1, 29, 4)
# (62, 1, 28, 4)
# (75, 1, 27, 4)
# (67, 1, 26, 4)
# (21, 1, 25, 4)
# (86, 1, 24, 4)
# (30, 1, 23, 4)
# (24, 1, 22, 4)
# (44, 1, 21, 4)
# (77, 1, 20, 4)
# (5, 1, 19, 4)
# (3, 1, 18, 4)
# (12, 1, 17, 4)
# (81, 1, 16, 4)
# (58, 1, 15, 4)
# (89, 1, 14, 4)
# (82, 1, 13, 4)
# (59, 1, 12, 4)
# (83, 1, 11, 4)
# (51, 1, 10, 4)
# (4, 1, 9, 4)
# (54, 1, 8, 4)
# (70, 1, 7, 4)
# (62, 1, 6, 4)
# (20, 1, 5, 4)
# (53, 1, 4, 4)
